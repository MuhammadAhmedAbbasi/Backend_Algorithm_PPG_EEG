# %%
import os
import pandas as pd
import sys
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from datetime import datetime
from torch.utils.data import Dataset, DataLoader

sys.path.append(os.path.join(os.getcwd(), '../../../common'))
from ppg_feature_processor import map_gender, map_age

# %%
# 获取当前日期
current_date = datetime.now().strftime("%Y-%m-%d")
# 构建导出的pth文件名以及ONNX文件名
outdir = 'outdir'
pth_file_path = os.path.join(outdir, f'ppg_stress-best_model_{current_date}.pth')
onnx_file_path = os.path.join(outdir, f"ppg_stress-best_model_{current_date}.onnx")

# %%
profile_columns = ['wave_quality', 'age', 'gender', 'label', 'id']

# %%
# 加载数据
train_pos_dataset = pd.read_pickle('./samples/train_pos_dataset.pkl')
train_neg_dataset = pd.read_pickle('./samples/train_neg_dataset.pkl')
test_pos_dataset = pd.read_pickle('./samples/test_pos_dataset.pkl')
test_neg_dataset = pd.read_pickle('./samples/test_neg_dataset.pkl')
# testing_pos_dataset = pd.read_pickle('./samples/testing_positive.pkl')
# testing_neg_dataset = pd.read_pickle('./samples/testing_negative.pkl')

test_val_pos_list  = (test_pos_dataset['id'].unique()).tolist()
test_val_neg_list  = (test_neg_dataset['id'].unique()).tolist()

validation_pos_data = test_pos_dataset[test_pos_dataset['id'].isin(test_val_pos_list[:3])]
test_pos_dataset = test_pos_dataset[test_pos_dataset['id'].isin(test_val_pos_list[3:])]
validation_neg_data = test_neg_dataset[test_neg_dataset['id'].isin(test_val_neg_list[:3])]
test_neg_dataset = test_neg_dataset[test_neg_dataset['id'].isin(test_val_neg_list[3:])]

# %%
train_pos_dataset['age'].unique()
# Out:
# array([13, 12], dtype=int64)

# %%
# # ---------------------------- 数据预处理 ----------------------------
def map_age(age):
    if age < 13:
        return [1, 0]
    elif age >= 13:
        return [0, 1] 

# ---------------------------- 数据预处理 ----------------------------
def map_gender(gender):
    return [1, 0] if gender == 'Female' else [0, 1]

def preprocess(df):
    df_new = df.copy()
    
    df_new[['age_0', 'age_1']] = df_new['age'].apply(map_age).apply(pd.Series)
    df_new[['gender_0', 'gender_1']] = df_new['gender'].apply(map_gender).apply(pd.Series)
    return df_new.drop(profile_columns, axis=1)


# 应用预处理
train_pos_features = preprocess(train_pos_dataset)
train_neg_features = preprocess(train_neg_dataset)
val_pos_features = preprocess(validation_pos_data)
val_neg_features = preprocess(validation_neg_data)
test_pos_features = preprocess(test_pos_dataset)
test_neg_features = preprocess(test_neg_dataset)


# testing_pos_features = preprocess(testing_pos_dataset)
# testing_neg_features = preprocess(testing_neg_dataset)

# %%
print(train_pos_dataset.columns)

print(train_pos_features.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_LF', 'HRV_HF',
#        'HRV_VHF', 'HRV_TP', 'HRV_LFHF', 'HRV_LFn', 'HRV_HFn', 'HRV_LnHF',
#        'wave_quality', 'label', 'id', 'age', 'gender'],
#       dtype='object')
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_LF', 'HRV_HF',
#        'HRV_VHF', 'HRV_TP', 'HRV_LFHF', 'HRV_LFn', 'HRV_HFn', 'HRV_LnHF',
#        'age_0', 'age_1', 'gender_0', 'gender_1'],
#       dtype='object')

# %%
# ---------------------------- DNN 模型 ----------------------------

class DNNModel(nn.Module):
    def __init__(self, input_dim):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.relu = nn.ReLU()
        self.dropOut = nn.Dropout(0.5)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropOut(x)
        x = self.relu(self.fc2(x))
        x = self.dropOut(x)
        x = self.sigmoid(self.fc3(x))
        return x

input_dim = train_pos_features.shape[1]
model = DNNModel(input_dim)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# ---------------------------- 自定义数据加载器 ----------------------------

class BalancedDataset(Dataset):
    def __init__(self, pos_data, neg_data):
        self.pos_data = pos_data
        self.neg_data = neg_data
        self.pos_len = len(pos_data)
        self.neg_len = len(neg_data)

    def __len__(self):
        return min(self.pos_len, self.neg_len)

    def __getitem__(self, idx):
        pos_idx = np.random.randint(0, self.pos_len)
        neg_idx = np.random.randint(0, self.neg_len)
        
        pos_sample = self.pos_data.iloc[pos_idx].values.astype(np.float32)
        neg_sample = self.neg_data.iloc[neg_idx].values.astype(np.float32)

        X = np.vstack([pos_sample, neg_sample])
        y = np.array([1, 0], dtype=np.float32)

        return torch.tensor(X), torch.tensor(y)

class TestDataset(Dataset):
    def __init__(self, pos_data, neg_data):
        self.pos_data = pos_data
        self.neg_data = neg_data
        self.pos_len = len(pos_data)
        self.neg_len = len(neg_data)

    def __len__(self):
        return self.pos_len + self.neg_len

    def __getitem__(self, idx):
        if idx < self.pos_len:
            sample = self.pos_data.iloc[idx].values.astype(np.float32)
            label = 1
        else:
            idx -= self.pos_len
            sample = self.neg_data.iloc[idx].values.astype(np.float32)
            label = 0
        
        return torch.tensor(sample), torch.tensor(label, dtype=torch.float32)

# 初始化数据集和数据加载器
batch_size = 64
train_dataset = BalancedDataset(train_pos_features, train_neg_features)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataset = TestDataset(val_pos_features, val_neg_features)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_dataset = TestDataset(test_pos_features, test_neg_features)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# ---------------------------- 模型训练 ----------------------------
num_epochs = 500
train_losses = []
test_accuracies = []

def evaluate_model(model, data_loader):
    model.eval()  # 设置模型为评估模式
    pos_correct = 0
    neg_correct = 0
    pos_total = 0
    neg_total = 0

    with torch.no_grad():  # 关闭梯度计算
        for inputs, labels in data_loader:
            outputs = model(inputs)
            predicted = (outputs.squeeze() >= 0.5).float()

            # print(f"predicted: {predicted}")
            # Calculate accuracy for positive and negative samples
            pos_mask = (labels == 1).float()
            neg_mask = (labels == 0).float()
            pos_correct += ((predicted == labels) * pos_mask).sum().item()
            neg_correct += ((predicted == labels) * neg_mask).sum().item()
            pos_total += pos_mask.sum().item()
            neg_total += neg_mask.sum().item()
            

    pos_accuracy = pos_correct / pos_total if pos_total > 0 else 0
    neg_accuracy = neg_correct / neg_total if neg_total > 0 else 0
    return pos_accuracy, neg_accuracy, (pos_correct+neg_correct) / (pos_total + neg_total)


best_accuracy = 0.0
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), labels)
        epoch_loss += loss.item()

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accuracy calculation
        predicted = (outputs.squeeze() > 0.5).float()
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    # Calculate average loss and accuracy for the epoch
    avg_loss = epoch_loss / len(train_loader)
    avg_accuracy = correct / total
    train_losses.append(avg_loss)
    
    # Evaluate on test set
    pos_accuracy, neg_accuracy, accuracy = evaluate_model(model, val_loader)
    test_accuracies.append(accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Avg Accuracy: {accuracy},  Positive Accuracy: {pos_accuracy * 100:.2f}%, Negative Accuracy: {neg_accuracy * 100:.2f}%')

    # Save the best model
    if accuracy > best_accuracy and (pos_accuracy >0.5 and neg_accuracy >0.5) and epoch > 2:
        best_accuracy = accuracy
        torch.save(model.state_dict(), pth_file_path)
        print("Best Accuracy Model: {}".format(best_accuracy))

        # Export the best model to ONNX
        dummy_input = torch.randn(1, input_dim)
        torch.onnx.export(model, dummy_input, onnx_file_path, input_names=['input'], output_names=['output'])
    

# ---------------------------- 绘制训练曲线 ----------------------------

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Curve')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), [acc * 100 for acc in test_accuracies], marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Testing Accuracy Curve')

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/500], Loss: 0.6945, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 28.89%, Negative Accuracy: 100.00%
# Epoch [2/500], Loss: 0.6926, Avg Accuracy: 0.4,  Positive Accuracy: 55.56%, Negative Accuracy: 24.44%
# Epoch [3/500], Loss: 0.6928, Avg Accuracy: 0.3333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 0.00%
# Epoch [4/500], Loss: 0.6920, Avg Accuracy: 0.3333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 0.00%
# Epoch [5/500], Loss: 0.6919, Avg Accuracy: 0.3333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 0.00%
# Epoch [6/500], Loss: 0.6934, Avg Accuracy: 0.34444444444444444,  Positive Accuracy: 66.67%, Negative Accuracy: 2.22%
# Epoch [7/500], Loss: 0.6926, Avg Accuracy: 0.3333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 0.00%
# Epoch [8/500], Loss: 0.6929, Avg Accuracy: 0.3333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 0.00%
# Epoch [9/500], Loss: 0.6929, Avg Accuracy: 0.4111111111111111,  Positive Accuracy: 57.78%, Negative Accuracy: 24.44%
# Epoch [10/500], Loss: 0.6941, Avg Accuracy: 0.34444444444444444,  Positive Accuracy: 66.67%, Negative Accuracy: 2.22%
# Epoch [11/500], Loss: 0.6906, Avg Accuracy: 0.34444444444444444,  Positive Accuracy: 64.44%, Negative Accuracy: 4.44%
# Epoch [12/500], Loss: 0.6916, Avg Accuracy: 0.3888888888888889,  Positive Accuracy: 62.22%, Negative Accuracy: 15.56%
# Epoch [13/500], Loss: 0.6931, Avg Accuracy: 0.37777777777777777,  Positive Accuracy: 64.44%, Negative Accuracy: 11.11%
# Epoch [14/500], Loss: 0.6937, Avg Accuracy: 0.4,  Positive Accuracy: 51.11%, Negative Accuracy: 28.89%
# Epoch [15/500], Loss: 0.6921, Avg Accuracy: 0.36666666666666664,  Positive Accuracy: 64.44%, Negative Accuracy: 8.89%
# Epoch [16/500], Loss: 0.6913, Avg Accuracy: 0.4222222222222222,  Positive Accuracy: 60.00%, Negative Accuracy: 24.44%
# Epoch [17/500], Loss: 0.6901, Avg Accuracy: 0.5333333333333333,  Positive Accuracy: 46.67%, Negative Accuracy: 60.00%
# Epoch [18/500], Loss: 0.6909, Avg Accuracy: 0.5,  Positive Accuracy: 46.67%, Negative Accuracy: 53.33%
# Epoch [19/500], Loss: 0.6923, Avg Accuracy: 0.5222222222222223,  Positive Accuracy: 55.56%, Negative Accuracy: 48.89%
# Epoch [20/500], Loss: 0.6887, Avg Accuracy: 0.5222222222222223,  Positive Accuracy: 48.89%, Negative Accuracy: 55.56%
# Epoch [21/500], Loss: 0.6874, Avg Accuracy: 0.4111111111111111,  Positive Accuracy: 60.00%, Negative Accuracy: 22.22%
# Epoch [22/500], Loss: 0.6922, Avg Accuracy: 0.4666666666666667,  Positive Accuracy: 51.11%, Negative Accuracy: 42.22%
# Epoch [23/500], Loss: 0.6870, Avg Accuracy: 0.36666666666666664,  Positive Accuracy: 57.78%, Negative Accuracy: 15.56%
# Epoch [24/500], Loss: 0.6877, Avg Accuracy: 0.3333333333333333,  Positive Accuracy: 64.44%, Negative Accuracy: 2.22%
# Epoch [25/500], Loss: 0.6874, Avg Accuracy: 0.35555555555555557,  Positive Accuracy: 64.44%, Negative Accuracy: 6.67%
# Epoch [26/500], Loss: 0.6896, Avg Accuracy: 0.5,  Positive Accuracy: 44.44%, Negative Accuracy: 55.56%
# Epoch [27/500], Loss: 0.6876, Avg Accuracy: 0.4888888888888889,  Positive Accuracy: 53.33%, Negative Accuracy: 44.44%
# Epoch [28/500], Loss: 0.6852, Avg Accuracy: 0.4666666666666667,  Positive Accuracy: 53.33%, Negative Accuracy: 40.00%
# Epoch [29/500], Loss: 0.6887, Avg Accuracy: 0.4777777777777778,  Positive Accuracy: 55.56%, Negative Accuracy: 40.00%
# Epoch [30/500], Loss: 0.6854, Avg Accuracy: 0.5,  Positive Accuracy: 55.56%, Negative Accuracy: 44.44%
# Epoch [31/500], Loss: 0.6869, Avg Accuracy: 0.4888888888888889,  Positive Accuracy: 40.00%, Negative Accuracy: 57.78%
# Epoch [32/500], Loss: 0.6880, Avg Accuracy: 0.5111111111111111,  Positive Accuracy: 40.00%, Negative Accuracy: 62.22%
# Epoch [33/500], Loss: 0.6868, Avg Accuracy: 0.5,  Positive Accuracy: 46.67%, Negative Accuracy: 53.33%
# Epoch [34/500], Loss: 0.6835, Avg Accuracy: 0.5111111111111111,  Positive Accuracy: 40.00%, Negative Accuracy: 62.22%
# Epoch [35/500], Loss: 0.6840, Avg Accuracy: 0.5222222222222223,  Positive Accuracy: 37.78%, Negative Accuracy: 66.67%
# Epoch [36/500], Loss: 0.6846, Avg Accuracy: 0.5222222222222223,  Positive Accuracy: 42.22%, Negative Accuracy: 62.22%
# Epoch [37/500], Loss: 0.6834, Avg Accuracy: 0.5,  Positive Accuracy: 33.33%, Negative Accuracy: 66.67%
# Epoch [38/500], Loss: 0.6849, Avg Accuracy: 0.5,  Positive Accuracy: 35.56%, Negative Accuracy: 64.44%
# Epoch [39/500], Loss: 0.6853, Avg Accuracy: 0.5,  Positive Accuracy: 55.56%, Negative Accuracy: 44.44%
# Epoch [40/500], Loss: 0.6856, Avg Accuracy: 0.5111111111111111,  Positive Accuracy: 37.78%, Negative Accuracy: 64.44%
# Epoch [41/500], Loss: 0.6850, Avg Accuracy: 0.5,  Positive Accuracy: 44.44%, Negative Accuracy: 55.56%
# Epoch [42/500], Loss: 0.6884, Avg Accuracy: 0.5111111111111111,  Positive Accuracy: 37.78%, Negative Accuracy: 64.44%
# Epoch [43/500], Loss: 0.6897, Avg Accuracy: 0.5,  Positive Accuracy: 35.56%, Negative Accuracy: 64.44%
# Epoch [44/500], Loss: 0.6859, Avg Accuracy: 0.5222222222222223,  Positive Accuracy: 40.00%, Negative Accuracy: 64.44%
# Epoch [45/500], Loss: 0.6867, Avg Accuracy: 0.5444444444444444,  Positive Accuracy: 48.89%, Negative Accuracy: 60.00%
# Epoch [46/500], Loss: 0.6831, Avg Accuracy: 0.5444444444444444,  Positive Accuracy: 48.89%, Negative Accuracy: 60.00%
# Epoch [47/500], Loss: 0.6837, Avg Accuracy: 0.5555555555555556,  Positive Accuracy: 57.78%, Negative Accuracy: 53.33%
# Best Accuracy Model: 0.5555555555555556
# Epoch [48/500], Loss: 0.6863, Avg Accuracy: 0.5333333333333333,  Positive Accuracy: 42.22%, Negative Accuracy: 64.44%
# Epoch [49/500], Loss: 0.6922, Avg Accuracy: 0.5111111111111111,  Positive Accuracy: 33.33%, Negative Accuracy: 68.89%
# Epoch [50/500], Loss: 0.6865, Avg Accuracy: 0.5222222222222223,  Positive Accuracy: 40.00%, Negative Accuracy: 64.44%
# Epoch [51/500], Loss: 0.6881, Avg Accuracy: 0.5333333333333333,  Positive Accuracy: 51.11%, Negative Accuracy: 55.56%
# Epoch [52/500], Loss: 0.6848, Avg Accuracy: 0.5444444444444444,  Positive Accuracy: 40.00%, Negative Accuracy: 68.89%
# Epoch [53/500], Loss: 0.6798, Avg Accuracy: 0.5444444444444444,  Positive Accuracy: 44.44%, Negative Accuracy: 64.44%
# Epoch [54/500], Loss: 0.6816, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 51.11%, Negative Accuracy: 62.22%
# Best Accuracy Model: 0.5666666666666667
# Epoch [55/500], Loss: 0.6857, Avg Accuracy: 0.5111111111111111,  Positive Accuracy: 33.33%, Negative Accuracy: 68.89%
# Epoch [56/500], Loss: 0.6808, Avg Accuracy: 0.5333333333333333,  Positive Accuracy: 37.78%, Negative Accuracy: 68.89%
# Epoch [57/500], Loss: 0.6778, Avg Accuracy: 0.5222222222222223,  Positive Accuracy: 35.56%, Negative Accuracy: 68.89%
# Epoch [58/500], Loss: 0.6810, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 48.89%, Negative Accuracy: 68.89%
# Epoch [59/500], Loss: 0.6764, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 57.78%, Negative Accuracy: 68.89%
# Best Accuracy Model: 0.6333333333333333
# Epoch [60/500], Loss: 0.6871, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 62.22%, Negative Accuracy: 68.89%
# Best Accuracy Model: 0.6555555555555556
# Epoch [61/500], Loss: 0.6816, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 57.78%, Negative Accuracy: 68.89%
# Epoch [62/500], Loss: 0.6851, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 64.44%, Negative Accuracy: 66.67%
# Epoch [63/500], Loss: 0.6795, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 68.89%, Negative Accuracy: 53.33%
# Epoch [64/500], Loss: 0.6778, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 64.44%, Negative Accuracy: 60.00%
# Epoch [65/500], Loss: 0.6807, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 55.56%, Negative Accuracy: 66.67%
# Epoch [66/500], Loss: 0.6821, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 55.56%, Negative Accuracy: 66.67%
# Epoch [67/500], Loss: 0.6814, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 55.56%, Negative Accuracy: 60.00%
# Epoch [68/500], Loss: 0.6821, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 57.78%, Negative Accuracy: 71.11%
# Epoch [69/500], Loss: 0.6889, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 64.44%, Negative Accuracy: 71.11%
# Best Accuracy Model: 0.6777777777777778
# Epoch [70/500], Loss: 0.6851, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 64.44%, Negative Accuracy: 62.22%
# Epoch [71/500], Loss: 0.6769, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 57.78%
# Epoch [72/500], Loss: 0.6771, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 62.22%, Negative Accuracy: 62.22%
# Epoch [73/500], Loss: 0.6747, Avg Accuracy: 0.5555555555555556,  Positive Accuracy: 53.33%, Negative Accuracy: 57.78%
# Epoch [74/500], Loss: 0.6845, Avg Accuracy: 0.5444444444444444,  Positive Accuracy: 53.33%, Negative Accuracy: 55.56%
# Epoch [75/500], Loss: 0.6809, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 64.44%, Negative Accuracy: 62.22%
# Epoch [76/500], Loss: 0.6779, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 68.89%, Negative Accuracy: 46.67%
# Epoch [77/500], Loss: 0.6765, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 68.89%, Negative Accuracy: 53.33%
# Epoch [78/500], Loss: 0.6805, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 60.00%, Negative Accuracy: 62.22%
# Epoch [79/500], Loss: 0.6856, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 62.22%
# Epoch [80/500], Loss: 0.6855, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 68.89%, Negative Accuracy: 64.44%
# Epoch [81/500], Loss: 0.6800, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 68.89%, Negative Accuracy: 60.00%
# Epoch [82/500], Loss: 0.6838, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 68.89%, Negative Accuracy: 60.00%
# Epoch [83/500], Loss: 0.6786, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 62.22%, Negative Accuracy: 62.22%
# Epoch [84/500], Loss: 0.6791, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 60.00%, Negative Accuracy: 71.11%
# Epoch [85/500], Loss: 0.6844, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 62.22%, Negative Accuracy: 64.44%
# Epoch [86/500], Loss: 0.6839, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 66.67%, Negative Accuracy: 64.44%
# Epoch [87/500], Loss: 0.6858, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 68.89%, Negative Accuracy: 66.67%
# Epoch [88/500], Loss: 0.6868, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 68.89%, Negative Accuracy: 66.67%
# Epoch [89/500], Loss: 0.6785, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 75.56%, Negative Accuracy: 57.78%
# Epoch [90/500], Loss: 0.6794, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 68.89%, Negative Accuracy: 64.44%
# Epoch [91/500], Loss: 0.6858, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 71.11%, Negative Accuracy: 55.56%
# Epoch [92/500], Loss: 0.6826, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 64.44%, Negative Accuracy: 68.89%
# Epoch [93/500], Loss: 0.6799, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 60.00%, Negative Accuracy: 68.89%
# Epoch [94/500], Loss: 0.6790, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 64.44%, Negative Accuracy: 68.89%
# Epoch [95/500], Loss: 0.6818, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 64.44%, Negative Accuracy: 71.11%
# Epoch [96/500], Loss: 0.6863, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 68.89%, Negative Accuracy: 64.44%
# Epoch [97/500], Loss: 0.6728, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 60.00%, Negative Accuracy: 68.89%
# Epoch [98/500], Loss: 0.6768, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 68.89%, Negative Accuracy: 62.22%
# Epoch [99/500], Loss: 0.6812, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 60.00%, Negative Accuracy: 71.11%
# Epoch [100/500], Loss: 0.6805, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 66.67%, Negative Accuracy: 86.67%
# Best Accuracy Model: 0.7666666666666667
# Epoch [101/500], Loss: 0.6777, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 66.67%, Negative Accuracy: 68.89%
# Epoch [102/500], Loss: 0.6771, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 73.33%, Negative Accuracy: 55.56%
# Epoch [103/500], Loss: 0.6769, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 55.56%
# Epoch [104/500], Loss: 0.6707, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 64.44%, Negative Accuracy: 66.67%
# Epoch [105/500], Loss: 0.6687, Avg Accuracy: 0.7,  Positive Accuracy: 75.56%, Negative Accuracy: 64.44%
# Epoch [106/500], Loss: 0.6772, Avg Accuracy: 0.7,  Positive Accuracy: 64.44%, Negative Accuracy: 75.56%
# Epoch [107/500], Loss: 0.6754, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 62.22%, Negative Accuracy: 62.22%
# Epoch [108/500], Loss: 0.6676, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 66.67%, Negative Accuracy: 64.44%
# Epoch [109/500], Loss: 0.6721, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 73.33%, Negative Accuracy: 57.78%
# Epoch [110/500], Loss: 0.6709, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 64.44%, Negative Accuracy: 62.22%
# Epoch [111/500], Loss: 0.6757, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 66.67%, Negative Accuracy: 64.44%
# Epoch [112/500], Loss: 0.6807, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 75.56%
# Epoch [113/500], Loss: 0.6786, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 75.56%
# Epoch [114/500], Loss: 0.6778, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 66.67%, Negative Accuracy: 77.78%
# Epoch [115/500], Loss: 0.6807, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 66.67%, Negative Accuracy: 68.89%
# Epoch [116/500], Loss: 0.6732, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [117/500], Loss: 0.6838, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 57.78%
# Epoch [118/500], Loss: 0.6757, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 68.89%, Negative Accuracy: 60.00%
# Epoch [119/500], Loss: 0.6718, Avg Accuracy: 0.7,  Positive Accuracy: 64.44%, Negative Accuracy: 75.56%
# Epoch [120/500], Loss: 0.6723, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 71.11%, Negative Accuracy: 71.11%
# Epoch [121/500], Loss: 0.6776, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 60.00%, Negative Accuracy: 73.33%
# Epoch [122/500], Loss: 0.6743, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 64.44%, Negative Accuracy: 68.89%
# Epoch [123/500], Loss: 0.6661, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 64.44%, Negative Accuracy: 66.67%
# Epoch [124/500], Loss: 0.6726, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 60.00%, Negative Accuracy: 86.67%
# Epoch [125/500], Loss: 0.6746, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 68.89%, Negative Accuracy: 57.78%
# Epoch [126/500], Loss: 0.6652, Avg Accuracy: 0.6,  Positive Accuracy: 64.44%, Negative Accuracy: 55.56%
# Epoch [127/500], Loss: 0.6730, Avg Accuracy: 0.6,  Positive Accuracy: 64.44%, Negative Accuracy: 55.56%
# Epoch [128/500], Loss: 0.6698, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 68.89%, Negative Accuracy: 62.22%
# Epoch [129/500], Loss: 0.6726, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 62.22%, Negative Accuracy: 82.22%
# Epoch [130/500], Loss: 0.6791, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 68.89%, Negative Accuracy: 68.89%
# Epoch [131/500], Loss: 0.6676, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 75.56%
# Epoch [132/500], Loss: 0.6751, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 66.67%, Negative Accuracy: 64.44%
# Epoch [133/500], Loss: 0.6766, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 64.44%
# Epoch [134/500], Loss: 0.6738, Avg Accuracy: 0.7,  Positive Accuracy: 68.89%, Negative Accuracy: 71.11%
# Epoch [135/500], Loss: 0.6691, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 73.33%, Negative Accuracy: 57.78%
# Epoch [136/500], Loss: 0.6658, Avg Accuracy: 0.7,  Positive Accuracy: 68.89%, Negative Accuracy: 71.11%
# Epoch [137/500], Loss: 0.6669, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 68.89%, Negative Accuracy: 68.89%
# Epoch [138/500], Loss: 0.6691, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 68.89%, Negative Accuracy: 62.22%
# Epoch [139/500], Loss: 0.6596, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 64.44%, Negative Accuracy: 62.22%
# Epoch [140/500], Loss: 0.6706, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 66.67%, Negative Accuracy: 66.67%
# Epoch [141/500], Loss: 0.6723, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [142/500], Loss: 0.6776, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 68.89%, Negative Accuracy: 60.00%
# Epoch [143/500], Loss: 0.6717, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 64.44%, Negative Accuracy: 71.11%
# Epoch [144/500], Loss: 0.6653, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 66.67%, Negative Accuracy: 71.11%
# Epoch [145/500], Loss: 0.6682, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 82.22%
# Epoch [146/500], Loss: 0.6674, Avg Accuracy: 0.7,  Positive Accuracy: 68.89%, Negative Accuracy: 71.11%
# Epoch [147/500], Loss: 0.6723, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 77.78%, Negative Accuracy: 51.11%
# Epoch [148/500], Loss: 0.6700, Avg Accuracy: 0.6,  Positive Accuracy: 64.44%, Negative Accuracy: 55.56%
# Epoch [149/500], Loss: 0.6633, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 62.22%, Negative Accuracy: 64.44%
# Epoch [150/500], Loss: 0.6638, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 64.44%, Negative Accuracy: 57.78%
# Epoch [151/500], Loss: 0.6721, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 66.67%, Negative Accuracy: 66.67%
# Epoch [152/500], Loss: 0.6609, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 66.67%, Negative Accuracy: 64.44%
# Epoch [153/500], Loss: 0.6668, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 66.67%, Negative Accuracy: 48.89%
# Epoch [154/500], Loss: 0.6706, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 60.00%
# Epoch [155/500], Loss: 0.6734, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 64.44%, Negative Accuracy: 82.22%
# Epoch [156/500], Loss: 0.6761, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 64.44%, Negative Accuracy: 73.33%
# Epoch [157/500], Loss: 0.6794, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 60.00%, Negative Accuracy: 64.44%
# Epoch [158/500], Loss: 0.6773, Avg Accuracy: 0.7,  Positive Accuracy: 62.22%, Negative Accuracy: 77.78%
# Epoch [159/500], Loss: 0.6679, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 71.11%, Negative Accuracy: 62.22%
# Epoch [160/500], Loss: 0.6728, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 73.33%, Negative Accuracy: 75.56%
# Epoch [161/500], Loss: 0.6647, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 68.89%, Negative Accuracy: 64.44%
# Epoch [162/500], Loss: 0.6652, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 71.11%, Negative Accuracy: 62.22%
# Epoch [163/500], Loss: 0.6655, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 71.11%, Negative Accuracy: 75.56%
# Epoch [164/500], Loss: 0.6703, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 73.33%, Negative Accuracy: 53.33%
# Epoch [165/500], Loss: 0.6598, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 75.56%
# Epoch [166/500], Loss: 0.6620, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 64.44%, Negative Accuracy: 84.44%
# Epoch [167/500], Loss: 0.6637, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 66.67%, Negative Accuracy: 84.44%
# Epoch [168/500], Loss: 0.6555, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 68.89%, Negative Accuracy: 64.44%
# Epoch [169/500], Loss: 0.6715, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 62.22%, Negative Accuracy: 73.33%
# Epoch [170/500], Loss: 0.6573, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 62.22%, Negative Accuracy: 62.22%
# Epoch [171/500], Loss: 0.6711, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 64.44%, Negative Accuracy: 77.78%
# Epoch [172/500], Loss: 0.6582, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 64.44%, Negative Accuracy: 73.33%
# Epoch [173/500], Loss: 0.6671, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [174/500], Loss: 0.6643, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 68.89%, Negative Accuracy: 80.00%
# Epoch [175/500], Loss: 0.6754, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 71.11%, Negative Accuracy: 62.22%
# Epoch [176/500], Loss: 0.6640, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 66.67%, Negative Accuracy: 64.44%
# Epoch [177/500], Loss: 0.6725, Avg Accuracy: 0.7,  Positive Accuracy: 68.89%, Negative Accuracy: 71.11%
# Epoch [178/500], Loss: 0.6605, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 64.44%, Negative Accuracy: 60.00%
# Epoch [179/500], Loss: 0.6697, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 77.78%
# Epoch [180/500], Loss: 0.6728, Avg Accuracy: 0.7,  Positive Accuracy: 66.67%, Negative Accuracy: 73.33%
# Epoch [181/500], Loss: 0.6664, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 62.22%
# Epoch [182/500], Loss: 0.6811, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 75.56%
# Epoch [183/500], Loss: 0.6635, Avg Accuracy: 0.7,  Positive Accuracy: 62.22%, Negative Accuracy: 77.78%
# Epoch [184/500], Loss: 0.6562, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 55.56%
# Epoch [185/500], Loss: 0.6584, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 64.44%, Negative Accuracy: 77.78%
# Epoch [186/500], Loss: 0.6592, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 75.56%, Negative Accuracy: 68.89%
# Epoch [187/500], Loss: 0.6609, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 64.44%, Negative Accuracy: 73.33%
# Epoch [188/500], Loss: 0.6679, Avg Accuracy: 0.7,  Positive Accuracy: 60.00%, Negative Accuracy: 80.00%
# Epoch [189/500], Loss: 0.6667, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 71.11%, Negative Accuracy: 73.33%
# Epoch [190/500], Loss: 0.6669, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 68.89%, Negative Accuracy: 77.78%
# Epoch [191/500], Loss: 0.6538, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 68.89%, Negative Accuracy: 68.89%
# Epoch [192/500], Loss: 0.6613, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 71.11%, Negative Accuracy: 75.56%
# Epoch [193/500], Loss: 0.6569, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 68.89%, Negative Accuracy: 68.89%
# Epoch [194/500], Loss: 0.6570, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 75.56%
# Epoch [195/500], Loss: 0.6669, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 64.44%, Negative Accuracy: 84.44%
# Epoch [196/500], Loss: 0.6632, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 68.89%, Negative Accuracy: 66.67%
# Epoch [197/500], Loss: 0.6630, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 80.00%
# Epoch [198/500], Loss: 0.6650, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 77.78%
# Epoch [199/500], Loss: 0.6605, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 75.56%, Negative Accuracy: 53.33%
# Epoch [200/500], Loss: 0.6569, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 64.44%, Negative Accuracy: 71.11%
# Epoch [201/500], Loss: 0.6510, Avg Accuracy: 0.7,  Positive Accuracy: 64.44%, Negative Accuracy: 75.56%
# Epoch [202/500], Loss: 0.6437, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 60.00%
# Epoch [203/500], Loss: 0.6605, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 66.67%, Negative Accuracy: 66.67%
# Epoch [204/500], Loss: 0.6537, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [205/500], Loss: 0.6502, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 64.44%, Negative Accuracy: 80.00%
# Epoch [206/500], Loss: 0.6697, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 64.44%, Negative Accuracy: 73.33%
# Epoch [207/500], Loss: 0.6802, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 71.11%, Negative Accuracy: 71.11%
# Epoch [208/500], Loss: 0.6634, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 73.33%, Negative Accuracy: 71.11%
# Epoch [209/500], Loss: 0.6659, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 80.00%
# Epoch [210/500], Loss: 0.6685, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 64.44%, Negative Accuracy: 84.44%
# Epoch [211/500], Loss: 0.6692, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 82.22%
# Epoch [212/500], Loss: 0.6655, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 66.67%, Negative Accuracy: 77.78%
# Epoch [213/500], Loss: 0.6816, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 62.22%, Negative Accuracy: 68.89%
# Epoch [214/500], Loss: 0.6592, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 62.22%, Negative Accuracy: 66.67%
# Epoch [215/500], Loss: 0.6634, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 60.00%, Negative Accuracy: 73.33%
# Epoch [216/500], Loss: 0.6729, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 64.44%, Negative Accuracy: 68.89%
# Epoch [217/500], Loss: 0.6608, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 80.00%
# Epoch [218/500], Loss: 0.6757, Avg Accuracy: 0.7,  Positive Accuracy: 71.11%, Negative Accuracy: 68.89%
# Epoch [219/500], Loss: 0.6656, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 64.44%, Negative Accuracy: 68.89%
# Epoch [220/500], Loss: 0.6651, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 64.44%
# Epoch [221/500], Loss: 0.6706, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 68.89%, Negative Accuracy: 80.00%
# Epoch [222/500], Loss: 0.6653, Avg Accuracy: 0.8,  Positive Accuracy: 71.11%, Negative Accuracy: 88.89%
# Best Accuracy Model: 0.8
# Epoch [223/500], Loss: 0.6586, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 73.33%, Negative Accuracy: 75.56%
# Epoch [224/500], Loss: 0.6672, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 71.11%, Negative Accuracy: 82.22%
# Epoch [225/500], Loss: 0.6464, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 71.11%, Negative Accuracy: 62.22%
# Epoch [226/500], Loss: 0.6686, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 68.89%, Negative Accuracy: 73.33%
# Epoch [227/500], Loss: 0.6613, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 71.11%, Negative Accuracy: 71.11%
# Epoch [228/500], Loss: 0.6560, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 71.11%, Negative Accuracy: 73.33%
# Epoch [229/500], Loss: 0.6539, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [230/500], Loss: 0.6546, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 77.78%
# Epoch [231/500], Loss: 0.6591, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [232/500], Loss: 0.6554, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [233/500], Loss: 0.6559, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 66.67%, Negative Accuracy: 86.67%
# Epoch [234/500], Loss: 0.6636, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 66.67%, Negative Accuracy: 71.11%
# Epoch [235/500], Loss: 0.6581, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 73.33%, Negative Accuracy: 75.56%
# Epoch [236/500], Loss: 0.6462, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 66.67%
# Epoch [237/500], Loss: 0.6561, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [238/500], Loss: 0.6653, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [239/500], Loss: 0.6558, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 64.44%, Negative Accuracy: 84.44%
# Epoch [240/500], Loss: 0.6533, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 80.00%
# Epoch [241/500], Loss: 0.6556, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 73.33%, Negative Accuracy: 71.11%
# Epoch [242/500], Loss: 0.6566, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 82.22%
# Epoch [243/500], Loss: 0.6506, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 68.89%, Negative Accuracy: 64.44%
# Epoch [244/500], Loss: 0.6678, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 75.56%, Negative Accuracy: 68.89%
# Epoch [245/500], Loss: 0.6529, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 75.56%, Negative Accuracy: 68.89%
# Epoch [246/500], Loss: 0.6614, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 64.44%, Negative Accuracy: 88.89%
# Epoch [247/500], Loss: 0.6594, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 68.89%, Negative Accuracy: 77.78%
# Epoch [248/500], Loss: 0.6562, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 82.22%
# Epoch [249/500], Loss: 0.6426, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 75.56%, Negative Accuracy: 71.11%
# Epoch [250/500], Loss: 0.6504, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [251/500], Loss: 0.6635, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 84.44%
# Epoch [252/500], Loss: 0.6454, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 66.67%, Negative Accuracy: 84.44%
# Epoch [253/500], Loss: 0.6566, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 66.67%, Negative Accuracy: 84.44%
# Epoch [254/500], Loss: 0.6461, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 75.56%
# Epoch [255/500], Loss: 0.6556, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 75.56%, Negative Accuracy: 68.89%
# Epoch [256/500], Loss: 0.6537, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 62.22%, Negative Accuracy: 88.89%
# Epoch [257/500], Loss: 0.6639, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 66.67%, Negative Accuracy: 77.78%
# Epoch [258/500], Loss: 0.6463, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 64.44%, Negative Accuracy: 80.00%
# Epoch [259/500], Loss: 0.6492, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 60.00%, Negative Accuracy: 82.22%
# Epoch [260/500], Loss: 0.6649, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 75.56%, Negative Accuracy: 80.00%
# Epoch [261/500], Loss: 0.6573, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 75.56%, Negative Accuracy: 75.56%
# Epoch [262/500], Loss: 0.6548, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 68.89%, Negative Accuracy: 77.78%
# Epoch [263/500], Loss: 0.6503, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [264/500], Loss: 0.6558, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 66.67%, Negative Accuracy: 88.89%
# Epoch [265/500], Loss: 0.6579, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 73.33%, Negative Accuracy: 62.22%
# Epoch [266/500], Loss: 0.6594, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 62.22%
# Epoch [267/500], Loss: 0.6434, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 60.00%, Negative Accuracy: 82.22%
# Epoch [268/500], Loss: 0.6546, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 64.44%, Negative Accuracy: 82.22%
# Epoch [269/500], Loss: 0.6409, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [270/500], Loss: 0.6634, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 86.67%
# Epoch [271/500], Loss: 0.6444, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 73.33%, Negative Accuracy: 82.22%
# Epoch [272/500], Loss: 0.6471, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [273/500], Loss: 0.6591, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 82.22%, Negative Accuracy: 60.00%
# Epoch [274/500], Loss: 0.6575, Avg Accuracy: 0.8,  Positive Accuracy: 73.33%, Negative Accuracy: 86.67%
# Epoch [275/500], Loss: 0.6524, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 62.22%, Negative Accuracy: 82.22%
# Epoch [276/500], Loss: 0.6574, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 66.67%, Negative Accuracy: 86.67%
# Epoch [277/500], Loss: 0.6567, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 68.89%, Negative Accuracy: 77.78%
# Epoch [278/500], Loss: 0.6432, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 71.11%, Negative Accuracy: 82.22%
# Epoch [279/500], Loss: 0.6638, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 64.44%, Negative Accuracy: 88.89%
# Epoch [280/500], Loss: 0.6351, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 66.67%, Negative Accuracy: 84.44%
# Epoch [281/500], Loss: 0.6452, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 64.44%, Negative Accuracy: 84.44%
# Epoch [282/500], Loss: 0.6668, Avg Accuracy: 0.7,  Positive Accuracy: 71.11%, Negative Accuracy: 68.89%
# Epoch [283/500], Loss: 0.6441, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 77.78%, Negative Accuracy: 77.78%
# Epoch [284/500], Loss: 0.6421, Avg Accuracy: 0.7,  Positive Accuracy: 64.44%, Negative Accuracy: 75.56%
# Epoch [285/500], Loss: 0.6492, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 68.89%, Negative Accuracy: 73.33%
# Epoch [286/500], Loss: 0.6486, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 75.56%, Negative Accuracy: 66.67%
# Epoch [287/500], Loss: 0.6564, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 71.11%, Negative Accuracy: 71.11%
# Epoch [288/500], Loss: 0.6426, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 71.11%, Negative Accuracy: 75.56%
# Epoch [289/500], Loss: 0.6479, Avg Accuracy: 0.7,  Positive Accuracy: 71.11%, Negative Accuracy: 68.89%
# Epoch [290/500], Loss: 0.6443, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 77.78%, Negative Accuracy: 68.89%
# Epoch [291/500], Loss: 0.6634, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 73.33%, Negative Accuracy: 57.78%
# Epoch [292/500], Loss: 0.6593, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [293/500], Loss: 0.6418, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 75.56%
# Epoch [294/500], Loss: 0.6554, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 64.44%, Negative Accuracy: 80.00%
# Epoch [295/500], Loss: 0.6510, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 66.67%, Negative Accuracy: 88.89%
# Epoch [296/500], Loss: 0.6632, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 73.33%, Negative Accuracy: 82.22%
# Epoch [297/500], Loss: 0.6542, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 80.00%
# Epoch [298/500], Loss: 0.6609, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 66.67%
# Epoch [299/500], Loss: 0.6580, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 82.22%
# Epoch [300/500], Loss: 0.6439, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 66.67%, Negative Accuracy: 80.00%
# Epoch [301/500], Loss: 0.6281, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 66.67%, Negative Accuracy: 71.11%
# Epoch [302/500], Loss: 0.6398, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 75.56%
# Epoch [303/500], Loss: 0.6445, Avg Accuracy: 0.7,  Positive Accuracy: 71.11%, Negative Accuracy: 68.89%
# Epoch [304/500], Loss: 0.6520, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 66.67%, Negative Accuracy: 88.89%
# Epoch [305/500], Loss: 0.6448, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 75.56%, Negative Accuracy: 80.00%
# Epoch [306/500], Loss: 0.6458, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 75.56%
# Epoch [307/500], Loss: 0.6435, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [308/500], Loss: 0.6497, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [309/500], Loss: 0.6449, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 62.22%, Negative Accuracy: 82.22%
# Epoch [310/500], Loss: 0.6402, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 75.56%
# Epoch [311/500], Loss: 0.6595, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 66.67%
# Epoch [312/500], Loss: 0.6541, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 68.89%, Negative Accuracy: 64.44%
# Epoch [313/500], Loss: 0.6660, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 68.89%, Negative Accuracy: 60.00%
# Epoch [314/500], Loss: 0.6469, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 68.89%, Negative Accuracy: 73.33%
# Epoch [315/500], Loss: 0.6494, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 62.22%, Negative Accuracy: 82.22%
# Epoch [316/500], Loss: 0.6539, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 66.67%, Negative Accuracy: 86.67%
# Epoch [317/500], Loss: 0.6438, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 73.33%, Negative Accuracy: 84.44%
# Epoch [318/500], Loss: 0.6482, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [319/500], Loss: 0.6486, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [320/500], Loss: 0.6384, Avg Accuracy: 0.7,  Positive Accuracy: 73.33%, Negative Accuracy: 66.67%
# Epoch [321/500], Loss: 0.6559, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 71.11%, Negative Accuracy: 82.22%
# Epoch [322/500], Loss: 0.6452, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [323/500], Loss: 0.6464, Avg Accuracy: 0.7,  Positive Accuracy: 71.11%, Negative Accuracy: 68.89%
# Epoch [324/500], Loss: 0.6431, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 66.67%, Negative Accuracy: 77.78%
# Epoch [325/500], Loss: 0.6358, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 73.33%, Negative Accuracy: 82.22%
# Epoch [326/500], Loss: 0.6643, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 75.56%
# Epoch [327/500], Loss: 0.6382, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 77.78%, Negative Accuracy: 66.67%
# Epoch [328/500], Loss: 0.6500, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [329/500], Loss: 0.6413, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 82.22%
# Epoch [330/500], Loss: 0.6405, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 82.22%
# Epoch [331/500], Loss: 0.6448, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 71.11%, Negative Accuracy: 82.22%
# Epoch [332/500], Loss: 0.6428, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [333/500], Loss: 0.6424, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [334/500], Loss: 0.6610, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [335/500], Loss: 0.6360, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [336/500], Loss: 0.6460, Avg Accuracy: 0.8222222222222222,  Positive Accuracy: 75.56%, Negative Accuracy: 88.89%
# Best Accuracy Model: 0.8222222222222222
# Epoch [337/500], Loss: 0.6519, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 75.56%, Negative Accuracy: 82.22%
# Epoch [338/500], Loss: 0.6426, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 68.89%, Negative Accuracy: 86.67%
# Epoch [339/500], Loss: 0.6562, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 68.89%, Negative Accuracy: 77.78%
# Epoch [340/500], Loss: 0.6603, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 75.56%, Negative Accuracy: 73.33%
# Epoch [341/500], Loss: 0.6472, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [342/500], Loss: 0.6355, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [343/500], Loss: 0.6493, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 73.33%, Negative Accuracy: 82.22%
# Epoch [344/500], Loss: 0.6478, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [345/500], Loss: 0.6473, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 77.78%, Negative Accuracy: 75.56%
# Epoch [346/500], Loss: 0.6324, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 77.78%, Negative Accuracy: 77.78%
# Epoch [347/500], Loss: 0.6401, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 68.89%, Negative Accuracy: 86.67%
# Epoch [348/500], Loss: 0.6462, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 66.67%, Negative Accuracy: 84.44%
# Epoch [349/500], Loss: 0.6325, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 64.44%
# Epoch [350/500], Loss: 0.6583, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 66.67%, Negative Accuracy: 66.67%
# Epoch [351/500], Loss: 0.6430, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 68.89%, Negative Accuracy: 73.33%
# Epoch [352/500], Loss: 0.6366, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [353/500], Loss: 0.6431, Avg Accuracy: 0.7,  Positive Accuracy: 71.11%, Negative Accuracy: 68.89%
# Epoch [354/500], Loss: 0.6344, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 66.67%
# Epoch [355/500], Loss: 0.6473, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 68.89%, Negative Accuracy: 80.00%
# Epoch [356/500], Loss: 0.6535, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 77.78%
# Epoch [357/500], Loss: 0.6354, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [358/500], Loss: 0.6473, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [359/500], Loss: 0.6395, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 75.56%
# Epoch [360/500], Loss: 0.6498, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 75.56%
# Epoch [361/500], Loss: 0.6437, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [362/500], Loss: 0.6532, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 64.44%
# Epoch [363/500], Loss: 0.6416, Avg Accuracy: 0.7,  Positive Accuracy: 71.11%, Negative Accuracy: 68.89%
# Epoch [364/500], Loss: 0.6386, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 75.56%, Negative Accuracy: 77.78%
# Epoch [365/500], Loss: 0.6336, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [366/500], Loss: 0.6355, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [367/500], Loss: 0.6432, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 71.11%, Negative Accuracy: 82.22%
# Epoch [368/500], Loss: 0.6514, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [369/500], Loss: 0.6365, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 86.67%
# Epoch [370/500], Loss: 0.6456, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 71.11%, Negative Accuracy: 82.22%
# Epoch [371/500], Loss: 0.6538, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 77.78%
# Epoch [372/500], Loss: 0.6422, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 75.56%, Negative Accuracy: 77.78%
# Epoch [373/500], Loss: 0.6431, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [374/500], Loss: 0.6416, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [375/500], Loss: 0.6299, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 75.56%, Negative Accuracy: 73.33%
# Epoch [376/500], Loss: 0.6507, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 71.11%, Negative Accuracy: 75.56%
# Epoch [377/500], Loss: 0.6460, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 75.56%, Negative Accuracy: 62.22%
# Epoch [378/500], Loss: 0.6409, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 66.67%
# Epoch [379/500], Loss: 0.6307, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 64.44%
# Epoch [380/500], Loss: 0.6466, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 66.67%
# Epoch [381/500], Loss: 0.6296, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 77.78%
# Epoch [382/500], Loss: 0.6369, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 73.33%, Negative Accuracy: 71.11%
# Epoch [383/500], Loss: 0.6234, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 66.67%
# Epoch [384/500], Loss: 0.6385, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 71.11%, Negative Accuracy: 75.56%
# Epoch [385/500], Loss: 0.6555, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 86.67%
# Epoch [386/500], Loss: 0.6391, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 75.56%, Negative Accuracy: 80.00%
# Epoch [387/500], Loss: 0.6430, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 68.89%, Negative Accuracy: 77.78%
# Epoch [388/500], Loss: 0.6461, Avg Accuracy: 0.7,  Positive Accuracy: 71.11%, Negative Accuracy: 68.89%
# Epoch [389/500], Loss: 0.6499, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 68.89%, Negative Accuracy: 77.78%
# Epoch [390/500], Loss: 0.6381, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 82.22%
# Epoch [391/500], Loss: 0.6370, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 66.67%, Negative Accuracy: 86.67%
# Epoch [392/500], Loss: 0.6343, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 68.89%, Negative Accuracy: 80.00%
# Epoch [393/500], Loss: 0.6400, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 68.89%, Negative Accuracy: 88.89%
# Epoch [394/500], Loss: 0.6386, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [395/500], Loss: 0.6364, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 73.33%, Negative Accuracy: 73.33%
# Epoch [396/500], Loss: 0.6525, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 75.56%, Negative Accuracy: 82.22%
# Epoch [397/500], Loss: 0.6254, Avg Accuracy: 0.8,  Positive Accuracy: 75.56%, Negative Accuracy: 84.44%
# Epoch [398/500], Loss: 0.6504, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 75.56%, Negative Accuracy: 75.56%
# Epoch [399/500], Loss: 0.6499, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 75.56%, Negative Accuracy: 77.78%
# Epoch [400/500], Loss: 0.6468, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 73.33%, Negative Accuracy: 84.44%
# Epoch [401/500], Loss: 0.6374, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [402/500], Loss: 0.6433, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 75.56%, Negative Accuracy: 66.67%
# Epoch [403/500], Loss: 0.6492, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 73.33%, Negative Accuracy: 82.22%
# Epoch [404/500], Loss: 0.6446, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 75.56%, Negative Accuracy: 77.78%
# Epoch [405/500], Loss: 0.6405, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 66.67%, Negative Accuracy: 84.44%
# Epoch [406/500], Loss: 0.6505, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 66.67%, Negative Accuracy: 88.89%
# Epoch [407/500], Loss: 0.6354, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [408/500], Loss: 0.6480, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [409/500], Loss: 0.6340, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 71.11%, Negative Accuracy: 82.22%
# Epoch [410/500], Loss: 0.6372, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 73.33%, Negative Accuracy: 75.56%
# Epoch [411/500], Loss: 0.6244, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [412/500], Loss: 0.6388, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [413/500], Loss: 0.6335, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [414/500], Loss: 0.6509, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [415/500], Loss: 0.6450, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 73.33%, Negative Accuracy: 73.33%
# Epoch [416/500], Loss: 0.6443, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 77.78%
# Epoch [417/500], Loss: 0.6459, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [418/500], Loss: 0.6338, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [419/500], Loss: 0.6507, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [420/500], Loss: 0.6395, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [421/500], Loss: 0.6292, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [422/500], Loss: 0.6456, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 75.56%
# Epoch [423/500], Loss: 0.6411, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 68.89%, Negative Accuracy: 64.44%
# Epoch [424/500], Loss: 0.6322, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [425/500], Loss: 0.6463, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 64.44%
# Epoch [426/500], Loss: 0.6387, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 71.11%, Negative Accuracy: 71.11%
# Epoch [427/500], Loss: 0.6379, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [428/500], Loss: 0.6491, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 73.33%, Negative Accuracy: 82.22%
# Epoch [429/500], Loss: 0.6336, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 66.67%, Negative Accuracy: 84.44%
# Epoch [430/500], Loss: 0.6254, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 66.67%, Negative Accuracy: 82.22%
# Epoch [431/500], Loss: 0.6487, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [432/500], Loss: 0.6409, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [433/500], Loss: 0.6354, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [434/500], Loss: 0.6371, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [435/500], Loss: 0.6329, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 68.89%, Negative Accuracy: 86.67%
# Epoch [436/500], Loss: 0.6305, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [437/500], Loss: 0.6197, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 71.11%, Negative Accuracy: 82.22%
# Epoch [438/500], Loss: 0.6433, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [439/500], Loss: 0.6439, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [440/500], Loss: 0.6478, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [441/500], Loss: 0.6407, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 86.67%
# Epoch [442/500], Loss: 0.6448, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 77.78%
# Epoch [443/500], Loss: 0.6386, Avg Accuracy: 0.8111111111111111,  Positive Accuracy: 77.78%, Negative Accuracy: 84.44%
# Epoch [444/500], Loss: 0.6249, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 71.11%, Negative Accuracy: 75.56%
# Epoch [445/500], Loss: 0.6531, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 73.33%, Negative Accuracy: 82.22%
# Epoch [446/500], Loss: 0.6474, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 73.33%, Negative Accuracy: 75.56%
# Epoch [447/500], Loss: 0.6423, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 73.33%, Negative Accuracy: 75.56%
# Epoch [448/500], Loss: 0.6474, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 75.56%, Negative Accuracy: 77.78%
# Epoch [449/500], Loss: 0.6368, Avg Accuracy: 0.8,  Positive Accuracy: 75.56%, Negative Accuracy: 84.44%
# Epoch [450/500], Loss: 0.6418, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 75.56%, Negative Accuracy: 77.78%
# Epoch [451/500], Loss: 0.6427, Avg Accuracy: 0.8111111111111111,  Positive Accuracy: 71.11%, Negative Accuracy: 91.11%
# Epoch [452/500], Loss: 0.6491, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 75.56%, Negative Accuracy: 80.00%
# Epoch [453/500], Loss: 0.6387, Avg Accuracy: 0.8111111111111111,  Positive Accuracy: 77.78%, Negative Accuracy: 84.44%
# Epoch [454/500], Loss: 0.6331, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 84.44%
# Epoch [455/500], Loss: 0.6343, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [456/500], Loss: 0.6231, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 75.56%, Negative Accuracy: 77.78%
# Epoch [457/500], Loss: 0.6268, Avg Accuracy: 0.8,  Positive Accuracy: 75.56%, Negative Accuracy: 84.44%
# Epoch [458/500], Loss: 0.6411, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 77.78%, Negative Accuracy: 80.00%
# Epoch [459/500], Loss: 0.6259, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 71.11%, Negative Accuracy: 75.56%
# Epoch [460/500], Loss: 0.6468, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 77.78%
# Epoch [461/500], Loss: 0.6404, Avg Accuracy: 0.8,  Positive Accuracy: 77.78%, Negative Accuracy: 82.22%
# Epoch [462/500], Loss: 0.6223, Avg Accuracy: 0.8,  Positive Accuracy: 75.56%, Negative Accuracy: 84.44%
# Epoch [463/500], Loss: 0.6452, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 86.67%
# Epoch [464/500], Loss: 0.6225, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 84.44%
# Epoch [465/500], Loss: 0.6334, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 84.44%
# Epoch [466/500], Loss: 0.6421, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 73.33%, Negative Accuracy: 82.22%
# Epoch [467/500], Loss: 0.6292, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 77.78%, Negative Accuracy: 80.00%
# Epoch [468/500], Loss: 0.6313, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 84.44%
# Epoch [469/500], Loss: 0.6260, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [470/500], Loss: 0.6423, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 84.44%
# Epoch [471/500], Loss: 0.6412, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 66.67%, Negative Accuracy: 88.89%
# Epoch [472/500], Loss: 0.6220, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 71.11%, Negative Accuracy: 75.56%
# Epoch [473/500], Loss: 0.6348, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 73.33%, Negative Accuracy: 75.56%
# Epoch [474/500], Loss: 0.6330, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 66.67%, Negative Accuracy: 91.11%
# Epoch [475/500], Loss: 0.6368, Avg Accuracy: 0.8,  Positive Accuracy: 71.11%, Negative Accuracy: 88.89%
# Epoch [476/500], Loss: 0.6173, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 84.44%
# Epoch [477/500], Loss: 0.6302, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [478/500], Loss: 0.6342, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 68.89%, Negative Accuracy: 86.67%
# Epoch [479/500], Loss: 0.6151, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 86.67%
# Epoch [480/500], Loss: 0.6414, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [481/500], Loss: 0.6395, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 82.22%
# Epoch [482/500], Loss: 0.6210, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 71.11%, Negative Accuracy: 73.33%
# Epoch [483/500], Loss: 0.6403, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 73.33%, Negative Accuracy: 80.00%
# Epoch [484/500], Loss: 0.6362, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 77.78%, Negative Accuracy: 75.56%
# Epoch [485/500], Loss: 0.6273, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 73.33%, Negative Accuracy: 77.78%
# Epoch [486/500], Loss: 0.6357, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 75.56%, Negative Accuracy: 75.56%
# Epoch [487/500], Loss: 0.6429, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 73.33%, Negative Accuracy: 84.44%
# Epoch [488/500], Loss: 0.6279, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 80.00%, Negative Accuracy: 77.78%
# Epoch [489/500], Loss: 0.6319, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 75.56%, Negative Accuracy: 73.33%
# Epoch [490/500], Loss: 0.6137, Avg Accuracy: 0.8,  Positive Accuracy: 73.33%, Negative Accuracy: 86.67%
# Epoch [491/500], Loss: 0.6423, Avg Accuracy: 0.8,  Positive Accuracy: 77.78%, Negative Accuracy: 82.22%
# Epoch [492/500], Loss: 0.6354, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 75.56%, Negative Accuracy: 60.00%
# Epoch [493/500], Loss: 0.6271, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 68.89%, Negative Accuracy: 86.67%
# Epoch [494/500], Loss: 0.6302, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 73.33%, Negative Accuracy: 84.44%
# Epoch [495/500], Loss: 0.6335, Avg Accuracy: 0.8,  Positive Accuracy: 77.78%, Negative Accuracy: 82.22%
# Epoch [496/500], Loss: 0.6299, Avg Accuracy: 0.7666666666666667,  Positive Accuracy: 71.11%, Negative Accuracy: 82.22%
# Epoch [497/500], Loss: 0.6373, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 75.56%, Negative Accuracy: 80.00%
# Epoch [498/500], Loss: 0.6257, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 73.33%, Negative Accuracy: 75.56%
# Epoch [499/500], Loss: 0.6367, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 80.00%
# Epoch [500/500], Loss: 0.6299, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 75.56%, Negative Accuracy: 82.22%

# %%
import glob
import glob
import numpy as np
import onnxruntime as ort

from collections import defaultdict

# %%
print(test_pos_dataset.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_LF', 'HRV_HF',
#        'HRV_VHF', 'HRV_TP', 'HRV_LFHF', 'HRV_LFn', 'HRV_HFn', 'HRV_LnHF',
#        'wave_quality', 'label', 'id', 'age', 'gender'],
#       dtype='object')

# %%
import enum


def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    # 如果找到的文件不为空
    if onnx_files:
        # 按文件名排序
        onnx_files.sort()

        # 选择最后一个文件
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    if onnx_files:
        onnx_files.sort()
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
ort_session = ort.InferenceSession(onnx_model_path)

# 预测函数
def predict(features):
    inputs = {ort_session.get_inputs()[0].name: features}
    outputs = ort_session.run(None, inputs)
    return outputs[0]

for idx, pair_data in enumerate([[test_neg_dataset, test_neg_features], [test_pos_dataset, test_pos_features]]):
    if idx == 0:
        print("\nTest for Negative subjects:")
    else:
        print("\nTest for Positive subjects:")

    # 加载测试数据集
    # 计算每个 subject 的准确率
    subject_results = defaultdict(list)

    for (_, row_dataset), (_, features), in zip(pair_data[0].iterrows(), pair_data[1].iterrows()):
        subject = row_dataset['id']
        label = row_dataset['label']

        features = np.array(features, dtype=np.float32)  # 确保 features 的数据类型与模型输入匹配
        features = features.reshape(1, -1)  # 调整形状以匹配模型输入
        prediction = predict(features)
        predicted_label = (prediction >= 0.5).astype(int)  # 使用阈值 0.5 将预测概率转换为类标签
        subject_results[subject].append((predicted_label, label))

    subject_accuracies = {}
    for subject, results in subject_results.items():
        correct = sum(1 for pred, label in results if pred == label)
        accuracy = correct / len(results)
        subject_accuracies[subject] = accuracy

    # 输出每个 subject 的准确度
    correct_count = 0
    for subject, accuracy in subject_accuracies.items():
        print(f'Subject: {subject}, Accuracy: {accuracy:.2f}')
        if accuracy > 0.5:
            correct_count += 1
        elif accuracy == 0.5:
            correct_count += 0.5
    print(f"subject accuracy: {(correct_count / len(subject_accuracies)):.2f}")
# Out:
# Test for Negative subjects:
# Subject: 15296f6a-42b1-9f4f-fdfe-4e6378685caa, Accuracy: 0.93
# Subject: 1b58cc46-381c-32d0-ce50-62e7fe37d869, Accuracy: 0.93
# Subject: f34fb6c0-c2f7-7367-3e25-d101c0605938, Accuracy: 0.36
# Subject: 6449e094-b088-e869-b145-fadb69a8b9b1, Accuracy: 0.80
# subject accuracy: 0.75
#
# Test for Positive subjects:
# Subject: eeb6a92b-0e23-7c08-c7ff-51c9fd87e0dc, Accuracy: 0.60
# Subject: cbfefb3c-08c5-6dc1-6d64-d68b849f9ed1, Accuracy: 0.20
# Subject: 97d91097-7e12-b9d6-778c-7f02c92a1851, Accuracy: 0.87
# Subject: bf102cd1-feed-4807-9ce7-d8bbfe9d0afd, Accuracy: 1.00
# Subject: b7b362c9-bf14-2276-e09a-fd18dd284230, Accuracy: 0.80
# Subject: 2a4bd1c8-888b-915b-d645-1ae939a492c5, Accuracy: 0.93
# Subject: 513195bb-f9b4-1d3d-6829-4cdf70008d23, Accuracy: 0.73
# subject accuracy: 0.86

# %% [markdown]
# # Testing Remaining Invalid and Unselected Valid Subjects
