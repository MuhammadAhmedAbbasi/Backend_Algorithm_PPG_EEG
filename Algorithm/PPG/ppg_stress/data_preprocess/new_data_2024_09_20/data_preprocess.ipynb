# %%
import datetime
import json
import os
import random
import sys
import warnings
import pandas as pd

sys.path.append(os.path.join(os.getcwd(), '../../../common'))
from ppg_feature_processor import generate_train_feature

# Suppress specific warnings
warnings.filterwarnings("ignore", category=DeprecationWarning, message=".*Conversion of an array with ndim > 0 to a scalar is deprecated.*")

# %%
# 读取 Excel 文件'
middleSchool_userProfile_file_new = r'C:\Users\Administrator\Desktop\Backend-Algorithm\Algorithm\PPG\ppg_depression\data_preprocess\new_data_2024_09_20\outdir\MiddleSchool_Depression_Anxiety.xlsx'
middleSchool_userProfile_file = r'C:\Users\Administrator\Desktop\Backend-Algorithm\Algorithm\PPG\ppg_depression\data_preprocess\outdir\MiddleSchool_Depression_Anxiety.xlsx'

# %%
stress_positive_threshold = 38
stress_negative_threshold = 32

# %%
### READ THE MIDDLESCHOOL SUBJECTS
df_middle = pd.read_excel(middleSchool_userProfile_file_new, sheet_name= 'PSS')
middle_pos_subjects = df_middle[df_middle['Stress_result']>=stress_positive_threshold]['subjectid'].values.tolist()
middle_neg_subjects = df_middle[df_middle['Stress_result']<=stress_negative_threshold]['subjectid'].values.tolist()

print(f"middle depression positive subjects count: {len(middle_pos_subjects)}")
print(f"middle depression negative subjects count: {len(middle_neg_subjects)}")
# Out:
# middle depression positive subjects count: 108
# middle depression negative subjects count: 89

# %%
old_stress_positive_threshold = 6
old_stress_negative_threshold = 5

# %%
### READ THE MIDDLESCHOOL SUBJECTS
old_df_middle = pd.read_excel(middleSchool_userProfile_file)
old_df_middle = old_df_middle[(old_df_middle['stress_sum'] > old_stress_positive_threshold) | (old_df_middle['stress_sum'] < old_stress_negative_threshold)]
print(f"Midlle schold available subject count: {old_df_middle.shape}")


old_middle_pos_subjects = old_df_middle[old_df_middle['stress_sum'] > old_stress_positive_threshold]['user_id'].values.tolist()
old_middle_neg_subjects = old_df_middle[old_df_middle['stress_sum'] < old_stress_negative_threshold]['user_id'].values.tolist()

print(f"middle stress positive subjects count: {len(old_middle_pos_subjects)}")
print(f"middle stress negative subjects count: {len(old_middle_neg_subjects)}")
# Out:
# Midlle schold available subject count: (349, 111)
# middle stress positive subjects count: 160
# middle stress negative subjects count: 189

# %%
profile_dict = dict()

for _, row in df_middle.iterrows():
    userId = row['subjectid']
    gender = row['gender']
    age = row['age']
    profile_dict[userId] = (gender, age)

for _, row in old_df_middle.iterrows():
    userId = row['user_id']
    gender = row['gender']
    age = 13
    profile_dict[userId] = (gender, age)

# %%
random.shuffle(middle_pos_subjects)
random.shuffle(middle_neg_subjects)

test_subject_count = 10

test_pos_subjects = middle_pos_subjects[0:test_subject_count]
test_neg_subjects = middle_neg_subjects[0:test_subject_count]

train_pos_subjects = old_middle_pos_subjects+ middle_pos_subjects[test_subject_count::] 
train_neg_subjects = old_middle_neg_subjects + middle_neg_subjects[test_subject_count::] 

print(f"train postive subjects: {len(train_pos_subjects)}")
print(f"train negative subjects: {len(train_neg_subjects)}")

print(f"test postive subjects: {len(test_pos_subjects)}")
print(f"test negative subjects: {len(test_neg_subjects)}")
# Out:
# train postive subjects: 258
# train negative subjects: 268
# test postive subjects: 10
# test negative subjects: 10

# %%
def load_wave_middleSchool(path):
    try:
        with open(path, 'r', encoding='utf-8') as file:  
            data = json.load(file)
        return data["ppg_raw_data"]
    except:
        print("Subject Not Loaded")
        pass


def old_load_wave_middleSchool(path):
    try:
        with open(path, 'r', encoding='utf-8') as file:  
            data = json.load(file)
            list_data = data['RawResults'][0]['rawDatas']
            final = [i/100000 for i in list_data]
        return final
    except (KeyError, IndexError, TypeError):
        with open(path, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return data["datas"]

# %%
sample_freq = 125
sample_window_minute = 1.0

middle_file_dir = r'C:\Users\Administrator\Desktop\middle_school_data\ppg_data'
old_middle_file_dir = r'C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data'

# %%
def generate_dataset(subject_collection, label, data_aug_times=1):
    ignored_id = []
    dataset = pd.DataFrame()
    for subject in subject_collection:
            subject_wave = []

            if subject in (middle_pos_subjects + middle_neg_subjects):
                files = os.listdir(middle_file_dir)
                for file in files:
                    if file.startswith(subject) and file.endswith('.json'):
                        file_path = os.path.join(middle_file_dir, file)
                        print(f"middle file path: {file_path}")
                        tmp_wave = load_wave_middleSchool(file_path)
                        subject_wave += tmp_wave
            elif subject in (old_middle_pos_subjects + old_middle_neg_subjects):
                files = os.listdir(old_middle_file_dir)
                for file in files:
                    if file.startswith(subject) and file.endswith('.json'):
                        file_path = os.path.join(old_middle_file_dir, file)
                        print(f"middle file path: {file_path}")
                        tmp_wave = old_load_wave_middleSchool(file_path)
                        subject_wave += tmp_wave
            
            if len(subject_wave) < (sample_freq * (sample_window_minute) * 60):
                print(f"Small time for subj: {subject} is: {len(subject_wave)/(sample_freq*60)}")
                ignored_id.append({'id': id, 'Time Length of data in minute ': f"{len(subject_wave)/(125 * 60):.02f}"})
                continue
            else:
                print(f"Recording time for subj: {subject} is: {len(subject_wave)/(sample_freq*60)}")
                subject_dataset = generate_train_feature(subject, subject_wave, label, profile_dict[subject][0], profile_dict[subject][1], sample_freq, sample_window_minute, data_aug_times, if_gender = True)
                dataset = pd.concat([dataset, subject_dataset], ignore_index=True)
    return dataset

# %%
train_pos_dataset = generate_dataset(train_pos_subjects, label=1, data_aug_times=1)
train_neg_dataset = generate_dataset(train_neg_subjects, label=0, data_aug_times=1)
# Out:
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\21667243296717534098247317258244048984.json
# Recording time for subj: 21667243296717534098247317258244048984 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\138681313570679646396533197328690174535.json
# Recording time for subj: 138681313570679646396533197328690174535 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\82498448730405369670702745834853438447.json
# Recording time for subj: 82498448730405369670702745834853438447 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\234663122709880533975616680634468445743.json
# Recording time for subj: 234663122709880533975616680634468445743 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\95409462719977513100021777459591360053.json
# Recording time for subj: 95409462719977513100021777459591360053 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\326175720451547606057536686016690581991.json
# Recording time for subj: 326175720451547606057536686016690581991 is: 1.9833333333333334
# Small time for subj: 5442445384831445465364876039121007542 is: 0.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\155974903198249598985226345893460192954.json
# Recording time for subj: 155974903198249598985226345893460192954 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\89015086248227340322450177808302591267.json
# Recording time for subj: 89015086248227340322450177808302591267 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\267367809881025707024976950419478664556.json
# Recording time for subj: 267367809881025707024976950419478664556 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\239647154274298628704040953626647006831.json
# Recording time for subj: 239647154274298628704040953626647006831 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\146292572288412702373476649337684468795.json
# Recording time for subj: 146292572288412702373476649337684468795 is: 4.866666666666666
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\235597310868064052825270017933329446492.json
# Recording time for subj: 235597310868064052825270017933329446492 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\137858228896762207131565170511894664167.json
# Recording time for subj: 137858228896762207131565170511894664167 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\305158848240269203442391029520371853323.json
# Recording time for subj: 305158848240269203442391029520371853323 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\280103981283984754605712413334189448713.json
# Recording time for subj: 280103981283984754605712413334189448713 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\180026746654759042090452315458916434701.json
# Recording time for subj: 180026746654759042090452315458916434701 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\204845103038116484980557716970136113388.json
# Recording time for subj: 204845103038116484980557716970136113388 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\97791393575067170943452115433796349604.json
# Recording time for subj: 97791393575067170943452115433796349604 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\212470578945876153547494938303382282800.json
# Recording time for subj: 212470578945876153547494938303382282800 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\206254331785533830049315502542703478728.json
# Small time for subj: 206254331785533830049315502542703478728 is: 0.9833333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\305915236564082705187365231974436613894.json
# Recording time for subj: 305915236564082705187365231974436613894 is: 1.0166666666666666
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\321272373820850313127332660512670140611.json
# Recording time for subj: 321272373820850313127332660512670140611 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\180354564963881481845914697843940257876.json
# Recording time for subj: 180354564963881481845914697843940257876 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\299049487973253671876447320174369050262.json
# Recording time for subj: 299049487973253671876447320174369050262 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\16612114337599212982788828505052133231.json
# Recording time for subj: 16612114337599212982788828505052133231 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\234997182067407201948214616328035260248.json
# Recording time for subj: 234997182067407201948214616328035260248 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\22701874826053748305968388566824125615.json
# Recording time for subj: 22701874826053748305968388566824125615 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\162688581511970890908978329266034445168.json
# Recording time for subj: 162688581511970890908978329266034445168 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\253236472362712351797769573369433989127.json
# Recording time for subj: 253236472362712351797769573369433989127 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\218573495288598613555322504618145813135.json
# Recording time for subj: 218573495288598613555322504618145813135 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\317331903178978258022589657654555103278.json
# Recording time for subj: 317331903178978258022589657654555103278 is: 1.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\34931901663861718465798076820184660214.json
# Recording time for subj: 34931901663861718465798076820184660214 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\71016560535034829410295386640763850032.json
# Recording time for subj: 71016560535034829410295386640763850032 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\223966184619010141064281599959431460852.json
# Recording time for subj: 223966184619010141064281599959431460852 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\310993511258890921358701613858346279508.json
# Recording time for subj: 310993511258890921358701613858346279508 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\36724560921116675115938466280858582222.json
# Recording time for subj: 36724560921116675115938466280858582222 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\8285329549026344726723545818313561637.json
# Recording time for subj: 8285329549026344726723545818313561637 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\112368478457110397448789952721833869236.json
# Recording time for subj: 112368478457110397448789952721833869236 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\273512605354803979690673146709274550290.json
# Recording time for subj: 273512605354803979690673146709274550290 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\156275748956021813065044996784968531790.json
# Recording time for subj: 156275748956021813065044996784968531790 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\49652182019910863950272610697424552312.json
# Recording time for subj: 49652182019910863950272610697424552312 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\121548899930842848751312663779363262996.json
# Recording time for subj: 121548899930842848751312663779363262996 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\84178952275838621849805119577871294912.json
# Recording time for subj: 84178952275838621849805119577871294912 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\50870569433662547424976446803687306459.json
# Recording time for subj: 50870569433662547424976446803687306459 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\16188876798564746412584684539374840092.json
# Recording time for subj: 16188876798564746412584684539374840092 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\257802955432590709965098427408431253033.json
# Recording time for subj: 257802955432590709965098427408431253033 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\122305803263178726728493960919715942514.json
# Recording time for subj: 122305803263178726728493960919715942514 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\119195583923612087416670680019846098656.json
# Recording time for subj: 119195583923612087416670680019846098656 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\322935917736529070732062674677811796298.json
# Recording time for subj: 322935917736529070732062674677811796298 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\37771404770360656757160133539357421144.json
# Recording time for subj: 37771404770360656757160133539357421144 is: 1.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\200638146859043915251450778310966476282.json
# Recording time for subj: 200638146859043915251450778310966476282 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\272644842981521865954601410341931323865.json
# Small time for subj: 272644842981521865954601410341931323865 is: 0.9833333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\283668670222861358895224925988118005202.json
# Recording time for subj: 283668670222861358895224925988118005202 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\52077102503621286583016980035109038061.json
# Recording time for subj: 52077102503621286583016980035109038061 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\48398204386767901130074413010766121894.json
# Small time for subj: 48398204386767901130074413010766121894 is: 0.9833333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\151752082913064155331664666692946928764.json
# Recording time for subj: 151752082913064155331664666692946928764 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\149145192076583502850914813099012728925.json
# Recording time for subj: 149145192076583502850914813099012728925 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\148595015854490470569560959720178473245.json
# Recording time for subj: 148595015854490470569560959720178473245 is: 1.9666666666666666
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\122241845394715518181387944797581832001.json
# Small time for subj: 122241845394715518181387944797581832001 is: 0.3333333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\163243854737138025263654164080563997272.json
# Recording time for subj: 163243854737138025263654164080563997272 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\333364077587273925240964493100427651900.json
# Recording time for subj: 333364077587273925240964493100427651900 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\68441290796842721766948350085075790448.json
# Recording time for subj: 68441290796842721766948350085075790448 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\197315460719593550396353596063872025641.json
# Recording time for subj: 197315460719593550396353596063872025641 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\333369095763755574065712150852028233455.json
# Recording time for subj: 333369095763755574065712150852028233455 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\166367831716388484489520561437010640306.json
# Recording time for subj: 166367831716388484489520561437010640306 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\114101291666208803023644507678911914760.json
# Recording time for subj: 114101291666208803023644507678911914760 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\279713686520327747703764314994584485312.json
# Recording time for subj: 279713686520327747703764314994584485312 is: 2.95
# Small time for subj: 258356333100981882183512624636763439898 is: 0.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\306877645633944670829341616314278123144.json
# Recording time for subj: 306877645633944670829341616314278123144 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\209451997226186821758748255081570927830.json
# Recording time for subj: 209451997226186821758748255081570927830 is: 2.95
# Small time for subj: 73237735215954021964510760233895308954 is: 0.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\99383412173966050321721355955917535141.json
# Recording time for subj: 99383412173966050321721355955917535141 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\319997953469040599793122241139270350702.json
# Recording time for subj: 319997953469040599793122241139270350702 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\38105743318352501687305527474372327912.json
# Recording time for subj: 38105743318352501687305527474372327912 is: 2.966666666666667
# Small time for subj: 202336982727307125405446245766360323930 is: 0.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\147286467279844571512642280185718562477.json
# Recording time for subj: 147286467279844571512642280185718562477 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\220412779112482284366202079009344459295.json
# Recording time for subj: 220412779112482284366202079009344459295 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\331113928004700519808917015039199286386.json
# Recording time for subj: 331113928004700519808917015039199286386 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\176116784174061127794093474409481059254.json
# Recording time for subj: 176116784174061127794093474409481059254 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\286764101343456992463975864443998370587.json
# Recording time for subj: 286764101343456992463975864443998370587 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\167778883336781991485772339526777662430.json
# Recording time for subj: 167778883336781991485772339526777662430 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\305168249340957441687910764346933734667.json
# Recording time for subj: 305168249340957441687910764346933734667 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\12840212086979211206628123494698476504.json
# Recording time for subj: 12840212086979211206628123494698476504 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\4081218792097645284953632200811961782.json
# Recording time for subj: 4081218792097645284953632200811961782 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\238900776150856601236907513542305529524.json
# Recording time for subj: 238900776150856601236907513542305529524 is: 1.9666666666666666
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\248745867043481860061400522592757429141.json
# Recording time for subj: 248745867043481860061400522592757429141 is: 2.933333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\143812828917731958874725791329349838013.json
# Recording time for subj: 143812828917731958874725791329349838013 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\237822312245693663368688006052242429787.json
# Recording time for subj: 237822312245693663368688006052242429787 is: 1.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\197445289474166971856388996004689014191.json
# Recording time for subj: 197445289474166971856388996004689014191 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\310218794756317037191347690470405405168.json
# Recording time for subj: 310218794756317037191347690470405405168 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\236294909131969157867605361878614042562.json
# Recording time for subj: 236294909131969157867605361878614042562 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\309464344667838927486340499999454792923.json
# Recording time for subj: 309464344667838927486340499999454792923 is: 2.933333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\317532430221552434669186273018041592902.json
# Recording time for subj: 317532430221552434669186273018041592902 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\339322724187443127112522868306539161010.json
# Recording time for subj: 339322724187443127112522868306539161010 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\244975779724248330107402013393276505462.json
# Recording time for subj: 244975779724248330107402013393276505462 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\141096633147123293564305683757951918737.json
# Recording time for subj: 141096633147123293564305683757951918737 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\68415645908804877552921659854931880952.json
# Recording time for subj: 68415645908804877552921659854931880952 is: 2.95
# Small time for subj: 94929086755618799457801167115527970170 is: 0.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\270887533756973472376441335892518057033.json
# Recording time for subj: 270887533756973472376441335892518057033 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\148639288212986584127354387481812660326.json
# Small time for subj: 148639288212986584127354387481812660326 is: 0.3
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\14586856609848013873913672393875766121.json
# Recording time for subj: 14586856609848013873913672393875766121 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\66883352438405515203389903841888282980.json
# Recording time for subj: 66883352438405515203389903841888282980 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\254321134067249714714878730482220789994.json
# Recording time for subj: 254321134067249714714878730482220789994 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\242056222106185540754324652621961959456.json
# Recording time for subj: 242056222106185540754324652621961959456 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\291817641151347512750847780043245117786.json
# Recording time for subj: 291817641151347512750847780043245117786 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\135896756116938088009570582069601649255.json
# Recording time for subj: 135896756116938088009570582069601649255 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\167813820591985297340393079467937834563.json
# Recording time for subj: 167813820591985297340393079467937834563 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\118401674357849734890478166825889992864.json
# Recording time for subj: 118401674357849734890478166825889992864 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\54859675454042600195622274479907726546.json
# Small time for subj: 54859675454042600195622274479907726546 is: 0.9833333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\221663728533701522053742739335557811585.json
# Recording time for subj: 221663728533701522053742739335557811585 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\141937329779245333917023400406363238989.json
# Recording time for subj: 141937329779245333917023400406363238989 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\188013775559290409209344422154340844028.json
# Recording time for subj: 188013775559290409209344422154340844028 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\59394480881392399544707620452359399697.json
# Recording time for subj: 59394480881392399544707620452359399697 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\316034713100539083740790895413161267739.json
# Recording time for subj: 316034713100539083740790895413161267739 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\216532202939989851211657144504314668637.json
# Recording time for subj: 216532202939989851211657144504314668637 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\146064041238557010788186948233088969104.json
# Recording time for subj: 146064041238557010788186948233088969104 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\61051594619193134343087204982766040895.json
# Recording time for subj: 61051594619193134343087204982766040895 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\53432263590786069539548595940834778143.json
# Recording time for subj: 53432263590786069539548595940834778143 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\152416903674534510578726275974630000963.json
# Recording time for subj: 152416903674534510578726275974630000963 is: 2.95
# Small time for subj: 331696711292762744729278407609265296683 is: 0.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\250494978444997270585647551622725992005.json
# Recording time for subj: 250494978444997270585647551622725992005 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\288968753257607227939769941103185695362.json
# Recording time for subj: 288968753257607227939769941103185695362 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\128323984464808208303504286338275258603.json
# Recording time for subj: 128323984464808208303504286338275258603 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\330708417614699062689789714196123612272.json
# Recording time for subj: 330708417614699062689789714196123612272 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\256949851016219061519144710517706888038.json
# Recording time for subj: 256949851016219061519144710517706888038 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\135652307618003958104306842765536111309.json
# Recording time for subj: 135652307618003958104306842765536111309 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\117079359035474074690365417557946048086.json
# Recording time for subj: 117079359035474074690365417557946048086 is: 3.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\304283173309091343875872021067570300854.json
# Recording time for subj: 304283173309091343875872021067570300854 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\322616964315554065624086560923948520823.json
# Recording time for subj: 322616964315554065624086560923948520823 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\306190386540638049114031574559895939729.json
# Recording time for subj: 306190386540638049114031574559895939729 is: 2.933333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\47155295106343825763989534008758209376.json
# Recording time for subj: 47155295106343825763989534008758209376 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\267828278527366910340979857914012054535.json
# Recording time for subj: 267828278527366910340979857914012054535 is: 2.9833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\244837623397725739033827989374034931563.json
# Recording time for subj: 244837623397725739033827989374034931563 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\130085639450041068004211156352139651905.json
# Recording time for subj: 130085639450041068004211156352139651905 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\170260898199865331516942901649175797899.json
# Recording time for subj: 170260898199865331516942901649175797899 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\24224661950343654525822317389000396758.json
# Recording time for subj: 24224661950343654525822317389000396758 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\18214877318401113801837311477727763289.json
# Recording time for subj: 18214877318401113801837311477727763289 is: 1.4833333333333334
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\82021857307461782491499562936350476465.json
# Recording time for subj: 82021857307461782491499562936350476465 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\147134295463639260896669462264244781096.json
# Recording time for subj: 147134295463639260896669462264244781096 is: 2.933333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\152232565392510054308847219623864287317.json
# Recording time for subj: 152232565392510054308847219623864287317 is: 3.033333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\291532865606838649685248811120276566576.json
# Recording time for subj: 291532865606838649685248811120276566576 is: 1.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\294885878575100370227534925114066149468.json
# Recording time for subj: 294885878575100370227534925114066149468 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\166982303707982007051928380408208812756.json
# Recording time for subj: 166982303707982007051928380408208812756 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\181111116088821967589334728562514270873.json
# Recording time for subj: 181111116088821967589334728562514270873 is: 5.780666666666667
# Small time for subj: 203861218384289679198792734130884546591 is: 0.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\260240317803029213106837561979534456162.json
# Recording time for subj: 260240317803029213106837561979534456162 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\287193774137046830846299820689671912262.json
# Recording time for subj: 287193774137046830846299820689671912262 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\16622918474073635031220652021682694945.json
# Recording time for subj: 16622918474073635031220652021682694945 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\59049209574526946105207528705266778097.json
# Recording time for subj: 59049209574526946105207528705266778097 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\209074174445323518467115471844887650404.json
# Recording time for subj: 209074174445323518467115471844887650404 is: 3.0166666666666666
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\122622512121837136229847012710705529979.json
# Small time for subj: 122622512121837136229847012710705529979 is: 0.9833333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\295048404300263447910443892159201485946.json
# Recording time for subj: 295048404300263447910443892159201485946 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\218793485769776969124501711306136315469.json
# Recording time for subj: 218793485769776969124501711306136315469 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\639172527045195363287108778219712510.json
# Recording time for subj: 639172527045195363287108778219712510 is: 2.933333333333333
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\113944072194837765400816116086180275264.json
# Recording time for subj: 113944072194837765400816116086180275264 is: 1.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\35301612054817462747500173124369716352.json
# Recording time for subj: 35301612054817462747500173124369716352 is: 2.966666666666667
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\111193710922326470738798863442907269378.json
# Recording time for subj: 111193710922326470738798863442907269378 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\23916555334375718433822687275242407999.json
# Recording time for subj: 23916555334375718433822687275242407999 is: 1.0
# middle file path: C:\Users\Administrator\Desktop\PPG_dataset\PPG_Dataset_ALL\middle_school\ppg_data\40646817068026815481891272868189762498.json
# Recording time for subj: 40646817068026815481891272868189762498 is: 2.95
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\0fda5bba-66bf-2899-6d3a-a19afc950122.json
# Recording time for subj: 0fda5bba-66bf-2899-6d3a-a19afc950122 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\07d7ac89-e84f-aa9a-b4ba-ae0bda191e57.json
# Recording time for subj: 07d7ac89-e84f-aa9a-b4ba-ae0bda191e57 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\c800db5b-29ad-7bd6-f7d8-d7c2c387022e.json
# Recording time for subj: c800db5b-29ad-7bd6-f7d8-d7c2c387022e is: 15.116666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\f1b5a636-2ab1-52de-df4b-648c041aaa19.json
# Recording time for subj: f1b5a636-2ab1-52de-df4b-648c041aaa19 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\fd7d9b8c-4574-1507-2226-212529e156dc.json
# Recording time for subj: fd7d9b8c-4574-1507-2226-212529e156dc is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\dcb646a8-a7b2-4493-5e97-b3df394fa9fc.json
# Recording time for subj: dcb646a8-a7b2-4493-5e97-b3df394fa9fc is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\99a8891e-67de-e941-e435-7c30c7faf658.json
# Recording time for subj: 99a8891e-67de-e941-e435-7c30c7faf658 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\00212fb4-0488-59a8-2688-5fe74ee77781.json
# Recording time for subj: 00212fb4-0488-59a8-2688-5fe74ee77781 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\d269758d-078b-c2d3-9996-1a54e129cba9.json
# Recording time for subj: d269758d-078b-c2d3-9996-1a54e129cba9 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\d3b21a2f-50d1-d623-3780-9250847f31a5.json
# Recording time for subj: d3b21a2f-50d1-d623-3780-9250847f31a5 is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\15ef5ac8-90d2-748d-a81a-e83f4c603443.json
# Recording time for subj: 15ef5ac8-90d2-748d-a81a-e83f4c603443 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\6ef52454-faae-1300-671f-5132b7b3e1f5.json
# Recording time for subj: 6ef52454-faae-1300-671f-5132b7b3e1f5 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\0e3e3efc-1b17-774d-a587-ca8e9f5a8090.json
# Recording time for subj: 0e3e3efc-1b17-774d-a587-ca8e9f5a8090 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\5e8f7bd2-6461-9dc1-9253-486769cdaaf5.json
# Recording time for subj: 5e8f7bd2-6461-9dc1-9253-486769cdaaf5 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\9851e2dc-9d2d-2019-583a-8521630dfc8d.json
# Recording time for subj: 9851e2dc-9d2d-2019-583a-8521630dfc8d is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\29a8784b-8752-4de0-579c-034c95044509.json
# Recording time for subj: 29a8784b-8752-4de0-579c-034c95044509 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\af4b7b1a-bf43-0f0d-3e5b-b8a762a430af.json
# Recording time for subj: af4b7b1a-bf43-0f0d-3e5b-b8a762a430af is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ac3eb6b4-483d-2613-f211-8b5b6152e6d0.json
# Recording time for subj: ac3eb6b4-483d-2613-f211-8b5b6152e6d0 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\c60d69be-472d-142c-f8b3-ec5d2779a7e2.json
# Recording time for subj: c60d69be-472d-142c-f8b3-ec5d2779a7e2 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\04a8fa82-4f32-d69c-72d9-8d82a472b803.json
# Recording time for subj: 04a8fa82-4f32-d69c-72d9-8d82a472b803 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\3489ea25-697c-25a0-fcc3-f84e913367f1.json
# Recording time for subj: 3489ea25-697c-25a0-fcc3-f84e913367f1 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\0f00efc4-65ef-cace-2e33-394ed0eaac10.json
# Recording time for subj: 0f00efc4-65ef-cace-2e33-394ed0eaac10 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\10e34531-3b8a-9200-615b-addabb8c5da1.json
# Recording time for subj: 10e34531-3b8a-9200-615b-addabb8c5da1 is: 15.2
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\2e1ee496-417c-a444-6c4a-733d6877983c.json
# Recording time for subj: 2e1ee496-417c-a444-6c4a-733d6877983c is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\c7f56e0c-1c40-c762-dd9d-c5bf12a69684.json
# Recording time for subj: c7f56e0c-1c40-c762-dd9d-c5bf12a69684 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\859959c0-bfb7-83a1-8594-5ae77ff3f3b4.json
# Recording time for subj: 859959c0-bfb7-83a1-8594-5ae77ff3f3b4 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\98f02bfa-e66c-a0d5-4e56-ce703f66989c.json
# Recording time for subj: 98f02bfa-e66c-a0d5-4e56-ce703f66989c is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\de2a72b6-f9df-29d8-58b7-f1462fdde466.json
# Small time for subj: de2a72b6-f9df-29d8-58b7-f1462fdde466 is: 0.65
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\850e5fd0-90a9-b081-8202-339998bb51cf.json
# Recording time for subj: 850e5fd0-90a9-b081-8202-339998bb51cf is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\3b28f19d-7fd1-5d93-8fae-b6eae8ca3b82.json
# Recording time for subj: 3b28f19d-7fd1-5d93-8fae-b6eae8ca3b82 is: 15.083333333333334
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\3a4d605d-c223-5f2f-b60d-0806dd71ffff.json
# Recording time for subj: 3a4d605d-c223-5f2f-b60d-0806dd71ffff is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\6b0f1873-9701-013f-6690-be179a444335.json
# Recording time for subj: 6b0f1873-9701-013f-6690-be179a444335 is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\eb658d47-4cab-b1f2-cd54-a6c3535ccd3b.json
# Recording time for subj: eb658d47-4cab-b1f2-cd54-a6c3535ccd3b is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\36c73f79-5f4d-1f15-6ae6-742529f3b18c.json
# Recording time for subj: 36c73f79-5f4d-1f15-6ae6-742529f3b18c is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\fce76679-d2f5-e038-696d-52fb72e55368.json
# Recording time for subj: fce76679-d2f5-e038-696d-52fb72e55368 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\3d874d9e-9a8e-9253-ec03-75e6fe138996.json
# Recording time for subj: 3d874d9e-9a8e-9253-ec03-75e6fe138996 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\2121ad4a-6621-530c-2a3d-cc49dfb50341.json
# Recording time for subj: 2121ad4a-6621-530c-2a3d-cc49dfb50341 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\646c24dd-defc-c76c-8445-50964793577c.json
# Recording time for subj: 646c24dd-defc-c76c-8445-50964793577c is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\03bde6e2-132a-717c-3a4e-a87ef66992f4.json
# Recording time for subj: 03bde6e2-132a-717c-3a4e-a87ef66992f4 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\816f33ed-55ea-1991-3c9f-185515a45099.json
# Recording time for subj: 816f33ed-55ea-1991-3c9f-185515a45099 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\f734890f-4e3a-c75d-4978-03f1ea48d841.json
# Recording time for subj: f734890f-4e3a-c75d-4978-03f1ea48d841 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ae10b469-3e20-eff1-eb09-80c4b720a422.json
# Recording time for subj: ae10b469-3e20-eff1-eb09-80c4b720a422 is: 15.083333333333334
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\9878443f-63d9-06a0-2314-c105d40cfbf0.json
# Recording time for subj: 9878443f-63d9-06a0-2314-c105d40cfbf0 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\3bd7c5d4-8402-103f-04d7-9b00d4e5ebba.json
# Recording time for subj: 3bd7c5d4-8402-103f-04d7-9b00d4e5ebba is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\380e2525-9fb4-e04a-f6e8-a5a134946973.json
# Recording time for subj: 380e2525-9fb4-e04a-f6e8-a5a134946973 is: 15.15
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\39d9b02d-2bc0-5e73-6733-5dbe4cf0b6f0.json
# Recording time for subj: 39d9b02d-2bc0-5e73-6733-5dbe4cf0b6f0 is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\204339b4-5e19-fc34-756c-672323422096.json
# Recording time for subj: 204339b4-5e19-fc34-756c-672323422096 is: 14.983333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\59d9f43d-b1cb-5c9e-82b2-e6f649c67f20.json
# Recording time for subj: 59d9f43d-b1cb-5c9e-82b2-e6f649c67f20 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\b93b3974-780d-3e7a-fa30-90f642df571d.json
# Recording time for subj: b93b3974-780d-3e7a-fa30-90f642df571d is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\48a96f87-7fc2-9aa9-bdbd-095bbb5c63ce.json
# Recording time for subj: 48a96f87-7fc2-9aa9-bdbd-095bbb5c63ce is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\f8651b9a-791a-5d89-baa8-5cb38ae5401b.json
# Recording time for subj: f8651b9a-791a-5d89-baa8-5cb38ae5401b is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\7480d1ea-2c43-2dfb-bc96-cc19f42892c8.json
# Recording time for subj: 7480d1ea-2c43-2dfb-bc96-cc19f42892c8 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\01a5e460-0607-38a6-b5ce-7f124b969222.json
# Recording time for subj: 01a5e460-0607-38a6-b5ce-7f124b969222 is: 15.166666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\9a34857c-2f52-99be-d371-af9a8244b656.json
# Recording time for subj: 9a34857c-2f52-99be-d371-af9a8244b656 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\80bec611-b0eb-4cd5-24e9-2acc1056da1a.json
# Recording time for subj: 80bec611-b0eb-4cd5-24e9-2acc1056da1a is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\eeb255b5-6a3d-0f9f-2f96-7f14b74472a4.json
# Recording time for subj: eeb255b5-6a3d-0f9f-2f96-7f14b74472a4 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\2f8a7e09-3897-4161-d964-13f9736e20aa.json
# Recording time for subj: 2f8a7e09-3897-4161-d964-13f9736e20aa is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\217fc97f-6078-0c93-dfa3-2ed780cd9195.json
# Recording time for subj: 217fc97f-6078-0c93-dfa3-2ed780cd9195 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\f9b743a8-3d70-e8e9-7af8-6e1cb5d66567.json
# Recording time for subj: f9b743a8-3d70-e8e9-7af8-6e1cb5d66567 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ab8776fd-efa8-3699-3a78-a7804e86db17.json
# Small time for subj: ab8776fd-efa8-3699-3a78-a7804e86db17 is: 0.6333333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\9a909ffc-d13e-c38f-e866-f814defcbfda.json
# Recording time for subj: 9a909ffc-d13e-c38f-e866-f814defcbfda is: 15.116666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\636bcbaf-43d6-7c8d-4864-417c3a9da5d2.json
# Recording time for subj: 636bcbaf-43d6-7c8d-4864-417c3a9da5d2 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\a793eaaf-fd17-2821-5e37-0ca88a71d1dc.json
# Recording time for subj: a793eaaf-fd17-2821-5e37-0ca88a71d1dc is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\2f85291e-eddb-0e86-7fe1-e5de9509cad4.json
# Recording time for subj: 2f85291e-eddb-0e86-7fe1-e5de9509cad4 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\e8adb307-edb2-b49a-573f-0a867aac4685.json
# Recording time for subj: e8adb307-edb2-b49a-573f-0a867aac4685 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ef002460-af1e-0ae6-323b-20d8dd8dc250.json
# ...
# Small time for subj: 66493837108231661395780815354402692759 is: 0.3
# Small time for subj: 216826399861443189739529122506289574411 is: 0.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\c9f6bffc-451c-2f44-b658-d1e15dac902f.json
# Recording time for subj: c9f6bffc-451c-2f44-b658-d1e15dac902f is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\568530e1-56cc-baea-3128-1b4ee0cc633c.json
# Recording time for subj: 568530e1-56cc-baea-3128-1b4ee0cc633c is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\3a510cc6-362b-8eba-7449-439c5a8d5f4c.json
# Recording time for subj: 3a510cc6-362b-8eba-7449-439c5a8d5f4c is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\8ee348e4-45c8-a3b3-9b30-c0fb2ac25c92.json
# Recording time for subj: 8ee348e4-45c8-a3b3-9b30-c0fb2ac25c92 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\a94e4393-384c-3a99-3c14-c23e608dd4c7.json
# Recording time for subj: a94e4393-384c-3a99-3c14-c23e608dd4c7 is: 15.083333333333334
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\6d879db2-4a18-1839-ca0d-dfb7a5f77f54.json
# Recording time for subj: 6d879db2-4a18-1839-ca0d-dfb7a5f77f54 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\484f8abd-08c7-84a5-f6b2-bbfda13e048d.json
# Recording time for subj: 484f8abd-08c7-84a5-f6b2-bbfda13e048d is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\4cc407e4-9771-02b6-cfd0-fc847ce6ba05.json
# Recording time for subj: 4cc407e4-9771-02b6-cfd0-fc847ce6ba05 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\48954108-6a28-64cd-2585-ce708fa6e2be.json
# Recording time for subj: 48954108-6a28-64cd-2585-ce708fa6e2be is: 15.133333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\25342799-aff8-b14a-81eb-940a97ce65a7.json
# Recording time for subj: 25342799-aff8-b14a-81eb-940a97ce65a7 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\9117b180-bb29-bc58-88e9-322eb807e296.json
# Recording time for subj: 9117b180-bb29-bc58-88e9-322eb807e296 is: 14.983333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\b1258f68-6daa-4474-ee4d-2992522fe41e.json
# Recording time for subj: b1258f68-6daa-4474-ee4d-2992522fe41e is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\0feb0f39-532d-2486-1f6b-2f8c0d70b24f.json
# Recording time for subj: 0feb0f39-532d-2486-1f6b-2f8c0d70b24f is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\cc6f3bff-1806-8048-3823-201a5ab6471b.json
# Recording time for subj: cc6f3bff-1806-8048-3823-201a5ab6471b is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\41bdce27-e22c-0695-bd6d-201562589a47.json
# Recording time for subj: 41bdce27-e22c-0695-bd6d-201562589a47 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\f8fd9136-63dc-cceb-e257-42abcdabd431.json
# Recording time for subj: f8fd9136-63dc-cceb-e257-42abcdabd431 is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\656a70d6-19d6-6b30-75e5-68718c502fac.json
# Recording time for subj: 656a70d6-19d6-6b30-75e5-68718c502fac is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\e308825b-1e12-18f9-fa00-0d2c2e5f60ca.json
# Recording time for subj: e308825b-1e12-18f9-fa00-0d2c2e5f60ca is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\173a36c1-be35-88f5-58ae-bca37ddb956b.json
# Recording time for subj: 173a36c1-be35-88f5-58ae-bca37ddb956b is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\22a0c441-5fad-ca2e-fe55-f667f0064b54.json
# Recording time for subj: 22a0c441-5fad-ca2e-fe55-f667f0064b54 is: 14.983333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\de72d4fb-812e-92b2-e268-b1d5b816ce56.json
# Recording time for subj: de72d4fb-812e-92b2-e268-b1d5b816ce56 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\83e7f95d-0e2f-48e9-a99d-9277b3ca32a8.json
# Recording time for subj: 83e7f95d-0e2f-48e9-a99d-9277b3ca32a8 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\e144aa5e-bb1a-ee2e-4873-69dd9d71e4a4.json
# Recording time for subj: e144aa5e-bb1a-ee2e-4873-69dd9d71e4a4 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\39b695f2-2cdd-ce5b-709a-a263cb8f9b34.json
# Recording time for subj: 39b695f2-2cdd-ce5b-709a-a263cb8f9b34 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ed618de8-8bb3-e16f-e4a3-1305e5f13a63.json
# Recording time for subj: ed618de8-8bb3-e16f-e4a3-1305e5f13a63 is: 15.116666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\2bfcb885-677a-b5c8-b434-fb02b9767fd8.json
# Recording time for subj: 2bfcb885-677a-b5c8-b434-fb02b9767fd8 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ef736c08-6674-93c3-ba4b-c741a89b28e0.json
# Recording time for subj: ef736c08-6674-93c3-ba4b-c741a89b28e0 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\d64ac85e-e810-285c-e61e-f7c74853ade6.json
# Recording time for subj: d64ac85e-e810-285c-e61e-f7c74853ade6 is: 15.116666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\064be51e-f7c6-e196-7c30-57fe14950331.json
# Recording time for subj: 064be51e-f7c6-e196-7c30-57fe14950331 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\3db4ec78-0911-4334-3789-bfd1feee8d66.json
# Recording time for subj: 3db4ec78-0911-4334-3789-bfd1feee8d66 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\bb2eaaba-1b05-bf28-3bd6-7c76fa5fd943.json
# Recording time for subj: bb2eaaba-1b05-bf28-3bd6-7c76fa5fd943 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\a3f39dac-711d-cbee-1d09-e8d2019fa3d5.json
# Recording time for subj: a3f39dac-711d-cbee-1d09-e8d2019fa3d5 is: 15.116666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\8398e116-d28c-ec20-cacb-efb9a5b09a1b.json
# Recording time for subj: 8398e116-d28c-ec20-cacb-efb9a5b09a1b is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\695153b8-cd54-28f7-5e2d-b43ef7a12347.json
# Recording time for subj: 695153b8-cd54-28f7-5e2d-b43ef7a12347 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\127d9913-29a2-25ff-d123-27423c776fd9.json
# Recording time for subj: 127d9913-29a2-25ff-d123-27423c776fd9 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\18b635c1-39d5-0965-112e-4e75acd82941.json
# Recording time for subj: 18b635c1-39d5-0965-112e-4e75acd82941 is: 15.233333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\b4cf31c5-df7a-075e-5459-a0afc90c538a.json
# Recording time for subj: b4cf31c5-df7a-075e-5459-a0afc90c538a is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\89fba810-86a9-0d86-4136-64638dd2122b.json
# Small time for subj: 89fba810-86a9-0d86-4136-64638dd2122b is: 0.6333333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\163f49e3-4026-e051-efaf-e91b9f15dc95.json
# Recording time for subj: 163f49e3-4026-e051-efaf-e91b9f15dc95 is: 15.116666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\f5dc6d57-2bc0-5c2b-3a42-2d74a826ea86.json
# Recording time for subj: f5dc6d57-2bc0-5c2b-3a42-2d74a826ea86 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\5d9a6588-b345-3ad6-b623-1fde4b1f279b.json
# Recording time for subj: 5d9a6588-b345-3ad6-b623-1fde4b1f279b is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\6bbd5adf-45b1-e6a6-606b-247b9b6ab5cf.json
# Recording time for subj: 6bbd5adf-45b1-e6a6-606b-247b9b6ab5cf is: 15.15
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\92145824-ff7e-be24-e815-a64e899f38e1.json
# Recording time for subj: 92145824-ff7e-be24-e815-a64e899f38e1 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\0cf44683-dda2-b7fb-5d13-9151df4db1c5.json
# Recording time for subj: 0cf44683-dda2-b7fb-5d13-9151df4db1c5 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\16f903f0-8aeb-5af4-79ba-04e74bd5248b.json
# Recording time for subj: 16f903f0-8aeb-5af4-79ba-04e74bd5248b is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\aac4b9a5-fdeb-35e3-fdad-2ffc149681f6.json
# Recording time for subj: aac4b9a5-fdeb-35e3-fdad-2ffc149681f6 is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\a1276cea-f175-a713-48ae-75b4180e1631.json
# Recording time for subj: a1276cea-f175-a713-48ae-75b4180e1631 is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\d2adc252-fd1e-659a-5b27-37327b37c4a4.json
# Recording time for subj: d2adc252-fd1e-659a-5b27-37327b37c4a4 is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\615eaee0-07c9-9607-3af5-e9365609a515.json
# Recording time for subj: 615eaee0-07c9-9607-3af5-e9365609a515 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\2a025ced-fe59-a4b3-0cf5-77689e20dc56.json
# Recording time for subj: 2a025ced-fe59-a4b3-0cf5-77689e20dc56 is: 14.983333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\2732c252-46a6-fe82-6341-1a2a43f8d657.json
# Small time for subj: 2732c252-46a6-fe82-6341-1a2a43f8d657 is: 0.65
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\a4993294-3529-e653-3177-ce307357ea08.json
# Recording time for subj: a4993294-3529-e653-3177-ce307357ea08 is: 15.316666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\13fbbc43-d58e-8115-1e69-0ab5503eb1f5.json
# Recording time for subj: 13fbbc43-d58e-8115-1e69-0ab5503eb1f5 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\94fadafd-52cc-6a16-6528-473ff8e9d033.json
# Recording time for subj: 94fadafd-52cc-6a16-6528-473ff8e9d033 is: 15.116666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\eadb5607-8809-4eda-b570-20ce6422fe19.json
# Recording time for subj: eadb5607-8809-4eda-b570-20ce6422fe19 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\d6c0396b-1139-4395-446d-54dc25203921.json
# Recording time for subj: d6c0396b-1139-4395-446d-54dc25203921 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\cc472b11-54b5-5785-27d0-6b5ee4c644cf.json
# Recording time for subj: cc472b11-54b5-5785-27d0-6b5ee4c644cf is: 15.116666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ac0cde67-f643-22c6-0e97-b910b70dfce9.json
# Recording time for subj: ac0cde67-f643-22c6-0e97-b910b70dfce9 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\519f7bf1-6ddf-4014-2caf-5e0ca8356316.json
# Recording time for subj: 519f7bf1-6ddf-4014-2caf-5e0ca8356316 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\401e20a5-0b27-1e4b-c53f-014797f0df59.json
# Recording time for subj: 401e20a5-0b27-1e4b-c53f-014797f0df59 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\c35d0097-5810-67c4-7c8e-72e8673f0bdc.json
# Recording time for subj: c35d0097-5810-67c4-7c8e-72e8673f0bdc is: 15.15
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\e775fef5-8005-4574-8dbc-9779f5fd78fd.json
# Recording time for subj: e775fef5-8005-4574-8dbc-9779f5fd78fd is: 15.116666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ed718921-8bc0-71f8-c9bb-8ce3ee322ee3.json
# Recording time for subj: ed718921-8bc0-71f8-c9bb-8ce3ee322ee3 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\38d47811-cff4-9965-fce9-facf4a613c60.json
# Recording time for subj: 38d47811-cff4-9965-fce9-facf4a613c60 is: 15.083333333333334
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\15734937-3410-57f6-3cc3-d1d32e9138c5.json
# Recording time for subj: 15734937-3410-57f6-3cc3-d1d32e9138c5 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\6132385d-1e83-d01e-8407-5cd748afab5c.json
# Recording time for subj: 6132385d-1e83-d01e-8407-5cd748afab5c is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\c831132a-79ed-6676-ad6c-811e7d40789c.json
# Recording time for subj: c831132a-79ed-6676-ad6c-811e7d40789c is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\73ad61cb-2c13-f505-c171-605e5b7eb722.json
# Recording time for subj: 73ad61cb-2c13-f505-c171-605e5b7eb722 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\5637365c-5c44-f98a-5384-c14f9a6a1e82.json
# Recording time for subj: 5637365c-5c44-f98a-5384-c14f9a6a1e82 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ee2ffda0-b7df-d854-7b31-d2e714196949.json
# Small time for subj: ee2ffda0-b7df-d854-7b31-d2e714196949 is: 0.6333333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\3ffaad51-9acf-5518-d769-7e9e88fcb864.json
# Recording time for subj: 3ffaad51-9acf-5518-d769-7e9e88fcb864 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ab1797e6-299c-cad7-31ce-b06cd86d7580.json
# Small time for subj: ab1797e6-299c-cad7-31ce-b06cd86d7580 is: 0.6166666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\ab6d10d7-2245-d3af-a1d7-f6d182d3131b.json
# Recording time for subj: ab6d10d7-2245-d3af-a1d7-f6d182d3131b is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\2cee9fb6-e907-59ef-d44e-c3c6cf2aa5b2.json
# Recording time for subj: 2cee9fb6-e907-59ef-d44e-c3c6cf2aa5b2 is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\a3bb10b9-2ac2-ecf1-a40d-4cec92f0a2c9.json
# Recording time for subj: a3bb10b9-2ac2-ecf1-a40d-4cec92f0a2c9 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\96976cbd-d5f3-ef86-34a5-347415e41e78.json
# Recording time for subj: 96976cbd-d5f3-ef86-34a5-347415e41e78 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\9394b150-8097-4249-46c4-0e430b348d73.json
# Recording time for subj: 9394b150-8097-4249-46c4-0e430b348d73 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\afdb37c1-120c-eca1-f767-866485073f77.json
# Recording time for subj: afdb37c1-120c-eca1-f767-866485073f77 is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\fed9c748-0ecd-6c7e-f104-e05d74ba1488.json
# Recording time for subj: fed9c748-0ecd-6c7e-f104-e05d74ba1488 is: 15.033333333333333

# %%
test_pos_dataset = generate_dataset(test_pos_subjects, label=1, data_aug_times=1)
test_neg_dataset = generate_dataset(test_neg_subjects, label=0, data_aug_times=1)
# Out:
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\dc7e8552-e3c4-4695-379c-10e144338a4b.json
# Recording time for subj: dc7e8552-e3c4-4695-379c-10e144338a4b is: 15.1
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\16a823bf-b6b5-6690-6969-bcd7f441c044.json
# Recording time for subj: 16a823bf-b6b5-6690-6969-bcd7f441c044 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\915b5d62-9bb0-655d-c013-8c84c3e98c87.json
# Recording time for subj: 915b5d62-9bb0-655d-c013-8c84c3e98c87 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\eeb6a92b-0e23-7c08-c7ff-51c9fd87e0dc.json
# Recording time for subj: eeb6a92b-0e23-7c08-c7ff-51c9fd87e0dc is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\cbfefb3c-08c5-6dc1-6d64-d68b849f9ed1.json
# Recording time for subj: cbfefb3c-08c5-6dc1-6d64-d68b849f9ed1 is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\97d91097-7e12-b9d6-778c-7f02c92a1851.json
# Recording time for subj: 97d91097-7e12-b9d6-778c-7f02c92a1851 is: 15.1
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\bf102cd1-feed-4807-9ce7-d8bbfe9d0afd.json
# Recording time for subj: bf102cd1-feed-4807-9ce7-d8bbfe9d0afd is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\b7b362c9-bf14-2276-e09a-fd18dd284230.json
# Recording time for subj: b7b362c9-bf14-2276-e09a-fd18dd284230 is: 15.033333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\2a4bd1c8-888b-915b-d645-1ae939a492c5.json
# Recording time for subj: 2a4bd1c8-888b-915b-d645-1ae939a492c5 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\513195bb-f9b4-1d3d-6829-4cdf70008d23.json
# Recording time for subj: 513195bb-f9b4-1d3d-6829-4cdf70008d23 is: 15.066666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\3534febe-86c1-f2e5-faf4-86b8dd027e56.json
# Recording time for subj: 3534febe-86c1-f2e5-faf4-86b8dd027e56 is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\e1f563f8-90bf-4b92-be94-b2ebff83a52d.json
# Recording time for subj: e1f563f8-90bf-4b92-be94-b2ebff83a52d is: 15.05
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\47d95a32-8afc-d476-16e8-5eea642afb1f.json
# Recording time for subj: 47d95a32-8afc-d476-16e8-5eea642afb1f is: 15.016666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\8dedcad7-073e-1c07-bfc8-41624aea3d11.json
# Small time for subj: 8dedcad7-073e-1c07-bfc8-41624aea3d11 is: 0.16666666666666666
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\0ba4d45e-1f39-aaa1-b2ce-0fefcd5c56ea.json
# Small time for subj: 0ba4d45e-1f39-aaa1-b2ce-0fefcd5c56ea is: 0.6333333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\15296f6a-42b1-9f4f-fdfe-4e6378685caa.json
# Recording time for subj: 15296f6a-42b1-9f4f-fdfe-4e6378685caa is: 15.1
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\1b58cc46-381c-32d0-ce50-62e7fe37d869.json
# Recording time for subj: 1b58cc46-381c-32d0-ce50-62e7fe37d869 is: 15.0
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\f34fb6c0-c2f7-7367-3e25-d101c0605938.json
# Recording time for subj: f34fb6c0-c2f7-7367-3e25-d101c0605938 is: 14.966666666666667
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\03f5022c-656d-e4c2-6cdd-2248276f0f41.json
# Small time for subj: 03f5022c-656d-e4c2-6cdd-2248276f0f41 is: 0.6333333333333333
# middle file path: C:\Users\Administrator\Desktop\middle_school_data\ppg_data\6449e094-b088-e869-b145-fadb69a8b9b1.json
# Recording time for subj: 6449e094-b088-e869-b145-fadb69a8b9b1 is: 15.133333333333333

# %%
def selecting_specific_time(dataset, time = 5):
    final_dataset = pd.DataFrame()
    subject_names =  (dataset['id'].unique()).tolist()
    for sub_name in subject_names:
        sub_data = dataset[dataset['id'] ==  sub_name].sample(time, ignore_index = True)
        final_dataset = pd.concat([final_dataset, sub_data], ignore_index = True)
    return final_dataset

# %%
# test_neg_dataset = selecting_specific_time(test_neg_dataset)
# test_pos_dataset = selecting_specific_time(test_pos_dataset)

# %%
print(f"train pos sample shape: {train_pos_dataset.shape}")
print(f"train neg sample shape: {train_neg_dataset.shape}")

print(f"test pos sample shape: {test_neg_dataset.shape}")
print(f"test neg sample shape: {test_pos_dataset.shape}")
# Out:
# train pos sample shape: (1666, 40)
# train neg sample shape: (1461, 40)
# test pos sample shape: (104, 40)
# test neg sample shape: (150, 40)

# %%
columns_drop = []
for col in train_pos_dataset.columns[:-4]:
    nan_count = (train_pos_dataset[col] == 0).sum() 
    if nan_count > (len(train_pos_dataset) // 4): 
        columns_drop.append(col)

train_pos_dataset_final = train_pos_dataset.drop(columns=columns_drop, inplace=False)
train_neg_dataset_final = train_neg_dataset.drop(columns=columns_drop, inplace=False)

test_pos_dataset_final = test_pos_dataset.drop(columns=columns_drop, inplace=False)
test_neg_dataset_final = test_neg_dataset.drop(columns=columns_drop, inplace=False)

# %%
print(f"After remove the invalid columns, train pos shape: {train_pos_dataset_final.shape}")
print(f"After remove the invalid columns, train neg shape: {train_neg_dataset_final.shape}")

print(f"After remove the invalid columns, test pos shape: {test_pos_dataset_final.shape}")
print(f"After remove the invalid columns, test neg shape: {test_neg_dataset_final.shape}")
# Out:
# After remove the invalid columns, train pos shape: (1666, 32)
# After remove the invalid columns, train neg shape: (1461, 32)
# After remove the invalid columns, test pos shape: (150, 32)
# After remove the invalid columns, test neg shape: (104, 32)

# %% [markdown]
# #### Do The Normalization for the Train Dataset and Test Dataset

# %%
profile_columns = ['wave_quality', 'age', 'gender', 'label', 'id']

# %%
# 合并训练集
train_combined = pd.concat([train_pos_dataset_final, train_neg_dataset_final])

# 需要归一化的列
columns_to_normalize = train_combined.columns.difference(profile_columns)

# 计算最大值和最小值
min_values = train_combined[columns_to_normalize].min()
max_values = train_combined[columns_to_normalize].max()

# 保存最大值和最小值到CSV
current_date = datetime.datetime.now().strftime("%Y-%m-%d")
outdir = os.path.join(os.getcwd(), 'outdir')
os.makedirs(outdir, exist_ok=True)
min_max_df = pd.DataFrame({'min': min_values, 'max': max_values})
min_max_df.to_csv(f'{outdir}/ppg_depression_norm_minmax_values_{current_date}.csv', index=True)


# 定义min-max归一化函数
def normalize(df, min_values, max_values):
    return (df - min_values) / (max_values - min_values)

# 对训练集进行归一化
train_pos_dataset_final[columns_to_normalize] = normalize(train_pos_dataset_final[columns_to_normalize], min_values, max_values)
train_neg_dataset_final[columns_to_normalize] = normalize(train_neg_dataset_final[columns_to_normalize], min_values, max_values)

# 从CSV文件中读取最小值和最大值
min_max_df = pd.read_csv(f'{outdir}/ppg_depression_norm_minmax_values_{current_date}.csv', index_col=0)
min_values = min_max_df['min']
max_values = min_max_df['max']

# 对测试集进行归一化
test_pos_dataset_final[columns_to_normalize] = normalize(test_pos_dataset_final[columns_to_normalize], min_values, max_values)
test_neg_dataset_final[columns_to_normalize] = normalize(test_neg_dataset_final[columns_to_normalize], min_values, max_values)

# %% [markdown]
# #### Save As Pkl File

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import figure

plt.subplot(3, 1, 1)  # 1行2列，第1个子图
sns.histplot(train_pos_dataset['wave_quality'], kde=True, bins=10)
plt.show()

plt.subplot(3, 1, 2)  # 1行2列，第1个子图
sns.histplot(train_neg_dataset['wave_quality'], kde=True, bins=10)
plt.show()

plt.subplot(3, 1, 3)  # 1行2列，第1个子图
sns.histplot(train_combined['wave_quality'], kde=True, bins=10)
# Out:
# <Axes: xlabel='wave_quality', ylabel='Count'>

# %%
wave_quality_threshold = 0.8

# %%
print(f"train pos sample shape: {train_pos_dataset.shape}")
print(f"train neg sample shape: {train_neg_dataset.shape}")

print(f"test pos sample shape: {test_neg_dataset.shape}")
print(f"test neg sample shape: {test_pos_dataset.shape}")
# Out:
# train pos sample shape: (1666, 40)
# train neg sample shape: (1461, 40)
# test pos sample shape: (104, 40)
# test neg sample shape: (150, 40)

# %%
train_pos_dataset_final_filter = train_pos_dataset_final[train_pos_dataset_final['wave_quality'] >= wave_quality_threshold]
train_neg_dataset_final_filter = train_neg_dataset_final[train_neg_dataset_final['wave_quality'] >= wave_quality_threshold]

print(f"After quality filter, train positive sample count: {train_pos_dataset_final_filter.shape[0]}")
print(f"After quality filter, train negative sample count: {train_neg_dataset_final_filter.shape[0]}")
# Out:
# After quality filter, train positive sample count: 1428
# After quality filter, train negative sample count: 1219

# %%
sample_folder = os.path.join(os.getcwd(), 'samples')
os.makedirs(sample_folder, exist_ok=True)

# 定义要保存的文件路径
train_pos_path = os.path.join(sample_folder, 'train_pos_dataset.pkl')
train_neg_path = os.path.join(sample_folder, 'train_neg_dataset.pkl')
test_pos_path = os.path.join(sample_folder, 'test_pos_dataset.pkl')
test_neg_path = os.path.join(sample_folder, 'test_neg_dataset.pkl')

# 保存 DataFrame 为 .pkl 文件
train_pos_dataset_final[train_pos_dataset_final['wave_quality'] >= wave_quality_threshold].to_pickle(train_pos_path)
train_neg_dataset_final[train_neg_dataset_final['wave_quality'] >= wave_quality_threshold].to_pickle(train_neg_path)
test_pos_dataset_final.to_pickle(test_pos_path)
test_neg_dataset_final.to_pickle(test_neg_path)

# %%
print(train_pos_dataset_final.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_LF', 'HRV_HF',
#        'HRV_VHF', 'HRV_TP', 'HRV_LFHF', 'HRV_LFn', 'HRV_HFn', 'HRV_LnHF',
#        'wave_quality', 'label', 'id', 'age', 'gender'],
#       dtype='object')
