# %%
import os
import pandas as pd
import sys
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from datetime import datetime
from torch.utils.data import Dataset, DataLoader

sys.path.append(os.path.join(os.getcwd(), '../../../common'))
from ppg_feature_processor import map_gender, map_age

# %%
# 获取当前日期
current_date = datetime.now().strftime("%Y-%m-%d")
# 构建导出的pth文件名以及ONNX文件名
outdir = 'outdir'
pth_file_path = os.path.join(outdir, f'ppg_depression-best_model_{current_date}.pth')
onnx_file_path = os.path.join(outdir, f"ppg_depression-best_model_{current_date}.onnx")

# %%
profile_columns = ['wave_quality', 'age', 'gender', 'label', 'id']

# %%
# 加载数据
train_pos_dataset = pd.read_pickle('./samples/train_pos_dataset.pkl')
train_neg_dataset = pd.read_pickle('./samples/train_neg_dataset.pkl')
test_pos_dataset = pd.read_pickle('./samples/test_pos_dataset.pkl')
test_neg_dataset = pd.read_pickle('./samples/test_neg_dataset.pkl')
testing_pos_dataset = pd.read_pickle('./samples/testing_positive.pkl')
testing_neg_dataset = pd.read_pickle('./samples/testing_negative.pkl')

test_val_pos_list  = (test_pos_dataset['id'].unique()).tolist()
test_val_neg_list  = (test_neg_dataset['id'].unique()).tolist()

validation_pos_data = test_pos_dataset[test_pos_dataset['id'].isin(test_val_pos_list[:3])]
test_pos_dataset = test_pos_dataset[test_pos_dataset['id'].isin(test_val_pos_list[3:])]
validation_neg_data = test_neg_dataset[test_neg_dataset['id'].isin(test_val_neg_list[:3])]
test_neg_dataset = test_neg_dataset[test_neg_dataset['id'].isin(test_val_neg_list[3:])]

# %%
train_pos_dataset['age'].unique()
# Out:
# array([12, 13, 14], dtype=int64)

# %%
# # ---------------------------- 数据预处理 ----------------------------
def map_age(age):
    if age < 13:
        return [1, 0]
    elif age >= 13:
        return [0, 1] 

# ---------------------------- 数据预处理 ----------------------------
def map_gender(gender):
    return [1, 0] if gender == 'Female' else [0, 1]

def preprocess(df):
    df_new = df.copy()
    
    df_new[['age_0', 'age_1']] = df_new['age'].apply(map_age).apply(pd.Series)
    df_new[['gender_0', 'gender_1']] = df_new['gender'].apply(map_gender).apply(pd.Series)
    return df_new.drop(profile_columns, axis=1)


# 应用预处理
train_pos_features = preprocess(train_pos_dataset)
train_neg_features = preprocess(train_neg_dataset)
val_pos_features = preprocess(validation_pos_data)
val_neg_features = preprocess(validation_neg_data)
test_pos_features = preprocess(test_pos_dataset)
test_neg_features = preprocess(test_neg_dataset)


testing_pos_features = preprocess(testing_pos_dataset)
testing_neg_features = preprocess(testing_neg_dataset)

# %%
print(train_pos_dataset.columns)

print(train_pos_features.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_HF', 'HRV_VHF',
#        'HRV_TP', 'HRV_HFn', 'HRV_LnHF', 'wave_quality', 'label', 'id', 'age',
#        'gender'],
#       dtype='object')
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_HF', 'HRV_VHF',
#        'HRV_TP', 'HRV_HFn', 'HRV_LnHF', 'age_0', 'age_1', 'gender_0',
#        'gender_1'],
#       dtype='object')

# %%
# ---------------------------- DNN 模型 ----------------------------

class DNNModel(nn.Module):
    def __init__(self, input_dim):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.relu = nn.ReLU()
        self.dropOut = nn.Dropout(0.8)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropOut(x)
        x = self.relu(self.fc2(x))
        x = self.dropOut(x)
        x = self.sigmoid(self.fc3(x))
        return x

input_dim = train_pos_features.shape[1]
model = DNNModel(input_dim)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# ---------------------------- 自定义数据加载器 ----------------------------

class BalancedDataset(Dataset):
    def __init__(self, pos_data, neg_data):
        self.pos_data = pos_data
        self.neg_data = neg_data
        self.pos_len = len(pos_data)
        self.neg_len = len(neg_data)

    def __len__(self):
        return min(self.pos_len, self.neg_len)

    def __getitem__(self, idx):
        pos_idx = np.random.randint(0, self.pos_len)
        neg_idx = np.random.randint(0, self.neg_len)
        
        pos_sample = self.pos_data.iloc[pos_idx].values.astype(np.float32)
        neg_sample = self.neg_data.iloc[neg_idx].values.astype(np.float32)

        X = np.vstack([pos_sample, neg_sample])
        y = np.array([1, 0], dtype=np.float32)

        return torch.tensor(X), torch.tensor(y)

class TestDataset(Dataset):
    def __init__(self, pos_data, neg_data):
        self.pos_data = pos_data
        self.neg_data = neg_data
        self.pos_len = len(pos_data)
        self.neg_len = len(neg_data)

    def __len__(self):
        return self.pos_len + self.neg_len

    def __getitem__(self, idx):
        if idx < self.pos_len:
            sample = self.pos_data.iloc[idx].values.astype(np.float32)
            label = 1
        else:
            idx -= self.pos_len
            sample = self.neg_data.iloc[idx].values.astype(np.float32)
            label = 0
        
        return torch.tensor(sample), torch.tensor(label, dtype=torch.float32)

# 初始化数据集和数据加载器
batch_size = 64
train_dataset = BalancedDataset(train_pos_features, train_neg_features)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataset = TestDataset(val_pos_features, val_neg_features)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_dataset = TestDataset(test_pos_features, test_neg_features)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# ---------------------------- 模型训练 ----------------------------
num_epochs = 300
train_losses = []
test_accuracies = []

def evaluate_model(model, data_loader):
    model.eval()  # 设置模型为评估模式
    pos_correct = 0
    neg_correct = 0
    pos_total = 0
    neg_total = 0

    with torch.no_grad():  # 关闭梯度计算
        for inputs, labels in data_loader:
            outputs = model(inputs)
            predicted = (outputs.squeeze() >= 0.5).float()

            # print(f"predicted: {predicted}")
            # Calculate accuracy for positive and negative samples
            pos_mask = (labels == 1).float()
            neg_mask = (labels == 0).float()
            pos_correct += ((predicted == labels) * pos_mask).sum().item()
            neg_correct += ((predicted == labels) * neg_mask).sum().item()
            pos_total += pos_mask.sum().item()
            neg_total += neg_mask.sum().item()
            

    pos_accuracy = pos_correct / pos_total if pos_total > 0 else 0
    neg_accuracy = neg_correct / neg_total if neg_total > 0 else 0
    return pos_accuracy, neg_accuracy, (pos_correct+neg_correct) / (pos_total + neg_total)


best_accuracy = 0.0
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), labels)
        epoch_loss += loss.item()

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accuracy calculation
        predicted = (outputs.squeeze() > 0.5).float()
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    # Calculate average loss and accuracy for the epoch
    avg_loss = epoch_loss / len(train_loader)
    avg_accuracy = correct / total
    train_losses.append(avg_loss)
    
    # Evaluate on test set
    pos_accuracy, neg_accuracy, accuracy = evaluate_model(model, val_loader)
    test_accuracies.append(accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Avg Accuracy: {accuracy},  Positive Accuracy: {pos_accuracy * 100:.2f}%, Negative Accuracy: {neg_accuracy * 100:.2f}%')

    # Save the best model
    if accuracy > best_accuracy and (pos_accuracy >0.4 and neg_accuracy >0.5) and epoch > 2:
        best_accuracy = accuracy
        torch.save(model.state_dict(), pth_file_path)
        print("Best Accuracy Model: {}".format(best_accuracy))

        # Export the best model to ONNX
        dummy_input = torch.randn(1, input_dim)
        torch.onnx.export(model, dummy_input, onnx_file_path, input_names=['input'], output_names=['output'])
    

# ---------------------------- 绘制训练曲线 ----------------------------

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Curve')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), [acc * 100 for acc in test_accuracies], marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Testing Accuracy Curve')

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/300], Loss: 0.6930, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 78.89%, Negative Accuracy: 40.00%
# Epoch [2/300], Loss: 0.6934, Avg Accuracy: 0.5166666666666667,  Positive Accuracy: 100.00%, Negative Accuracy: 3.33%
# Epoch [3/300], Loss: 0.6896, Avg Accuracy: 0.6555555555555556,  Positive Accuracy: 100.00%, Negative Accuracy: 31.11%
# Epoch [4/300], Loss: 0.6887, Avg Accuracy: 0.8055555555555556,  Positive Accuracy: 100.00%, Negative Accuracy: 61.11%
# Best Accuracy Model: 0.8055555555555556
# Epoch [5/300], Loss: 0.6838, Avg Accuracy: 0.8166666666666667,  Positive Accuracy: 100.00%, Negative Accuracy: 63.33%
# Best Accuracy Model: 0.8166666666666667
# Epoch [6/300], Loss: 0.6787, Avg Accuracy: 0.8333333333333334,  Positive Accuracy: 100.00%, Negative Accuracy: 66.67%
# Best Accuracy Model: 0.8333333333333334
# Epoch [7/300], Loss: 0.6737, Avg Accuracy: 0.7777777777777778,  Positive Accuracy: 100.00%, Negative Accuracy: 55.56%
# Epoch [8/300], Loss: 0.6736, Avg Accuracy: 0.8277777777777777,  Positive Accuracy: 100.00%, Negative Accuracy: 65.56%
# Epoch [9/300], Loss: 0.6588, Avg Accuracy: 0.8333333333333334,  Positive Accuracy: 100.00%, Negative Accuracy: 66.67%
# Epoch [10/300], Loss: 0.6499, Avg Accuracy: 0.8333333333333334,  Positive Accuracy: 100.00%, Negative Accuracy: 66.67%
# Epoch [11/300], Loss: 0.6518, Avg Accuracy: 0.8277777777777777,  Positive Accuracy: 98.89%, Negative Accuracy: 66.67%
# Epoch [12/300], Loss: 0.6428, Avg Accuracy: 0.8111111111111111,  Positive Accuracy: 95.56%, Negative Accuracy: 66.67%
# Epoch [13/300], Loss: 0.6550, Avg Accuracy: 0.7833333333333333,  Positive Accuracy: 90.00%, Negative Accuracy: 66.67%
# Epoch [14/300], Loss: 0.6475, Avg Accuracy: 0.7944444444444444,  Positive Accuracy: 92.22%, Negative Accuracy: 66.67%
# Epoch [15/300], Loss: 0.6347, Avg Accuracy: 0.7722222222222223,  Positive Accuracy: 87.78%, Negative Accuracy: 66.67%
# Epoch [16/300], Loss: 0.6514, Avg Accuracy: 0.7388888888888889,  Positive Accuracy: 81.11%, Negative Accuracy: 66.67%
# Epoch [17/300], Loss: 0.6463, Avg Accuracy: 0.7611111111111111,  Positive Accuracy: 85.56%, Negative Accuracy: 66.67%
# Epoch [18/300], Loss: 0.6335, Avg Accuracy: 0.7888888888888889,  Positive Accuracy: 91.11%, Negative Accuracy: 66.67%
# Epoch [19/300], Loss: 0.6334, Avg Accuracy: 0.7611111111111111,  Positive Accuracy: 85.56%, Negative Accuracy: 66.67%
# Epoch [20/300], Loss: 0.6370, Avg Accuracy: 0.7555555555555555,  Positive Accuracy: 84.44%, Negative Accuracy: 66.67%
# Epoch [21/300], Loss: 0.6294, Avg Accuracy: 0.75,  Positive Accuracy: 83.33%, Negative Accuracy: 66.67%
# Epoch [22/300], Loss: 0.6211, Avg Accuracy: 0.7722222222222223,  Positive Accuracy: 87.78%, Negative Accuracy: 66.67%
# Epoch [23/300], Loss: 0.6222, Avg Accuracy: 0.7722222222222223,  Positive Accuracy: 87.78%, Negative Accuracy: 66.67%
# Epoch [24/300], Loss: 0.6264, Avg Accuracy: 0.7444444444444445,  Positive Accuracy: 82.22%, Negative Accuracy: 66.67%
# Epoch [25/300], Loss: 0.6328, Avg Accuracy: 0.7388888888888889,  Positive Accuracy: 81.11%, Negative Accuracy: 66.67%
# Epoch [26/300], Loss: 0.6155, Avg Accuracy: 0.75,  Positive Accuracy: 83.33%, Negative Accuracy: 66.67%
# Epoch [27/300], Loss: 0.6239, Avg Accuracy: 0.7388888888888889,  Positive Accuracy: 81.11%, Negative Accuracy: 66.67%
# Epoch [28/300], Loss: 0.6141, Avg Accuracy: 0.7222222222222222,  Positive Accuracy: 77.78%, Negative Accuracy: 66.67%
# Epoch [29/300], Loss: 0.6280, Avg Accuracy: 0.7055555555555556,  Positive Accuracy: 74.44%, Negative Accuracy: 66.67%
# Epoch [30/300], Loss: 0.6164, Avg Accuracy: 0.7333333333333333,  Positive Accuracy: 80.00%, Negative Accuracy: 66.67%
# Epoch [31/300], Loss: 0.6073, Avg Accuracy: 0.7277777777777777,  Positive Accuracy: 78.89%, Negative Accuracy: 66.67%
# Epoch [32/300], Loss: 0.5938, Avg Accuracy: 0.7,  Positive Accuracy: 73.33%, Negative Accuracy: 66.67%
# Epoch [33/300], Loss: 0.6044, Avg Accuracy: 0.7166666666666667,  Positive Accuracy: 78.89%, Negative Accuracy: 64.44%
# Epoch [34/300], Loss: 0.6103, Avg Accuracy: 0.7055555555555556,  Positive Accuracy: 75.56%, Negative Accuracy: 65.56%
# Epoch [35/300], Loss: 0.6130, Avg Accuracy: 0.7111111111111111,  Positive Accuracy: 77.78%, Negative Accuracy: 64.44%
# Epoch [36/300], Loss: 0.6103, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 73.33%, Negative Accuracy: 64.44%
# Epoch [37/300], Loss: 0.6082, Avg Accuracy: 0.6833333333333333,  Positive Accuracy: 71.11%, Negative Accuracy: 65.56%
# Epoch [38/300], Loss: 0.5971, Avg Accuracy: 0.7,  Positive Accuracy: 77.78%, Negative Accuracy: 62.22%
# Epoch [39/300], Loss: 0.5962, Avg Accuracy: 0.6944444444444444,  Positive Accuracy: 78.89%, Negative Accuracy: 60.00%
# Epoch [40/300], Loss: 0.5998, Avg Accuracy: 0.7055555555555556,  Positive Accuracy: 78.89%, Negative Accuracy: 62.22%
# Epoch [41/300], Loss: 0.6102, Avg Accuracy: 0.6833333333333333,  Positive Accuracy: 72.22%, Negative Accuracy: 64.44%
# Epoch [42/300], Loss: 0.6080, Avg Accuracy: 0.6833333333333333,  Positive Accuracy: 72.22%, Negative Accuracy: 64.44%
# Epoch [43/300], Loss: 0.5977, Avg Accuracy: 0.6777777777777778,  Positive Accuracy: 71.11%, Negative Accuracy: 64.44%
# Epoch [44/300], Loss: 0.6056, Avg Accuracy: 0.6888888888888889,  Positive Accuracy: 73.33%, Negative Accuracy: 64.44%
# Epoch [45/300], Loss: 0.6131, Avg Accuracy: 0.6666666666666666,  Positive Accuracy: 66.67%, Negative Accuracy: 66.67%
# Epoch [46/300], Loss: 0.6006, Avg Accuracy: 0.6611111111111111,  Positive Accuracy: 73.33%, Negative Accuracy: 58.89%
# Epoch [47/300], Loss: 0.5905, Avg Accuracy: 0.65,  Positive Accuracy: 71.11%, Negative Accuracy: 58.89%
# Epoch [48/300], Loss: 0.6027, Avg Accuracy: 0.6277777777777778,  Positive Accuracy: 67.78%, Negative Accuracy: 57.78%
# Epoch [49/300], Loss: 0.5868, Avg Accuracy: 0.65,  Positive Accuracy: 71.11%, Negative Accuracy: 58.89%
# Epoch [50/300], Loss: 0.5764, Avg Accuracy: 0.65,  Positive Accuracy: 72.22%, Negative Accuracy: 57.78%
# Epoch [51/300], Loss: 0.5897, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 71.11%, Negative Accuracy: 57.78%
# Epoch [52/300], Loss: 0.5800, Avg Accuracy: 0.6388888888888888,  Positive Accuracy: 70.00%, Negative Accuracy: 57.78%
# Epoch [53/300], Loss: 0.6001, Avg Accuracy: 0.6388888888888888,  Positive Accuracy: 70.00%, Negative Accuracy: 57.78%
# Epoch [54/300], Loss: 0.5820, Avg Accuracy: 0.6388888888888888,  Positive Accuracy: 68.89%, Negative Accuracy: 58.89%
# Epoch [55/300], Loss: 0.5720, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 70.00%, Negative Accuracy: 58.89%
# Epoch [56/300], Loss: 0.5816, Avg Accuracy: 0.6388888888888888,  Positive Accuracy: 70.00%, Negative Accuracy: 57.78%
# Epoch [57/300], Loss: 0.5850, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 70.00%, Negative Accuracy: 56.67%
# Epoch [58/300], Loss: 0.5889, Avg Accuracy: 0.6444444444444445,  Positive Accuracy: 67.78%, Negative Accuracy: 61.11%
# Epoch [59/300], Loss: 0.5771, Avg Accuracy: 0.6388888888888888,  Positive Accuracy: 70.00%, Negative Accuracy: 57.78%
# Epoch [60/300], Loss: 0.5853, Avg Accuracy: 0.6388888888888888,  Positive Accuracy: 68.89%, Negative Accuracy: 58.89%
# Epoch [61/300], Loss: 0.5758, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 55.56%
# Epoch [62/300], Loss: 0.5822, Avg Accuracy: 0.6,  Positive Accuracy: 70.00%, Negative Accuracy: 50.00%
# Epoch [63/300], Loss: 0.5834, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 65.56%, Negative Accuracy: 58.89%
# Epoch [64/300], Loss: 0.5793, Avg Accuracy: 0.6277777777777778,  Positive Accuracy: 68.89%, Negative Accuracy: 56.67%
# Epoch [65/300], Loss: 0.5797, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 65.56%, Negative Accuracy: 58.89%
# Epoch [66/300], Loss: 0.5763, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 67.78%, Negative Accuracy: 56.67%
# Epoch [67/300], Loss: 0.5865, Avg Accuracy: 0.6166666666666667,  Positive Accuracy: 67.78%, Negative Accuracy: 55.56%
# Epoch [68/300], Loss: 0.5812, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 66.67%, Negative Accuracy: 57.78%
# Epoch [69/300], Loss: 0.5755, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 66.67%, Negative Accuracy: 54.44%
# Epoch [70/300], Loss: 0.5714, Avg Accuracy: 0.6166666666666667,  Positive Accuracy: 66.67%, Negative Accuracy: 56.67%
# Epoch [71/300], Loss: 0.5841, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 55.56%
# Epoch [72/300], Loss: 0.5665, Avg Accuracy: 0.6333333333333333,  Positive Accuracy: 68.89%, Negative Accuracy: 57.78%
# Epoch [73/300], Loss: 0.5626, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 55.56%
# Epoch [74/300], Loss: 0.5621, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 55.56%
# Epoch [75/300], Loss: 0.5649, Avg Accuracy: 0.6222222222222222,  Positive Accuracy: 67.78%, Negative Accuracy: 56.67%
# Epoch [76/300], Loss: 0.5748, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 70.00%, Negative Accuracy: 52.22%
# Epoch [77/300], Loss: 0.5657, Avg Accuracy: 0.6166666666666667,  Positive Accuracy: 67.78%, Negative Accuracy: 55.56%
# Epoch [78/300], Loss: 0.5652, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [79/300], Loss: 0.5669, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 71.11%, Negative Accuracy: 47.78%
# Epoch [80/300], Loss: 0.5710, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 50.00%
# Epoch [81/300], Loss: 0.5529, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 66.67%, Negative Accuracy: 51.11%
# Epoch [82/300], Loss: 0.5702, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 65.56%, Negative Accuracy: 51.11%
# Epoch [83/300], Loss: 0.5590, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [84/300], Loss: 0.5681, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 70.00%, Negative Accuracy: 47.78%
# Epoch [85/300], Loss: 0.5576, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 68.89%, Negative Accuracy: 47.78%
# Epoch [86/300], Loss: 0.5625, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 72.22%, Negative Accuracy: 46.67%
# Epoch [87/300], Loss: 0.5760, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [88/300], Loss: 0.5667, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [89/300], Loss: 0.5560, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 70.00%, Negative Accuracy: 47.78%
# Epoch [90/300], Loss: 0.5558, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 66.67%, Negative Accuracy: 48.89%
# Epoch [91/300], Loss: 0.5503, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 67.78%, Negative Accuracy: 48.89%
# Epoch [92/300], Loss: 0.5729, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 70.00%, Negative Accuracy: 46.67%
# Epoch [93/300], Loss: 0.5608, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [94/300], Loss: 0.5541, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 68.89%, Negative Accuracy: 46.67%
# Epoch [95/300], Loss: 0.5878, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 67.78%, Negative Accuracy: 48.89%
# Epoch [96/300], Loss: 0.5539, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 64.44%, Negative Accuracy: 50.00%
# Epoch [97/300], Loss: 0.5538, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 67.78%, Negative Accuracy: 48.89%
# Epoch [98/300], Loss: 0.5535, Avg Accuracy: 0.6,  Positive Accuracy: 73.33%, Negative Accuracy: 46.67%
# Epoch [99/300], Loss: 0.5664, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 70.00%, Negative Accuracy: 46.67%
# Epoch [100/300], Loss: 0.5533, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 68.89%, Negative Accuracy: 46.67%
# Epoch [101/300], Loss: 0.5420, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 45.56%
# Epoch [102/300], Loss: 0.5401, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 70.00%, Negative Accuracy: 44.44%
# Epoch [103/300], Loss: 0.5438, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 72.22%, Negative Accuracy: 41.11%
# Epoch [104/300], Loss: 0.5560, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 66.67%, Negative Accuracy: 46.67%
# Epoch [105/300], Loss: 0.5459, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 70.00%, Negative Accuracy: 45.56%
# Epoch [106/300], Loss: 0.5675, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 68.89%, Negative Accuracy: 47.78%
# Epoch [107/300], Loss: 0.5622, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 66.67%, Negative Accuracy: 46.67%
# Epoch [108/300], Loss: 0.5441, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 67.78%, Negative Accuracy: 45.56%
# Epoch [109/300], Loss: 0.5515, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 73.33%, Negative Accuracy: 41.11%
# Epoch [110/300], Loss: 0.5453, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 44.44%
# Epoch [111/300], Loss: 0.5504, Avg Accuracy: 0.5611111111111111,  Positive Accuracy: 67.78%, Negative Accuracy: 44.44%
# Epoch [112/300], Loss: 0.5469, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 70.00%, Negative Accuracy: 44.44%
# Epoch [113/300], Loss: 0.5624, Avg Accuracy: 0.5611111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 45.56%
# Epoch [114/300], Loss: 0.5424, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 67.78%, Negative Accuracy: 46.67%
# Epoch [115/300], Loss: 0.5728, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 67.78%, Negative Accuracy: 46.67%
# Epoch [116/300], Loss: 0.5400, Avg Accuracy: 0.5611111111111111,  Positive Accuracy: 67.78%, Negative Accuracy: 44.44%
# Epoch [117/300], Loss: 0.5425, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 66.67%, Negative Accuracy: 48.89%
# Epoch [118/300], Loss: 0.5436, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 67.78%, Negative Accuracy: 46.67%
# Epoch [119/300], Loss: 0.5499, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 68.89%, Negative Accuracy: 46.67%
# Epoch [120/300], Loss: 0.5554, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 65.56%, Negative Accuracy: 50.00%
# Epoch [121/300], Loss: 0.5621, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 66.67%, Negative Accuracy: 48.89%
# Epoch [122/300], Loss: 0.5434, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 67.78%, Negative Accuracy: 48.89%
# Epoch [123/300], Loss: 0.5561, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 67.78%, Negative Accuracy: 45.56%
# Epoch [124/300], Loss: 0.5653, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 67.78%, Negative Accuracy: 45.56%
# Epoch [125/300], Loss: 0.5518, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 71.11%, Negative Accuracy: 45.56%
# Epoch [126/300], Loss: 0.5400, Avg Accuracy: 0.6,  Positive Accuracy: 74.44%, Negative Accuracy: 45.56%
# Epoch [127/300], Loss: 0.5330, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 72.22%, Negative Accuracy: 48.89%
# Epoch [128/300], Loss: 0.5326, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 45.56%
# Epoch [129/300], Loss: 0.5287, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 71.11%, Negative Accuracy: 44.44%
# Epoch [130/300], Loss: 0.5427, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 72.22%, Negative Accuracy: 45.56%
# Epoch [131/300], Loss: 0.5555, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 66.67%, Negative Accuracy: 46.67%
# Epoch [132/300], Loss: 0.5505, Avg Accuracy: 0.5611111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 45.56%
# Epoch [133/300], Loss: 0.5645, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 67.78%, Negative Accuracy: 45.56%
# Epoch [134/300], Loss: 0.5311, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 67.78%, Negative Accuracy: 47.78%
# Epoch [135/300], Loss: 0.5542, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 66.67%, Negative Accuracy: 47.78%
# Epoch [136/300], Loss: 0.5349, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 66.67%, Negative Accuracy: 48.89%
# Epoch [137/300], Loss: 0.5328, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 73.33%, Negative Accuracy: 44.44%
# Epoch [138/300], Loss: 0.5449, Avg Accuracy: 0.5611111111111111,  Positive Accuracy: 65.56%, Negative Accuracy: 46.67%
# Epoch [139/300], Loss: 0.5394, Avg Accuracy: 0.5611111111111111,  Positive Accuracy: 67.78%, Negative Accuracy: 44.44%
# Epoch [140/300], Loss: 0.5338, Avg Accuracy: 0.5555555555555556,  Positive Accuracy: 65.56%, Negative Accuracy: 45.56%
# Epoch [141/300], Loss: 0.5379, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 67.78%, Negative Accuracy: 45.56%
# Epoch [142/300], Loss: 0.5456, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 45.56%
# Epoch [143/300], Loss: 0.5451, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 65.56%, Negative Accuracy: 47.78%
# Epoch [144/300], Loss: 0.5361, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 68.89%, Negative Accuracy: 47.78%
# Epoch [145/300], Loss: 0.5413, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 71.11%, Negative Accuracy: 45.56%
# Epoch [146/300], Loss: 0.5331, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [147/300], Loss: 0.5180, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 68.89%, Negative Accuracy: 47.78%
# Epoch [148/300], Loss: 0.5391, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 70.00%, Negative Accuracy: 44.44%
# Epoch [149/300], Loss: 0.5215, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 71.11%, Negative Accuracy: 45.56%
# Epoch [150/300], Loss: 0.5515, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 68.89%, Negative Accuracy: 47.78%
# Epoch [151/300], Loss: 0.5327, Avg Accuracy: 0.5611111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 45.56%
# Epoch [152/300], Loss: 0.5433, Avg Accuracy: 0.5555555555555556,  Positive Accuracy: 65.56%, Negative Accuracy: 45.56%
# Epoch [153/300], Loss: 0.5372, Avg Accuracy: 0.5611111111111111,  Positive Accuracy: 66.67%, Negative Accuracy: 45.56%
# Epoch [154/300], Loss: 0.5494, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 66.67%, Negative Accuracy: 48.89%
# Epoch [155/300], Loss: 0.5433, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 68.89%, Negative Accuracy: 47.78%
# Epoch [156/300], Loss: 0.5411, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 67.78%, Negative Accuracy: 45.56%
# Epoch [157/300], Loss: 0.5592, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 66.67%, Negative Accuracy: 48.89%
# Epoch [158/300], Loss: 0.5260, Avg Accuracy: 0.5611111111111111,  Positive Accuracy: 65.56%, Negative Accuracy: 46.67%
# Epoch [159/300], Loss: 0.5250, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 72.22%, Negative Accuracy: 46.67%
# Epoch [160/300], Loss: 0.5456, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [161/300], Loss: 0.5355, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [162/300], Loss: 0.5492, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 66.67%, Negative Accuracy: 48.89%
# Epoch [163/300], Loss: 0.5442, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 68.89%, Negative Accuracy: 48.89%
# Epoch [164/300], Loss: 0.5376, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [165/300], Loss: 0.5311, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [166/300], Loss: 0.5477, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 65.56%, Negative Accuracy: 50.00%
# Epoch [167/300], Loss: 0.5292, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 65.56%, Negative Accuracy: 48.89%
# Epoch [168/300], Loss: 0.5280, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 68.89%, Negative Accuracy: 45.56%
# Epoch [169/300], Loss: 0.5233, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [170/300], Loss: 0.5170, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [171/300], Loss: 0.5301, Avg Accuracy: 0.6,  Positive Accuracy: 73.33%, Negative Accuracy: 46.67%
# Epoch [172/300], Loss: 0.5559, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 67.78%, Negative Accuracy: 48.89%
# Epoch [173/300], Loss: 0.5224, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [174/300], Loss: 0.5160, Avg Accuracy: 0.6,  Positive Accuracy: 70.00%, Negative Accuracy: 50.00%
# Epoch [175/300], Loss: 0.5264, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 70.00%, Negative Accuracy: 46.67%
# Epoch [176/300], Loss: 0.5229, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 71.11%, Negative Accuracy: 47.78%
# Epoch [177/300], Loss: 0.5278, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 70.00%, Negative Accuracy: 44.44%
# Epoch [178/300], Loss: 0.5479, Avg Accuracy: 0.5666666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 44.44%
# Epoch [179/300], Loss: 0.5344, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 68.89%, Negative Accuracy: 48.89%
# Epoch [180/300], Loss: 0.5222, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [181/300], Loss: 0.5073, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [182/300], Loss: 0.5324, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 73.33%, Negative Accuracy: 44.44%
# Epoch [183/300], Loss: 0.5264, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 70.00%, Negative Accuracy: 44.44%
# Epoch [184/300], Loss: 0.5414, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 66.67%, Negative Accuracy: 47.78%
# Epoch [185/300], Loss: 0.5397, Avg Accuracy: 0.5555555555555556,  Positive Accuracy: 66.67%, Negative Accuracy: 44.44%
# Epoch [186/300], Loss: 0.5067, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 70.00%, Negative Accuracy: 44.44%
# Epoch [187/300], Loss: 0.5172, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 70.00%, Negative Accuracy: 48.89%
# Epoch [188/300], Loss: 0.5341, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 70.00%, Negative Accuracy: 46.67%
# Epoch [189/300], Loss: 0.5065, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [190/300], Loss: 0.5257, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 71.11%, Negative Accuracy: 47.78%
# Epoch [191/300], Loss: 0.5516, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [192/300], Loss: 0.5366, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 64.44%, Negative Accuracy: 50.00%
# Epoch [193/300], Loss: 0.5264, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [194/300], Loss: 0.5274, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [195/300], Loss: 0.5108, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 71.11%, Negative Accuracy: 46.67%
# Epoch [196/300], Loss: 0.5202, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [197/300], Loss: 0.5006, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [198/300], Loss: 0.5147, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 66.67%, Negative Accuracy: 48.89%
# Epoch [199/300], Loss: 0.5316, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 67.78%, Negative Accuracy: 46.67%
# Epoch [200/300], Loss: 0.5362, Avg Accuracy: 0.6,  Positive Accuracy: 71.11%, Negative Accuracy: 48.89%
# Epoch [201/300], Loss: 0.5223, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [202/300], Loss: 0.5083, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 65.56%, Negative Accuracy: 50.00%
# Epoch [203/300], Loss: 0.5148, Avg Accuracy: 0.6,  Positive Accuracy: 70.00%, Negative Accuracy: 50.00%
# Epoch [204/300], Loss: 0.5283, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 68.89%, Negative Accuracy: 48.89%
# Epoch [205/300], Loss: 0.5278, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 50.00%
# Epoch [206/300], Loss: 0.5288, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 65.56%, Negative Accuracy: 50.00%
# Epoch [207/300], Loss: 0.5167, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 70.00%, Negative Accuracy: 48.89%
# Epoch [208/300], Loss: 0.5351, Avg Accuracy: 0.5722222222222222,  Positive Accuracy: 66.67%, Negative Accuracy: 47.78%
# Epoch [209/300], Loss: 0.5128, Avg Accuracy: 0.5611111111111111,  Positive Accuracy: 67.78%, Negative Accuracy: 44.44%
# Epoch [210/300], Loss: 0.5149, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 70.00%, Negative Accuracy: 47.78%
# Epoch [211/300], Loss: 0.5227, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 68.89%, Negative Accuracy: 48.89%
# Epoch [212/300], Loss: 0.5276, Avg Accuracy: 0.6,  Positive Accuracy: 70.00%, Negative Accuracy: 50.00%
# Epoch [213/300], Loss: 0.5360, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 50.00%
# Epoch [214/300], Loss: 0.5168, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [215/300], Loss: 0.5273, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [216/300], Loss: 0.5290, Avg Accuracy: 0.6,  Positive Accuracy: 70.00%, Negative Accuracy: 50.00%
# Epoch [217/300], Loss: 0.5064, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [218/300], Loss: 0.5118, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [219/300], Loss: 0.5231, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [220/300], Loss: 0.5076, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [221/300], Loss: 0.5223, Avg Accuracy: 0.6,  Positive Accuracy: 70.00%, Negative Accuracy: 50.00%
# Epoch [222/300], Loss: 0.5107, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [223/300], Loss: 0.5347, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [224/300], Loss: 0.5196, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [225/300], Loss: 0.5186, Avg Accuracy: 0.6,  Positive Accuracy: 70.00%, Negative Accuracy: 50.00%
# Epoch [226/300], Loss: 0.5151, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 50.00%
# Epoch [227/300], Loss: 0.5247, Avg Accuracy: 0.6,  Positive Accuracy: 70.00%, Negative Accuracy: 50.00%
# Epoch [228/300], Loss: 0.5170, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 65.56%, Negative Accuracy: 51.11%
# Epoch [229/300], Loss: 0.5235, Avg Accuracy: 0.6,  Positive Accuracy: 70.00%, Negative Accuracy: 50.00%
# Epoch [230/300], Loss: 0.5151, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [231/300], Loss: 0.5167, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 65.56%, Negative Accuracy: 50.00%
# Epoch [232/300], Loss: 0.5066, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 65.56%, Negative Accuracy: 50.00%
# Epoch [233/300], Loss: 0.5198, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [234/300], Loss: 0.5092, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [235/300], Loss: 0.5066, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [236/300], Loss: 0.5028, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [237/300], Loss: 0.5192, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 70.00%, Negative Accuracy: 51.11%
# Epoch [238/300], Loss: 0.5156, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 67.78%, Negative Accuracy: 53.33%
# Epoch [239/300], Loss: 0.5114, Avg Accuracy: 0.6,  Positive Accuracy: 68.89%, Negative Accuracy: 51.11%
# Epoch [240/300], Loss: 0.5193, Avg Accuracy: 0.6,  Positive Accuracy: 68.89%, Negative Accuracy: 51.11%
# Epoch [241/300], Loss: 0.5054, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [242/300], Loss: 0.5082, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [243/300], Loss: 0.5044, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [244/300], Loss: 0.5490, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 67.78%, Negative Accuracy: 51.11%
# Epoch [245/300], Loss: 0.5273, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 65.56%, Negative Accuracy: 53.33%
# Epoch [246/300], Loss: 0.4995, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 67.78%, Negative Accuracy: 51.11%
# Epoch [247/300], Loss: 0.5090, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [248/300], Loss: 0.4889, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 68.89%, Negative Accuracy: 53.33%
# Epoch [249/300], Loss: 0.5087, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [250/300], Loss: 0.5236, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [251/300], Loss: 0.5105, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [252/300], Loss: 0.5182, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [253/300], Loss: 0.5068, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [254/300], Loss: 0.4983, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 50.00%
# Epoch [255/300], Loss: 0.5098, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 71.11%, Negative Accuracy: 50.00%
# Epoch [256/300], Loss: 0.5187, Avg Accuracy: 0.6,  Positive Accuracy: 70.00%, Negative Accuracy: 50.00%
# Epoch [257/300], Loss: 0.5237, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [258/300], Loss: 0.5175, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [259/300], Loss: 0.5176, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 68.89%, Negative Accuracy: 53.33%
# Epoch [260/300], Loss: 0.5176, Avg Accuracy: 0.6166666666666667,  Positive Accuracy: 71.11%, Negative Accuracy: 52.22%
# Epoch [261/300], Loss: 0.5074, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 67.78%, Negative Accuracy: 53.33%
# Epoch [262/300], Loss: 0.5132, Avg Accuracy: 0.6166666666666667,  Positive Accuracy: 68.89%, Negative Accuracy: 54.44%
# Epoch [263/300], Loss: 0.5065, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 65.56%, Negative Accuracy: 52.22%
# Epoch [264/300], Loss: 0.4955, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 65.56%, Negative Accuracy: 52.22%
# Epoch [265/300], Loss: 0.5048, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 67.78%, Negative Accuracy: 51.11%
# Epoch [266/300], Loss: 0.5116, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 72.22%, Negative Accuracy: 50.00%
# Epoch [267/300], Loss: 0.5052, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 67.78%, Negative Accuracy: 50.00%
# Epoch [268/300], Loss: 0.4912, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 65.56%, Negative Accuracy: 51.11%
# Epoch [269/300], Loss: 0.4937, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 68.89%, Negative Accuracy: 53.33%
# Epoch [270/300], Loss: 0.5079, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 65.56%, Negative Accuracy: 53.33%
# Epoch [271/300], Loss: 0.4931, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 65.56%, Negative Accuracy: 50.00%
# Epoch [272/300], Loss: 0.5204, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%
# Epoch [273/300], Loss: 0.5111, Avg Accuracy: 0.5777777777777777,  Positive Accuracy: 65.56%, Negative Accuracy: 50.00%
# Epoch [274/300], Loss: 0.5252, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 65.56%, Negative Accuracy: 53.33%
# Epoch [275/300], Loss: 0.4973, Avg Accuracy: 0.6,  Positive Accuracy: 66.67%, Negative Accuracy: 53.33%
# Epoch [276/300], Loss: 0.4931, Avg Accuracy: 0.6166666666666667,  Positive Accuracy: 66.67%, Negative Accuracy: 56.67%
# Epoch [277/300], Loss: 0.5234, Avg Accuracy: 0.6,  Positive Accuracy: 66.67%, Negative Accuracy: 53.33%
# Epoch [278/300], Loss: 0.4931, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 65.56%, Negative Accuracy: 52.22%
# Epoch [279/300], Loss: 0.4930, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 65.56%, Negative Accuracy: 53.33%
# Epoch [280/300], Loss: 0.4981, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 65.56%, Negative Accuracy: 53.33%
# Epoch [281/300], Loss: 0.5159, Avg Accuracy: 0.6111111111111112,  Positive Accuracy: 65.56%, Negative Accuracy: 56.67%
# Epoch [282/300], Loss: 0.4994, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 65.56%, Negative Accuracy: 53.33%
# Epoch [283/300], Loss: 0.5164, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 65.56%, Negative Accuracy: 52.22%
# Epoch [284/300], Loss: 0.5185, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 65.56%, Negative Accuracy: 51.11%
# Epoch [285/300], Loss: 0.4938, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 65.56%, Negative Accuracy: 52.22%
# Epoch [286/300], Loss: 0.5008, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 65.56%, Negative Accuracy: 51.11%
# Epoch [287/300], Loss: 0.5101, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 65.56%, Negative Accuracy: 53.33%
# Epoch [288/300], Loss: 0.5168, Avg Accuracy: 0.6,  Positive Accuracy: 65.56%, Negative Accuracy: 54.44%
# Epoch [289/300], Loss: 0.5005, Avg Accuracy: 0.6,  Positive Accuracy: 65.56%, Negative Accuracy: 54.44%
# Epoch [290/300], Loss: 0.4871, Avg Accuracy: 0.6,  Positive Accuracy: 68.89%, Negative Accuracy: 51.11%
# Epoch [291/300], Loss: 0.4999, Avg Accuracy: 0.6055555555555555,  Positive Accuracy: 68.89%, Negative Accuracy: 52.22%
# Epoch [292/300], Loss: 0.4960, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 65.56%, Negative Accuracy: 53.33%
# Epoch [293/300], Loss: 0.4895, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 65.56%, Negative Accuracy: 53.33%
# Epoch [294/300], Loss: 0.5143, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 68.89%, Negative Accuracy: 50.00%
# Epoch [295/300], Loss: 0.5052, Avg Accuracy: 0.5888888888888889,  Positive Accuracy: 66.67%, Negative Accuracy: 51.11%
# Epoch [296/300], Loss: 0.5053, Avg Accuracy: 0.6,  Positive Accuracy: 66.67%, Negative Accuracy: 53.33%
# Epoch [297/300], Loss: 0.5151, Avg Accuracy: 0.6166666666666667,  Positive Accuracy: 65.56%, Negative Accuracy: 57.78%
# Epoch [298/300], Loss: 0.5051, Avg Accuracy: 0.6,  Positive Accuracy: 65.56%, Negative Accuracy: 54.44%
# Epoch [299/300], Loss: 0.5181, Avg Accuracy: 0.5944444444444444,  Positive Accuracy: 65.56%, Negative Accuracy: 53.33%
# Epoch [300/300], Loss: 0.4932, Avg Accuracy: 0.5833333333333334,  Positive Accuracy: 66.67%, Negative Accuracy: 50.00%

# %%
import glob
import glob
import numpy as np
import onnxruntime as ort

from collections import defaultdict

# %%
print(test_pos_dataset.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_HF', 'HRV_VHF',
#        'HRV_TP', 'HRV_HFn', 'HRV_LnHF', 'wave_quality', 'label', 'id', 'age',
#        'gender'],
#       dtype='object')

# %%
import enum


def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    # 如果找到的文件不为空
    if onnx_files:
        # 按文件名排序
        onnx_files.sort()

        # 选择最后一个文件
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    if onnx_files:
        onnx_files.sort()
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
ort_session = ort.InferenceSession(onnx_model_path)

# 预测函数
def predict(features):
    inputs = {ort_session.get_inputs()[0].name: features}
    outputs = ort_session.run(None, inputs)
    return outputs[0]

for idx, pair_data in enumerate([[test_neg_dataset, test_neg_features], [test_pos_dataset, test_pos_features]]):
    if idx == 0:
        print("\nTest for Negative subjects:")
    else:
        print("\nTest for Positive subjects:")

    # 加载测试数据集
    # 计算每个 subject 的准确率
    subject_results = defaultdict(list)

    for (_, row_dataset), (_, features), in zip(pair_data[0].iterrows(), pair_data[1].iterrows()):
        subject = row_dataset['id']
        label = row_dataset['label']

        features = np.array(features, dtype=np.float32)  # 确保 features 的数据类型与模型输入匹配
        features = features.reshape(1, -1)  # 调整形状以匹配模型输入
        prediction = predict(features)
        predicted_label = (prediction >= 0.5).astype(int)  # 使用阈值 0.5 将预测概率转换为类标签
        subject_results[subject].append((predicted_label, label))

    subject_accuracies = {}
    for subject, results in subject_results.items():
        correct = sum(1 for pred, label in results if pred == label)
        accuracy = correct / len(results)
        subject_accuracies[subject] = accuracy

    # 输出每个 subject 的准确度
    correct_count = 0
    for subject, accuracy in subject_accuracies.items():
        print(f'Subject: {subject}, Accuracy: {accuracy:.2f}')
        if accuracy > 0.5:
            correct_count += 1
        elif accuracy == 0.5:
            correct_count += 0.5
    print(f"subject accuracy: {(correct_count / len(subject_accuracies)):.2f}")
# Out:
# Test for Negative subjects:
# Subject: c5cf4093-8c88-3388-dd4a-8de8169eac4d, Accuracy: 0.17
# Subject: e144aa5e-bb1a-ee2e-4873-69dd9d71e4a4, Accuracy: 0.00
# Subject: 2f8a7e09-3897-4161-d964-13f9736e20aa, Accuracy: 1.00
# Subject: ab1797e6-299c-cad7-31ce-b06cd86d7580, Accuracy: 1.00
# Subject: 91a89ac9-f767-614f-97dd-ce09b72a6605, Accuracy: 1.00
# subject accuracy: 0.60
#
# Test for Positive subjects:
# Subject: 29a8784b-8752-4de0-579c-034c95044509, Accuracy: 1.00
# Subject: 04a8fa82-4f32-d69c-72d9-8d82a472b803, Accuracy: 0.93
# Subject: 00655d01-28c6-c69c-260f-7dff23f8eeea, Accuracy: 0.00
# Subject: a793eaaf-fd17-2821-5e37-0ca88a71d1dc, Accuracy: 0.00
# Subject: 513195bb-f9b4-1d3d-6829-4cdf70008d23, Accuracy: 1.00
# subject accuracy: 0.60

# %% [markdown]
# # Testing Remaining Invalid and Unselected Valid Subjects

# %%
import enum


def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    # 如果找到的文件不为空
    if onnx_files:
        # 按文件名排序
        onnx_files.sort()

        # 选择最后一个文件
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    if onnx_files:
        onnx_files.sort()
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
ort_session = ort.InferenceSession(onnx_model_path)

# 预测函数
def predict(features):
    inputs = {ort_session.get_inputs()[0].name: features}
    outputs = ort_session.run(None, inputs)
    return outputs[0]

for idx, pair_data in enumerate([[testing_neg_dataset, testing_neg_features], [testing_pos_dataset, testing_pos_features]]):
    if idx == 0:
        print("\nTest for Negative subjects:")
    else:
        print("\nTest for Positive subjects:")

    # 加载测试数据集
    # 计算每个 subject 的准确率
    subject_results = defaultdict(list)

    for (_, row_dataset), (_, features), in zip(pair_data[0].iterrows(), pair_data[1].iterrows()):
        subject = row_dataset['id']
        label = row_dataset['label']

        features = np.array(features, dtype=np.float32)  # 确保 features 的数据类型与模型输入匹配
        features = features.reshape(1, -1)  # 调整形状以匹配模型输入
        prediction = predict(features)
        predicted_label = (prediction >= 0.5).astype(int)  # 使用阈值 0.5 将预测概率转换为类标签
        subject_results[subject].append((predicted_label, label))

    subject_accuracies = {}
    for subject, results in subject_results.items():
        correct = sum(1 for pred, label in results if pred == label)
        accuracy = correct / len(results)
        subject_accuracies[subject] = accuracy

    # 输出每个 subject 的准确度
    correct_count = 0
    for subject, accuracy in subject_accuracies.items():
        print(f'Subject: {subject}, Accuracy: {accuracy:.2f}')
        if accuracy > 0.5:
            correct_count += 1
        elif accuracy == 0.5:
            correct_count += 0.5
    print(f"subject accuracy: {(correct_count / len(subject_accuracies)):.2f}")
# Out:
# Test for Negative subjects:
# Subject: 235792954820569771831655130904093139843, Accuracy: 1.00
# Subject: 85933772090356422521289624360166209939, Accuracy: 0.00
# Subject: 60228161332762748415551414300089973898, Accuracy: 1.00
# Subject: 161346534092114523856867163199691341683, Accuracy: 1.00
# Subject: 141906085562194353137386602945104356379, Accuracy: 1.00
# Subject: 5349986675310973883230174956193451312, Accuracy: 1.00
# Subject: 179552393834535204130497190211521480528, Accuracy: 1.00
# Subject: 162605572782799812941958232855498162671, Accuracy: 0.00
# Subject: 328979043108500441381507934447150040192, Accuracy: 1.00
# Subject: 69539675861277205097272916516697061781, Accuracy: 1.00
# Subject: 75865972755766528539403317857267700933, Accuracy: 0.00
# Subject: 95761494257721479533125487182722112566, Accuracy: 1.00
# Subject: 56173384089530407014585696471908551437, Accuracy: 1.00
# Subject: 191759629860844597801430096821463085325, Accuracy: 0.00
# Subject: 47862737607272227529163978988231672324, Accuracy: 0.00
# Subject: 275715900705387641828826784079157581803, Accuracy: 0.00
# Subject: 264462959477221103534577834338092764164, Accuracy: 0.00
# Subject: 329228107762570497981481112297011162309, Accuracy: 1.00
# Subject: 302354828935195917150349154493181150388, Accuracy: 0.00
# Subject: 272054027678183636459331929783923096114, Accuracy: 1.00
# Subject: 34762425403445864083077781595636677946, Accuracy: 0.00
# Subject: 76054440420906582745935704299707044111, Accuracy: 1.00
# Subject: 185015740221569025205516001300193241334, Accuracy: 0.00
# Subject: 231326694132439594567559210812205426976, Accuracy: 0.80
# Subject: 179810728925376422764373029056359020778, Accuracy: 1.00
# Subject: 134931342716911390485053380628622871159, Accuracy: 1.00
# Subject: 51139037471666429322826801460190066689, Accuracy: 1.00
# Subject: 317601447212386935950077814758891670876, Accuracy: 0.00
# Subject: 111926663816747827588607674970577727469, Accuracy: 1.00
# Subject: 188361816522301425173778248273565407378, Accuracy: 1.00
# Subject: 224619338657120980855883007642023268109, Accuracy: 0.00
# Subject: 206917214582156291215535805333254145621, Accuracy: 0.00
# Subject: 77076855497726083793951279765245530830, Accuracy: 0.00
# Subject: 167045044196849165430793491795015270478, Accuracy: 0.83
# Subject: 165913765095380822661721975875630714513, Accuracy: 0.00
# Subject: 191360775943194451169196340984054399550, Accuracy: 0.00
# Subject: 77428803254134998092824986488981871994, Accuracy: 1.00
# Subject: 46657542496997477966490146746124905250, Accuracy: 1.00
# Subject: 286992898400087581405015992557702572150, Accuracy: 0.00
# Subject: 84737541056202964389142359315202158934, Accuracy: 1.00
# Subject: 297635308447967734809253098814588901263, Accuracy: 0.00
# Subject: 132209494129050971515328649837601507448, Accuracy: 0.00
# Subject: 75047507063991609500738433808819571673, Accuracy: 0.00
# Subject: 69591887887134192948829421726744172269, Accuracy: 1.00
# Subject: 330963081336627755835529717053442348541, Accuracy: 0.00
# Subject: 193475718750275626735054712002790632542, Accuracy: 1.00
# Subject: 282604893328248088209225847430647813573, Accuracy: 0.00
# Subject: 167003820761625356177288269402121425707, Accuracy: 1.00
# Subject: 313654511016966003796809988664334862184, Accuracy: 0.00
# Subject: 161477850179666120015696119837108848069, Accuracy: 1.00
# Subject: 142333782898743498520691807574107652747, Accuracy: 0.00
# Subject: 314034045907054885400165735931939789247, Accuracy: 0.00
# Subject: 140319194873675145452985058009342670341, Accuracy: 1.00
# Subject: 295633366458656626799641335525548613570, Accuracy: 0.00
# Subject: 245709246373688299677462300699010035587, Accuracy: 1.00
# Subject: 96220036608250377551390929500423578615, Accuracy: 1.00
# Subject: 177893884182876632474140723566972872966, Accuracy: 1.00
# Subject: 329266429109223192841984307055553270929, Accuracy: 0.00
# Subject: 126170832791775280770532478941287608212, Accuracy: 0.00
# Subject: 99385955208441366061286684978591209044, Accuracy: 1.00
# Subject: 14994278066123261838997543054394279507, Accuracy: 1.00
# Subject: 100253109100344226651211334387380002481, Accuracy: 1.00
# Subject: 68240617007739236531833329101102234412, Accuracy: 1.00
# Subject: 21497201702158295203790207308919261939, Accuracy: 1.00
# Subject: 143601126869005826423555491097044489935, Accuracy: 1.00
# Subject: 309000391195502937138546655424849717518, Accuracy: 0.83
# Subject: 36624313595758016695641556876575440765, Accuracy: 0.00
# Subject: 218709976066868486528324196573480047800, Accuracy: 0.00
# Subject: 336438027660049617510959378070596472097, Accuracy: 1.00
# Subject: 294737205009271235820121204148504277021, Accuracy: 1.00
# Subject: 128317116583089554602562665360226229321, Accuracy: 1.00
# Subject: 110161370178529976028120340597458580821, Accuracy: 0.00
# Subject: 27384113139794060774257569632727978954, Accuracy: 1.00
# Subject: 41788758688050513881956557498658905599, Accuracy: 0.00
# Subject: 247974914479780218470720831424827294737, Accuracy: 1.00
# Subject: 300795196818106981129062473256888166050, Accuracy: 1.00
# Subject: 56099145895561546925186384714104526912, Accuracy: 0.00
# Subject: 301654629743095236754021889037892066847, Accuracy: 0.00
# Subject: 169245413571916393789952686809364669615, Accuracy: 0.00
# Subject: 73294041557433943997927635060952902769, Accuracy: 1.00
# Subject: 248322071472985981630892450583315449660, Accuracy: 1.00
# Subject: 208531144402009771658308455178863520020, Accuracy: 0.00
# Subject: 9421273830420760043311072508536033657, Accuracy: 0.00
# Subject: 96953071888897865000881666795917059639, Accuracy: 0.00
# Subject: 74676610303512588309975630864179375703, Accuracy: 0.60
# Subject: 277321838551377480536580976040868399935, Accuracy: 1.00
# Subject: 127618336275786426563637065140013919798, Accuracy: 1.00
# Subject: 233899353621199828490979403945204234829, Accuracy: 1.00
# Subject: 144730453347578389629982372049373705933, Accuracy: 0.00
# Subject: 79607384054796034879474504528818320374, Accuracy: 1.00
# Subject: 257118737742800810450979725369064899269, Accuracy: 0.00
# Subject: 8723806117798315608223747949420072126, Accuracy: 0.00
# Subject: 159456317318385784752402571381888174647, Accuracy: 1.00
# Subject: 142378190264254162529163290567549841427, Accuracy: 0.00
# Subject: 265972501962807306701755900976515522537, Accuracy: 0.00
# Subject: 262125641357055355562730650708875843490, Accuracy: 0.00
# Subject: 94361243232128478657327008148075453476, Accuracy: 1.00
# Subject: 179914790667295564318715575582224783058, Accuracy: 1.00
# Subject: 217489778373101432839240252002542972060, Accuracy: 0.00
# Subject: fdd1c76c-0377-a8a7-8da8-1be5740a9807, Accuracy: 1.00
# Subject: 2b4679a1-d317-67e1-e1a6-41fce7354fbf, Accuracy: 0.93
# Subject: 96eb0bb4-be38-dbc9-b4b3-b225010b162c, Accuracy: 0.03
# Subject: 8623724d-1fdb-8058-4206-38f8c15fcdbc, Accuracy: 1.00
# Subject: bc729999-f0c4-8e74-359b-2f7a9957d391, Accuracy: 1.00
# Subject: 2c7873d6-7f15-af8c-c1e6-d723565d9cdc, Accuracy: 1.00
# Subject: 41d7ea36-d828-b4a4-b622-20e3ba414a20, Accuracy: 0.17
# Subject: 82b64345-89a0-207c-8371-34c07935760a, Accuracy: 1.00
# Subject: d1605e67-a616-bfeb-5776-8672dd979bc8, Accuracy: 0.03
# Subject: 242f97c9-80cb-fee1-feb7-3341bc9bb347, Accuracy: 0.93
# Subject: a2e550cb-4f1f-d675-71bf-ffb58b9611f6, Accuracy: 1.00
# Subject: 99151b13-02cd-0a17-e176-0dd4d44b9714, Accuracy: 1.00
# Subject: 245546b8-6c0e-6887-02ff-09a9d6cb4310, Accuracy: 1.00
# Subject: 7e0d073a-5070-d163-040d-7da2d1af9026, Accuracy: 0.00
# Subject: 2992216d-a0f6-1712-2c27-c0c1323a1652, Accuracy: 0.00
# Subject: 34034597-7268-211e-a82a-ee5f958e641a, Accuracy: 0.00
# Subject: e8470455-6531-c287-ce81-e251f504768f, Accuracy: 0.00
# Subject: d5a56aab-df0d-d42b-d74e-647ce539924f, Accuracy: 0.00
# Subject: ed718921-8bc0-71f8-c9bb-8ce3ee322ee3, Accuracy: 0.00
# Subject: db303fac-a216-c949-5f32-8f02f6e29c52, Accuracy: 1.00
# Subject: 2732c252-46a6-fe82-6341-1a2a43f8d657, Accuracy: 1.00
# Subject: 92145824-ff7e-be24-e815-a64e899f38e1, Accuracy: 1.00
# Subject: 01a5e460-0607-38a6-b5ce-7f124b969222, Accuracy: 1.00
# Subject: 15734937-3410-57f6-3cc3-d1d32e9138c5, Accuracy: 1.00
# Subject: 18c05426-dbb4-adab-607c-ae88d99bfc89, Accuracy: 1.00
# subject accuracy: 0.56
#
# Test for Positive subjects:
# Subject: 138681313570679646396533197328690174535, Accuracy: 1.00
# Subject: 82498448730405369670702745834853438447, Accuracy: 1.00
# Subject: 70055199254646997137347024168883235522, Accuracy: 1.00
# Subject: 85636101400926141949023704298355735329, Accuracy: 1.00
# Subject: 155974903198249598985226345893460192954, Accuracy: 0.00
# Subject: 89015086248227340322450177808302591267, Accuracy: 0.00
# Subject: 320959423528186916134905550043948948343, Accuracy: 0.00
# Subject: 156837674528439857628122970322463736207, Accuracy: 1.00
# Subject: 267367809881025707024976950419478664556, Accuracy: 0.00
# Subject: 239647154274298628704040953626647006831, Accuracy: 0.00
# Subject: 193719296216095512478745018452760902713, Accuracy: 0.00
# Subject: 85368278269151765477300734597278915014, Accuracy: 0.00
# Subject: 144111508360023855671272150765716605222, Accuracy: 1.00
# Subject: 235597310868064052825270017933329446492, Accuracy: 1.00
# Subject: 13055000144067068623933972187234756394, Accuracy: 1.00
# Subject: 191820077183087381850956733957693807622, Accuracy: 1.00
# Subject: 204845103038116484980557716970136113388, Accuracy: 1.00
# Subject: 97791393575067170943452115433796349604, Accuracy: 0.00
# Subject: 212470578945876153547494938303382282800, Accuracy: 1.00
# Subject: 206254331785533830049315502542703478728, Accuracy: 1.00
# Subject: 255383028215169739599801628334229912338, Accuracy: 1.00
# Subject: 321272373820850313127332660512670140611, Accuracy: 0.00
# Subject: 73166992386845156057007771705501841871, Accuracy: 0.05
# Subject: 299049487973253671876447320174369050262, Accuracy: 1.00
# Subject: 16612114337599212982788828505052133231, Accuracy: 1.00
# Subject: 234997182067407201948214616328035260248, Accuracy: 0.00
# Subject: 317331903178978258022589657654555103278, Accuracy: 0.00
# Subject: 34931901663861718465798076820184660214, Accuracy: 1.00
# Subject: 71016560535034829410295386640763850032, Accuracy: 1.00
# Subject: 223966184619010141064281599959431460852, Accuracy: 0.00
# Subject: 49103409560515323249196705066033094450, Accuracy: 0.00
# Subject: 8285329549026344726723545818313561637, Accuracy: 1.00
# Subject: 112368478457110397448789952721833869236, Accuracy: 0.00
# Subject: 273512605354803979690673146709274550290, Accuracy: 1.00
# Subject: 156275748956021813065044996784968531790, Accuracy: 0.00
# Subject: 49652182019910863950272610697424552312, Accuracy: 0.00
# Subject: 78395221887903160869825619296363305785, Accuracy: 1.00
# Subject: 121548899930842848751312663779363262996, Accuracy: 1.00
# Subject: 84178952275838621849805119577871294912, Accuracy: 1.00
# Subject: 50870569433662547424976446803687306459, Accuracy: 1.00
# Subject: 16188876798564746412584684539374840092, Accuracy: 1.00
# Subject: 118388850650277315092296183437132290088, Accuracy: 0.00
# Subject: 122305803263178726728493960919715942514, Accuracy: 1.00
# Subject: 322935917736529070732062674677811796298, Accuracy: 1.00
# Subject: 37771404770360656757160133539357421144, Accuracy: 0.00
# Subject: 228760749467426179810384564148985759627, Accuracy: 0.00
# Subject: 283668670222861358895224925988118005202, Accuracy: 0.00
# Subject: 182350189608783495035342964872538076153, Accuracy: 1.00
# Subject: 52077102503621286583016980035109038061, Accuracy: 0.50
# Subject: 48398204386767901130074413010766121894, Accuracy: 0.00
# Subject: 151752082913064155331664666692946928764, Accuracy: 0.00
# Subject: 20757663043634913234864113012427467166, Accuracy: 1.00
# Subject: 242728686966373925850490808462680117185, Accuracy: 1.00
# Subject: 28378669234658138342196963709044529563, Accuracy: 1.00
# Subject: 336397792234371190811165460444253997013, Accuracy: 1.00
# Subject: 173921082610526810047850791425882581771, Accuracy: 1.00
# Subject: 111029221338992223315989889972047868487, Accuracy: 1.00
# Subject: 148595015854490470569560959720178473245, Accuracy: 1.00
# Subject: 184231884339909973526914936683309815104, Accuracy: 1.00
# Subject: 169726882416958308536333969983756283138, Accuracy: 0.00
# Subject: 68441290796842721766948350085075790448, Accuracy: 0.00
# Subject: 197315460719593550396353596063872025641, Accuracy: 0.00
# Subject: 333369095763755574065712150852028233455, Accuracy: 1.00
# Subject: 166367831716388484489520561437010640306, Accuracy: 0.00
# Subject: 114101291666208803023644507678911914760, Accuracy: 0.00
# Subject: 12127779151939630777631201115596615400, Accuracy: 0.00
# Subject: 3302264511463213255896606730625538305, Accuracy: 1.00
# Subject: 279713686520327747703764314994584485312, Accuracy: 0.00
# Subject: 293722985553091477959065716570706656057, Accuracy: 0.00
# Subject: 19129752819397524225040191809645716293, Accuracy: 1.00
# Subject: 209451997226186821758748255081570927830, Accuracy: 1.00
# Subject: 319997953469040599793122241139270350702, Accuracy: 0.00
# Subject: 147359196293566602169362260165807304353, Accuracy: 1.00
# Subject: 38105743318352501687305527474372327912, Accuracy: 1.00
# Subject: 3390830934956738620136635612564212472, Accuracy: 0.00
# Subject: 331113928004700519808917015039199286386, Accuracy: 0.05
# Subject: 176116784174061127794093474409481059254, Accuracy: 0.00
# Subject: 286764101343456992463975864443998370587, Accuracy: 1.00
# Subject: 167778883336781991485772339526777662430, Accuracy: 1.00
# Subject: 305168249340957441687910764346933734667, Accuracy: 1.00
# Subject: 12840212086979211206628123494698476504, Accuracy: 0.00
# Subject: 238900776150856601236907513542305529524, Accuracy: 1.00
# Subject: 248745867043481860061400522592757429141, Accuracy: 1.00
# Subject: 3090578306455859195973259924928164372, Accuracy: 1.00
# Subject: 237822312245693663368688006052242429787, Accuracy: 1.00
# Subject: 197445289474166971856388996004689014191, Accuracy: 1.00
# Subject: 310218794756317037191347690470405405168, Accuracy: 0.00
# Subject: 236294909131969157867605361878614042562, Accuracy: 0.00
# Subject: 317532430221552434669186273018041592902, Accuracy: 1.00
# Subject: 339322724187443127112522868306539161010, Accuracy: 0.00
# Subject: 141096633147123293564305683757951918737, Accuracy: 1.00
# Subject: 68415645908804877552921659854931880952, Accuracy: 1.00
# Subject: 270887533756973472376441335892518057033, Accuracy: 0.20
# Subject: 66883352438405515203389903841888282980, Accuracy: 0.00
# Subject: 23205074593279052134046953709489087251, Accuracy: 1.00
# Subject: 242056222106185540754324652621961959456, Accuracy: 1.00
# Subject: 299252821111888185972955829864288861861, Accuracy: 1.00
# Subject: 291817641151347512750847780043245117786, Accuracy: 0.00
# Subject: 135896756116938088009570582069601649255, Accuracy: 1.00
# Subject: 169081970761154957120178502312935114059, Accuracy: 1.00
# Subject: 54859675454042600195622274479907726546, Accuracy: 1.00
# Subject: 141937329779245333917023400406363238989, Accuracy: 0.05
# Subject: 102893678352271687868826902246387286299, Accuracy: 0.05
# Subject: 65157796530199877103172143713024456592, Accuracy: 1.00
# Subject: 188013775559290409209344422154340844028, Accuracy: 0.30
# Subject: 80575571060641279042901204877627252558, Accuracy: 1.00
# Subject: 316034713100539083740790895413161267739, Accuracy: 1.00
# Subject: 35676858906437917172776202816157612798, Accuracy: 0.00
# Subject: 146064041238557010788186948233088969104, Accuracy: 0.00
# Subject: 53432263590786069539548595940834778143, Accuracy: 1.00
# Subject: 11161087957123078188422325860062954608, Accuracy: 0.00
# Subject: 152416903674534510578726275974630000963, Accuracy: 1.00
# Subject: 288968753257607227939769941103185695362, Accuracy: 1.00
# Subject: 128323984464808208303504286338275258603, Accuracy: 1.00
# Subject: 330708417614699062689789714196123612272, Accuracy: 0.00
# Subject: 256949851016219061519144710517706888038, Accuracy: 1.00
# Subject: 149769079249044175718542947961906074174, Accuracy: 0.00
# Subject: 117079359035474074690365417557946048086, Accuracy: 0.00
# Subject: 121570624448964156250577598848516111142, Accuracy: 1.00
# Subject: 304283173309091343875872021067570300854, Accuracy: 0.00
# Subject: 306190386540638049114031574559895939729, Accuracy: 1.00
# Subject: 47155295106343825763989534008758209376, Accuracy: 0.00
# Subject: 244837623397725739033827989374034931563, Accuracy: 1.00
# Subject: 6540170531091209213247532411020438917, Accuracy: 1.00
# Subject: 170260898199865331516942901649175797899, Accuracy: 1.00
# Subject: 24224661950343654525822317389000396758, Accuracy: 0.00
# Subject: 78460094672176268648341182229569409885, Accuracy: 0.00
# Subject: 18214877318401113801837311477727763289, Accuracy: 0.00
# Subject: 82021857307461782491499562936350476465, Accuracy: 1.00
# Subject: 152232565392510054308847219623864287317, Accuracy: 0.00
# Subject: 291532865606838649685248811120276566576, Accuracy: 0.00
# Subject: 182500516767200798258395644582570054817, Accuracy: 1.00
# Subject: 180745759199479264532511978473906503851, Accuracy: 0.00
# Subject: 124318003077138137545570561290815990639, Accuracy: 0.00
# Subject: 294885878575100370227534925114066149468, Accuracy: 1.00
# Subject: 93662820189211795719680984402174453884, Accuracy: 1.00
# Subject: 138088406774515365533553516408921425393, Accuracy: 0.00
# Subject: 166982303707982007051928380408208812756, Accuracy: 0.00
# Subject: 2095522444768535858586342343882057465, Accuracy: 1.00
# Subject: 181111116088821967589334728562514270873, Accuracy: 0.14
# Subject: 260240317803029213106837561979534456162, Accuracy: 1.00
# Subject: 287193774137046830846299820689671912262, Accuracy: 1.00
# Subject: 6009035266745465739540991066413956998, Accuracy: 1.00
# Subject: 209074174445323518467115471844887650404, Accuracy: 0.00
# Subject: 122622512121837136229847012710705529979, Accuracy: 0.00
# Subject: 295048404300263447910443892159201485946, Accuracy: 1.00
# Subject: 218793485769776969124501711306136315469, Accuracy: 1.00
# Subject: 639172527045195363287108778219712510, Accuracy: 1.00
# Subject: 113944072194837765400816116086180275264, Accuracy: 1.00
# Subject: 35301612054817462747500173124369716352, Accuracy: 0.00
# Subject: 111193710922326470738798863442907269378, Accuracy: 1.00
# Subject: 23916555334375718433822687275242407999, Accuracy: 0.00
# Subject: 329999035806196665900603236514873441447, Accuracy: 1.00
# Subject: 53925216174340312919435862714894548735, Accuracy: 1.00
# Subject: 116653212415901981538518364005483413701, Accuracy: 1.00
# Subject: 166133250285908503164484604416802963171, Accuracy: 0.00
# Subject: 40646817068026815481891272868189762498, Accuracy: 1.00
# Subject: 46592d2c-7cd9-ebe8-7746-3ccff2c5329e, Accuracy: 0.98
# Subject: b93b3974-780d-3e7a-fa30-90f642df571d, Accuracy: 1.00
# Subject: 7036f895-20f6-3156-51a6-5d19cab15bf7, Accuracy: 1.00
# Subject: af4b7b1a-bf43-0f0d-3e5b-b8a762a430af, Accuracy: 0.00
# Subject: 16a823bf-b6b5-6690-6969-bcd7f441c044, Accuracy: 1.00
# Subject: aacd119d-a02c-2361-78b4-e0eb20d95b0c, Accuracy: 0.14
# Subject: e14df6ca-28de-8c8f-a68e-602597901013, Accuracy: 0.00
# Subject: 00655d01-28c6-c69c-260f-7dff23f8eeea, Accuracy: 0.00
# Subject: c800db5b-29ad-7bd6-f7d8-d7c2c387022e, Accuracy: 0.00
# Subject: 568530e1-56cc-baea-3128-1b4ee0cc633c, Accuracy: 0.92
# Subject: 63397c94-9d63-ac1f-b96b-9c9c380f3f99, Accuracy: 1.00
# Subject: 761b0d7b-2257-50d7-2ae8-5b8bdcf61b87, Accuracy: 0.00
# Subject: 3a4d5112-7df3-b354-6445-cf5ba04de94f, Accuracy: 1.00
# Subject: 7480d1ea-2c43-2dfb-bc96-cc19f42892c8, Accuracy: 1.00
# Subject: 0b4a2989-c884-70ad-2795-437e43073dad, Accuracy: 0.89
# subject accuracy: 0.57
