# %%
import os
import pandas as pd
import sys
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from datetime import datetime
from torch.utils.data import Dataset, DataLoader

sys.path.append(os.path.join(os.getcwd(), '../../common'))
from ppg_feature_processor import map_gender

# %%
# 获取当前日期
current_date = datetime.now().strftime("%Y-%m-%d")

# 构建导出的pth文件名以及ONNX文件名
outdir = 'outdir'
pth_file_path = os.path.join(outdir, f'ppg_anxiety-best_model_{current_date}.pth')
onnx_file_path = os.path.join(outdir, f"ppg_anxiety-best_model_{current_date}.onnx")

# %%
profile_columns = ['wave_quality', 'age', 'gender', 'label', 'id']

# %%
# # ---------------------------- 数据预处理 ----------------------------
# def map_age(age):
#     if age < 16:
#         return [1, 0, 0, 0]
#     elif age >= 16 and age <= 18:
#         return [0, 1, 0, 0]

#     elif age > 18 and age < 25:
#         return [0, 0, 1, 0]
#     elif age >= 25:
#         return [0, 0, 0, 1] 

# ---------------------------- 数据预处理 ----------------------------

def preprocess(df):
    df_new = df.copy()
    # df_new[['age_0', 'age_1', 'age_2', 'age_3']] = df_new['age'].apply(map_age).apply(pd.Series)
    df_new[['gender_0', 'gender_1']] = df_new['gender'].apply(map_gender).apply(pd.Series)
    return df_new.drop(profile_columns, axis=1)

# 加载数据
train_pos_dataset = pd.read_pickle('./samples/train_pos_dataset.pkl')
train_neg_dataset = pd.read_pickle('./samples/train_neg_dataset.pkl')
test_pos_dataset = pd.read_pickle('./samples/test_pos_dataset.pkl')
test_neg_dataset = pd.read_pickle('./samples/test_neg_dataset.pkl')

# 应用预处理
train_pos_features = preprocess(train_pos_dataset)
train_neg_features = preprocess(train_neg_dataset)
test_pos_features = preprocess(test_pos_dataset)
test_neg_features = preprocess(test_neg_dataset)

# %%
print(train_pos_dataset.columns)

print(train_pos_features.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_HF', 'HRV_VHF',
#        'HRV_TP', 'HRV_HFn', 'HRV_LnHF', 'wave_quality', 'label', 'id', 'age',
#        'gender'],
#       dtype='object')
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_HF', 'HRV_VHF',
#        'HRV_TP', 'HRV_HFn', 'HRV_LnHF', 'gender_0', 'gender_1'],
#       dtype='object')

# %%
# ---------------------------- DNN 模型 ----------------------------

class DNNModel(nn.Module):
    def __init__(self, input_dim):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.relu = nn.ReLU()
        self.dropOut = nn.Dropout(0.5)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropOut(x)
        x = self.relu(self.fc2(x))
        x = self.dropOut(x)
        x = self.sigmoid(self.fc3(x))
        return x

input_dim = train_pos_features.shape[1]
model = DNNModel(input_dim)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# ---------------------------- 自定义数据加载器 ----------------------------

class BalancedDataset(Dataset):
    def __init__(self, pos_data, neg_data):
        self.pos_data = pos_data
        self.neg_data = neg_data
        self.pos_len = len(pos_data)
        self.neg_len = len(neg_data)

    def __len__(self):
        return min(self.pos_len, self.neg_len)

    def __getitem__(self, idx):
        pos_idx = np.random.randint(0, self.pos_len)
        neg_idx = np.random.randint(0, self.neg_len)
        
        pos_sample = self.pos_data.iloc[pos_idx].values.astype(np.float32)
        neg_sample = self.neg_data.iloc[neg_idx].values.astype(np.float32)

        X = np.vstack([pos_sample, neg_sample])
        y = np.array([1, 0], dtype=np.float32)

        return torch.tensor(X), torch.tensor(y)

class TestDataset(Dataset):
    def __init__(self, pos_data, neg_data):
        self.pos_data = pos_data
        self.neg_data = neg_data
        self.pos_len = len(pos_data)
        self.neg_len = len(neg_data)

    def __len__(self):
        return self.pos_len + self.neg_len

    def __getitem__(self, idx):
        if idx < self.pos_len:
            sample = self.pos_data.iloc[idx].values.astype(np.float32)
            label = 1
        else:
            idx -= self.pos_len
            sample = self.neg_data.iloc[idx].values.astype(np.float32)
            label = 0
        
        return torch.tensor(sample), torch.tensor(label, dtype=torch.float32)

# 初始化数据集和数据加载器
batch_size = 64
train_dataset = BalancedDataset(train_pos_features, train_neg_features)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = TestDataset(test_pos_features, test_neg_features)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# ---------------------------- 模型训练 ----------------------------

num_epochs = 500
train_losses = []
test_accuracies = []

def evaluate_model(model, data_loader):
    model.eval()  # 设置模型为评估模式
    pos_correct = 0
    neg_correct = 0
    pos_total = 0
    neg_total = 0

    with torch.no_grad():  # 关闭梯度计算
        for inputs, labels in data_loader:
            outputs = model(inputs)
            predicted = (outputs.squeeze() >= 0.5).float()

            # print(f"predicted: {predicted}")
            # Calculate accuracy for positive and negative samples
            pos_mask = (labels == 1).float()
            neg_mask = (labels == 0).float()
            pos_correct += ((predicted == labels) * pos_mask).sum().item()
            neg_correct += ((predicted == labels) * neg_mask).sum().item()
            pos_total += pos_mask.sum().item()
            neg_total += neg_mask.sum().item()
            

    pos_accuracy = pos_correct / pos_total if pos_total > 0 else 0
    neg_accuracy = neg_correct / neg_total if neg_total > 0 else 0
    return pos_accuracy, neg_accuracy, (pos_correct+neg_correct) / (pos_total + neg_total)


best_accuracy = 0.0
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), labels)
        epoch_loss += loss.item()

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accuracy calculation
        predicted = (outputs.squeeze() > 0.5).float()
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    # Calculate average loss and accuracy for the epoch
    avg_loss = epoch_loss / len(train_loader)
    avg_accuracy = correct / total
    train_losses.append(avg_loss)
    
    # Evaluate on test set
    pos_accuracy, neg_accuracy, accuracy = evaluate_model(model, test_loader)
    test_accuracies.append(accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Avg Accuracy: {accuracy},  Positive Accuracy: {pos_accuracy * 100:.2f}%, Negative Accuracy: {neg_accuracy * 100:.2f}%')

    # Save the best model
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        torch.save(model.state_dict(), pth_file_path)
        print("Best Accuracy Model: {}".format(best_accuracy))

        # Export the best model to ONNX
        dummy_input = torch.randn(1, input_dim)
        torch.onnx.export(model, dummy_input, onnx_file_path, input_names=['input'], output_names=['output'])
    

# ---------------------------- 绘制训练曲线 ----------------------------

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Curve')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), [acc * 100 for acc in test_accuracies], marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Testing Accuracy Curve')

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/500], Loss: 0.6868, Avg Accuracy: 0.44155844155844154,  Positive Accuracy: 8.33%, Negative Accuracy: 75.61%
# Best Accuracy Model: 0.44155844155844154
# Epoch [2/500], Loss: 0.6822, Avg Accuracy: 0.4155844155844156,  Positive Accuracy: 33.33%, Negative Accuracy: 48.78%
# Epoch [3/500], Loss: 0.6788, Avg Accuracy: 0.4025974025974026,  Positive Accuracy: 36.11%, Negative Accuracy: 43.90%
# Epoch [4/500], Loss: 0.6758, Avg Accuracy: 0.42857142857142855,  Positive Accuracy: 38.89%, Negative Accuracy: 46.34%
# Epoch [5/500], Loss: 0.6641, Avg Accuracy: 0.4025974025974026,  Positive Accuracy: 33.33%, Negative Accuracy: 46.34%
# Epoch [6/500], Loss: 0.6515, Avg Accuracy: 0.4025974025974026,  Positive Accuracy: 33.33%, Negative Accuracy: 46.34%
# Epoch [7/500], Loss: 0.6479, Avg Accuracy: 0.4025974025974026,  Positive Accuracy: 33.33%, Negative Accuracy: 46.34%
# Epoch [8/500], Loss: 0.6535, Avg Accuracy: 0.38961038961038963,  Positive Accuracy:
Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [441/500], Loss: 0.4591, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [442/500], Loss: 0.4712, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [443/500], Loss: 0.4704, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [444/500], Loss: 0.4784, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [445/500], Loss: 0.4723, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [446/500], Loss: 0.4738, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [447/500], Loss: 0.4818, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [448/500], Loss: 0.4664, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [449/500], Loss: 0.4616, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [450/500], Loss: 0.4986, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [451/500], Loss: 0.4733, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [452/500], Loss: 0.4719, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [453/500], Loss: 0.4792, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [454/500], Loss: 0.4770, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [455/500], Loss: 0.4686, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [456/500], Loss: 0.4866, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [457/500], Loss: 0.4773, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [458/500], Loss: 0.4881, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [459/500], Loss: 0.4797, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [460/500], Loss: 0.4807, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [461/500], Loss: 0.4496, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [462/500], Loss: 0.4481, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [463/500], Loss: 0.4543, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [464/500], Loss: 0.4655, Avg Accuracy: 0.4025974025974026,  Positive Accuracy: 11.11%, Negative Accuracy: 65.85%
# Epoch [465/500], Loss: 0.4695, Avg Accuracy: 0.4025974025974026,  Positive Accuracy: 11.11%, Negative Accuracy: 65.85%
# Epoch [466/500], Loss: 0.4953, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [467/500], Loss: 0.4605, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [468/500], Loss: 0.4432, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [469/500], Loss: 0.4640, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [470/500], Loss: 0.4749, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [471/500], Loss: 0.4642, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [472/500], Loss: 0.4740, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [473/500], Loss: 0.4701, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [474/500], Loss: 0.4526, Avg Accuracy: 0.4025974025974026,  Positive Accuracy: 11.11%, Negative Accuracy: 65.85%
# Epoch [475/500], Loss: 0.4666, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 13.89%, Negative Accuracy: 60.98%
# Epoch [476/500], Loss: 0.4942, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 13.89%, Negative Accuracy: 60.98%
# Epoch [477/500], Loss: 0.4513, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [478/500], Loss: 0.4941, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [479/500], Loss: 0.4613, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [480/500], Loss: 0.4536, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 13.89%, Negative Accuracy: 60.98%
# Epoch [481/500], Loss: 0.4446, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 13.89%, Negative Accuracy: 60.98%
# Epoch [482/500], Loss: 0.4835, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [483/500], Loss: 0.4710, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [484/500], Loss: 0.4803, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [485/500], Loss: 0.4482, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [486/500], Loss: 0.4668, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [487/500], Loss: 0.4473, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [488/500], Loss: 0.4864, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [489/500], Loss: 0.4615, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [490/500], Loss: 0.4787, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [491/500], Loss: 0.4963, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [492/500], Loss: 0.4612, Avg Accuracy: 0.36363636363636365,  Positive Accuracy: 11.11%, Negative Accuracy: 58.54%
# Epoch [493/500], Loss: 0.4728, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [494/500], Loss: 0.4343, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [495/500], Loss: 0.4746, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [496/500], Loss: 0.4798, Avg Accuracy: 0.38961038961038963,  Positive Accuracy: 11.11%, Negative Accuracy: 63.41%
# Epoch [497/500], Loss: 0.4440, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [498/500], Loss: 0.4734, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [499/500], Loss: 0.4715, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%
# Epoch [500/500], Loss: 0.4592, Avg Accuracy: 0.37662337662337664,  Positive Accuracy: 11.11%, Negative Accuracy: 60.98%

# %%
import glob
import glob
import numpy as np
import onnxruntime as ort

from collections import defaultdict

# %%
print(test_pos_dataset.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_HF', 'HRV_VHF',
#        'HRV_TP', 'HRV_HFn', 'HRV_LnHF', 'wave_quality', 'label', 'id', 'age',
#        'gender'],
#       dtype='object')

# %%
import enum


def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    # 如果找到的文件不为空
    if onnx_files:
        # 按文件名排序
        onnx_files.sort()

        # 选择最后一个文件
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    if onnx_files:
        onnx_files.sort()
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
ort_session = ort.InferenceSession(onnx_model_path)

# 预测函数
def predict(features):
    inputs = {ort_session.get_inputs()[0].name: features}
    outputs = ort_session.run(None, inputs)
    return outputs[0]

for idx, pair_data in enumerate([[test_neg_dataset, test_neg_features], [test_pos_dataset, test_pos_features]]):
    if idx == 0:
        print("\nTest for Negative subjects:")
    else:
        print("\nTest for Positive subjects:")

    # 加载测试数据集
    # 计算每个 subject 的准确率
    subject_results = defaultdict(list)

    for (_, row_dataset), (_, features), in zip(pair_data[0].iterrows(), pair_data[1].iterrows()):
        subject = row_dataset['id']
        label = row_dataset['label']

        features = np.array(features, dtype=np.float32)  # 确保 features 的数据类型与模型输入匹配
        features = features.reshape(1, -1)  # 调整形状以匹配模型输入
        prediction = predict(features)
        predicted_label = (prediction >= 0.5).astype(int)  # 使用阈值 0.5 将预测概率转换为类标签
        subject_results[subject].append((predicted_label, label))

    subject_accuracies = {}
    for subject, results in subject_results.items():
        correct = sum(1 for pred, label in results if pred == label)
        accuracy = correct / len(results)
        subject_accuracies[subject] = accuracy

    # 输出每个 subject 的准确度
    correct_count = 0
    for subject, accuracy in subject_accuracies.items():
        print(f'Subject: {subject}, Accuracy: {accuracy:.2f}')
        if accuracy > 0.5:
            correct_count += 1
        elif accuracy == 0.5:
            correct_count += 0.5
    print(f"subject accuracy: {(correct_count / len(subject_accuracies)):.2f}")
# Out:
# Test for Negative subjects:
# Subject: 75047507063991609500738433808819571673, Accuracy: 1.00
# Subject: 95761494257721479533125487182722112566, Accuracy: 1.00
# Subject: 141906085562194353137386602945104356379, Accuracy: 1.00
# Subject: 41788758688050513881956557498658905599, Accuracy: 0.80
# Subject: 162605572782799812941958232855498162671, Accuracy: 0.40
# Subject: 47862737607272227529163978988231672324, Accuracy: 0.25
# Subject: 193475718750275626735054712002790632542, Accuracy: 1.00
# Subject: 328979043108500441381507934447150040192, Accuracy: 1.00
# Subject: 177893884182876632474140723566972872966, Accuracy: 1.00
# Subject: 56099145895561546925186384714104526912, Accuracy: 0.40
# Subject: 245709246373688299677462300699010035587, Accuracy: 1.00
# Subject: 21497201702158295203790207308919261939, Accuracy: 1.00
# Subject: 110161370178529976028120340597458580821, Accuracy: 1.00
# subject accuracy: 0.77
#
# Test for Positive subjects:
# Subject: 82498448730405369670702745834853438447, Accuracy: 0.50
# Subject: 339322724187443127112522868306539161010, Accuracy: 0.00
# Subject: 169726882416958308536333969983756283138, Accuracy: 0.00
# Subject: 182500516767200798258395644582570054817, Accuracy: 0.20
# Subject: 244837623397725739033827989374034931563, Accuracy: 0.33
# Subject: 291532865606838649685248811120276566576, Accuracy: 0.00
# Subject: 68441290796842721766948350085075790448, Accuracy: 0.00
# Subject: 239647154274298628704040953626647006831, Accuracy: 0.00
# Subject: 149769079249044175718542947961906074174, Accuracy: 0.00
# Subject: 256949851016219061519144710517706888038, Accuracy: 0.00
# Subject: 291817641151347512750847780043245117786, Accuracy: 0.00
# Subject: 48398204386767901130074413010766121894, Accuracy: 0.00
# subject accuracy: 0.04
