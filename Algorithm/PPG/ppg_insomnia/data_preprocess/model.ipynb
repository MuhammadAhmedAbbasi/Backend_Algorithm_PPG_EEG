# %%
import os
import pandas as pd
import sys
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from datetime import datetime
from torch.utils.data import Dataset, DataLoader

sys.path.append(os.path.join(os.getcwd(), '../common'))
from ppg_feature_processor import map_gender, map_age

# %%
# 获取当前日期
current_date = datetime.now().strftime("%Y-%m-%d")
# 构建导出的pth文件名以及ONNX文件名

outdir = 'outdir'
pth_file_path = os.path.join(outdir, f'ppg_sleep-best_model_{current_date}.pth')
onnx_file_path = os.path.join(outdir, f"ppg_sleep-best_model_{current_date}.onnx")

# %%
profile_columns = ['wave_quality', 'age', 'gender', 'label', 'id']

# %%
# # ---------------------------- 数据预处理 ----------------------------
def map_age(age):
    if age < 14:
        return [1, 0]
    elif age >= 14:
        return [0, 1]

# ---------------------------- 数据预处理 ----------------------------

def preprocess(df):
    df_new = df.copy()
    df_new[['age_0', 'age_1']] = df_new['age'].apply(map_age).apply(pd.Series)
    df_new[['gender_0', 'gender_1']] = df_new['gender'].apply(map_gender).apply(pd.Series)
    return df_new.drop(profile_columns, axis=1)

# 加载数据
train_pos_dataset = pd.read_pickle('./samples/train_pos_dataset.pkl')
train_neg_dataset = pd.read_pickle('./samples/train_neg_dataset.pkl')
val_pos_dataset = pd.read_pickle('./samples/val_pos_dataset.pkl')
val_neg_dataset = pd.read_pickle('./samples/val_neg_dataset.pkl')
test_pos_dataset = pd.read_pickle('./samples/test_pos_dataset.pkl')
test_neg_dataset = pd.read_pickle('./samples/test_neg_dataset.pkl')

# 应用预处理
train_pos_features = preprocess(train_pos_dataset)
train_neg_features = preprocess(train_neg_dataset)
val_pos_features = preprocess(val_pos_dataset)
val_neg_features = preprocess(val_neg_dataset)
test_pos_features = preprocess(test_pos_dataset)
test_neg_features = preprocess(test_neg_dataset)

# %%
print(train_pos_dataset.columns)

print(train_pos_features.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_HF', 'HRV_VHF',
#        'HRV_TP', 'HRV_HFn', 'HRV_LnHF', 'wave_quality', 'label', 'id', 'age',
#        'gender'],
#       dtype='object')
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_HF', 'HRV_VHF',
#        'HRV_TP', 'HRV_HFn', 'HRV_LnHF', 'age_0', 'age_1', 'gender_0',
#        'gender_1'],
#       dtype='object')

# %%
# ---------------------------- DNN 模型 ----------------------------

class DNNModel(nn.Module):
    def __init__(self, input_dim):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.relu = nn.ReLU()
        self.dropOut = nn.Dropout(0.5)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropOut(x)
        x = self.relu(self.fc2(x))
        x = self.dropOut(x)
        x = self.sigmoid(self.fc3(x))
        return x

input_dim = train_pos_features.shape[1]
model = DNNModel(input_dim)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# ---------------------------- 自定义数据加载器 ----------------------------

class BalancedDataset(Dataset):
    def __init__(self, pos_data, neg_data):
        self.pos_data = pos_data
        self.neg_data = neg_data
        self.pos_len = len(pos_data)
        self.neg_len = len(neg_data)

    def __len__(self):
        return min(self.pos_len, self.neg_len)

    def __getitem__(self, idx):
        pos_idx = np.random.randint(0, self.pos_len)
        neg_idx = np.random.randint(0, self.neg_len)
        
        pos_sample = self.pos_data.iloc[pos_idx].values.astype(np.float32)
        neg_sample = self.neg_data.iloc[neg_idx].values.astype(np.float32)

        X = np.vstack([pos_sample, neg_sample])
        y = np.array([1, 0], dtype=np.float32)

        return torch.tensor(X), torch.tensor(y)

class TestDataset(Dataset):
    def __init__(self, pos_data, neg_data):
        self.pos_data = pos_data
        self.neg_data = neg_data
        self.pos_len = len(pos_data)
        self.neg_len = len(neg_data)

    def __len__(self):
        return self.pos_len + self.neg_len

    def __getitem__(self, idx):
        if idx < self.pos_len:
            sample = self.pos_data.iloc[idx].values.astype(np.float32)
            label = 1
        else:
            idx -= self.pos_len
            sample = self.neg_data.iloc[idx].values.astype(np.float32)
            label = 0
        
        return torch.tensor(sample), torch.tensor(label, dtype=torch.float32)

# 初始化数据集和数据加载器
batch_size = 64
train_dataset = BalancedDataset(train_pos_features, train_neg_features)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TestDataset(val_pos_features, val_neg_features)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TestDataset(test_pos_features, test_neg_features)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# ---------------------------- 模型训练 ----------------------------

num_epochs = 150
train_losses = []
test_accuracies = []

def evaluate_model(model, data_loader):
    model.eval()  # 设置模型为评估模式
    pos_correct = 0
    neg_correct = 0
    pos_total = 0
    neg_total = 0

    with torch.no_grad():  # 关闭梯度计算
        for inputs, labels in data_loader:
            outputs = model(inputs)
            predicted = (outputs.squeeze() >= 0.5).float()

            # print(f"predicted: {predicted}")
            # Calculate accuracy for positive and negative samples
            pos_mask = (labels == 1).float()
            neg_mask = (labels == 0).float()
            pos_correct += ((predicted == labels) * pos_mask).sum().item()
            neg_correct += ((predicted == labels) * neg_mask).sum().item()
            pos_total += pos_mask.sum().item()
            neg_total += neg_mask.sum().item()
            

    pos_accuracy = pos_correct / pos_total if pos_total > 0 else 0
    neg_accuracy = neg_correct / neg_total if neg_total > 0 else 0
    return pos_accuracy, neg_accuracy, (pos_correct+neg_correct) / (pos_total + neg_total)


best_accuracy = 0.0
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), labels)
        epoch_loss += loss.item()

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accuracy calculation
        predicted = (outputs.squeeze() > 0.5).float()
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    # Calculate average loss and accuracy for the epoch
    avg_loss = epoch_loss / len(train_loader)
    avg_accuracy = correct / total
    train_losses.append(avg_loss)
    
    # Evaluate on test set
    pos_accuracy, neg_accuracy, accuracy = evaluate_model(model, val_loader)
    test_accuracies.append(accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Avg Accuracy: {accuracy},  Positive Accuracy: {pos_accuracy * 100:.2f}%, Negative Accuracy: {neg_accuracy * 100:.2f}%')

    # Save the best model
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        torch.save(model.state_dict(), pth_file_path)
        print("Best Accuracy Model: {}".format(best_accuracy))

        # Export the best model to ONNX
        dummy_input = torch.randn(1, input_dim)
        torch.onnx.export(model, dummy_input, onnx_file_path, input_names=['input'], output_names=['output'])
    

# ---------------------------- 绘制训练曲线 ----------------------------

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Curve')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), [acc * 100 for acc in test_accuracies], marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Testing Accuracy Curve')

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/150], Loss: 0.6970, Avg Accuracy: 0.5689655172413793,  Positive Accuracy: 50.00%, Negative Accuracy: 63.33%
# Best Accuracy Model: 0.5689655172413793
# Epoch [2/150], Loss: 0.6940, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 92.86%, Negative Accuracy: 66.67%
# Best Accuracy Model: 0.7931034482758621
# Epoch [3/150], Loss: 0.6901, Avg Accuracy: 0.7241379310344828,  Positive Accuracy: 82.14%, Negative Accuracy: 63.33%
# Epoch [4/150], Loss: 0.6922, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 75.00%, Negative Accuracy: 86.67%
# Best Accuracy Model: 0.8103448275862069
# Epoch [5/150], Loss: 0.6902, Avg Accuracy: 0.8793103448275862,  Positive Accuracy: 75.00%, Negative Accuracy: 100.00%
# Best Accuracy Model: 0.8793103448275862
# Epoch [6/150], Loss: 0.6918, Avg Accuracy: 0.896551724137931,  Positive Accuracy: 78.57%, Negative Accuracy: 100.00%
# Best Accuracy Model: 0.896551724137931
# Epoch [7/150], Loss: 0.6869, Avg Accuracy: 0.8448275862068966,  Positive Accuracy: 78.57%, Negative Accuracy: 90.00%
# Epoch [8/150], Loss: 0.6879, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [9/150], Loss: 0.6901, Avg Accuracy: 0.8448275862068966,  Positive Accuracy: 78.57%, Negative Accuracy: 90.00%
# Epoch [10/150], Loss: 0.6850, Avg Accuracy: 0.8620689655172413,  Positive Accuracy: 78.57%, Negative Accuracy: 93.33%
# Epoch [11/150], Loss: 0.6844, Avg Accuracy: 0.8448275862068966,  Positive Accuracy: 78.57%, Negative Accuracy: 90.00%
# Epoch [12/150], Loss: 0.6826, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [13/150], Loss: 0.6790, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [14/150], Loss: 0.6749, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [15/150], Loss: 0.6765, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [16/150], Loss: 0.6776, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [17/150], Loss: 0.6842, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [18/150], Loss: 0.6806, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [19/150], Loss: 0.6800, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [20/150], Loss: 0.6763, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [21/150], Loss: 0.6714, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [22/150], Loss: 0.6734, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [23/150], Loss: 0.6689, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [24/150], Loss: 0.6826, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [25/150], Loss: 0.6678, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [26/150], Loss: 0.6597, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [27/150], Loss: 0.6631, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [28/150], Loss: 0.6597, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [29/150], Loss: 0.6469, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [30/150], Loss: 0.6760, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [31/150], Loss: 0.6809, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [32/150], Loss: 0.6617, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [33/150], Loss: 0.6639, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [34/150], Loss: 0.6671, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [35/150], Loss: 0.6682, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [36/150], Loss: 0.6559, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [37/150], Loss: 0.6483, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [38/150], Loss: 0.6522, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [39/150], Loss: 0.6660, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [40/150], Loss: 0.6611, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [41/150], Loss: 0.6765, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [42/150], Loss: 0.6525, Avg Accuracy: 0.8448275862068966,  Positive Accuracy: 78.57%, Negative Accuracy: 90.00%
# Epoch [43/150], Loss: 0.6705, Avg Accuracy: 0.8793103448275862,  Positive Accuracy: 78.57%, Negative Accuracy: 96.67%
# Epoch [44/150], Loss: 0.6657, Avg Accuracy: 0.8793103448275862,  Positive Accuracy: 78.57%, Negative Accuracy: 96.67%
# Epoch [45/150], Loss: 0.6617, Avg Accuracy: 0.8793103448275862,  Positive Accuracy: 78.57%, Negative Accuracy: 96.67%
# Epoch [46/150], Loss: 0.6579, Avg Accuracy: 0.8448275862068966,  Positive Accuracy: 78.57%, Negative Accuracy: 90.00%
# Epoch [47/150], Loss: 0.6726, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [48/150], Loss: 0.6589, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [49/150], Loss: 0.6646, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [50/150], Loss: 0.6349, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [51/150], Loss: 0.6509, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [52/150], Loss: 0.6642, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [53/150], Loss: 0.6569, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [54/150], Loss: 0.6608, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [55/150], Loss: 0.6438, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [56/150], Loss: 0.6478, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [57/150], Loss: 0.6562, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [58/150], Loss: 0.6631, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [59/150], Loss: 0.6707, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [60/150], Loss: 0.6433, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [61/150], Loss: 0.6523, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [62/150], Loss: 0.6640, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [63/150], Loss: 0.6582, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [64/150], Loss: 0.6623, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [65/150], Loss: 0.6591, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [66/150], Loss: 0.6298, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [67/150], Loss: 0.6544, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [68/150], Loss: 0.6461, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [69/150], Loss: 0.6473, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [70/150], Loss: 0.6566, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [71/150], Loss: 0.6690, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [72/150], Loss: 0.6485, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [73/150], Loss: 0.6343, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [74/150], Loss: 0.6462, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [75/150], Loss: 0.6466, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [76/150], Loss: 0.6594, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [77/150], Loss: 0.6572, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [78/150], Loss: 0.6342, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [79/150], Loss: 0.6439, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [80/150], Loss: 0.6416, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [81/150], Loss: 0.6551, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [82/150], Loss: 0.6315, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [83/150], Loss: 0.6587, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [84/150], Loss: 0.6526, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [85/150], Loss: 0.6568, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [86/150], Loss: 0.6513, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [87/150], Loss: 0.6407, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [88/150], Loss: 0.6454, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [89/150], Loss: 0.6388, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [90/150], Loss: 0.6582, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [91/150], Loss: 0.6509, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [92/150], Loss: 0.6221, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [93/150], Loss: 0.6324, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [94/150], Loss: 0.6529, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [95/150], Loss: 0.6522, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [96/150], Loss: 0.6531, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [97/150], Loss: 0.6302, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [98/150], Loss: 0.6332, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [99/150], Loss: 0.6256, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [100/150], Loss: 0.6529, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [101/150], Loss: 0.6510, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [102/150], Loss: 0.6301, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [103/150], Loss: 0.6298, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [104/150], Loss: 0.6349, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [105/150], Loss: 0.6509, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [106/150], Loss: 0.6463, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [107/150], Loss: 0.6569, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [108/150], Loss: 0.6470, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [109/150], Loss: 0.6283, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [110/150], Loss: 0.6324, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [111/150], Loss: 0.6362, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [112/150], Loss: 0.6282, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [113/150], Loss: 0.6304, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [114/150], Loss: 0.6384, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [115/150], Loss: 0.6496, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [116/150], Loss: 0.6424, Avg Accuracy: 0.7413793103448276,  Positive Accuracy: 78.57%, Negative Accuracy: 70.00%
# Epoch [117/150], Loss: 0.6390, Avg Accuracy: 0.7413793103448276,  Positive Accuracy: 78.57%, Negative Accuracy: 70.00%
# Epoch [118/150], Loss: 0.6332, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [119/150], Loss: 0.6292, Avg Accuracy: 0.8103448275862069,  Positive Accuracy: 78.57%, Negative Accuracy: 83.33%
# Epoch [120/150], Loss: 0.6207, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [121/150], Loss: 0.6625, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [122/150], Loss: 0.6303, Avg Accuracy: 0.7413793103448276,  Positive Accuracy: 78.57%, Negative Accuracy: 70.00%
# Epoch [123/150], Loss: 0.6260, Avg Accuracy: 0.7413793103448276,  Positive Accuracy: 78.57%, Negative Accuracy: 70.00%
# Epoch [124/150], Loss: 0.6558, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [125/150], Loss: 0.6319, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [126/150], Loss: 0.6537, Avg Accuracy: 0.7413793103448276,  Positive Accuracy: 78.57%, Negative Accuracy: 70.00%
# Epoch [127/150], Loss: 0.6511, Avg Accuracy: 0.7413793103448276,  Positive Accuracy: 78.57%, Negative Accuracy: 70.00%
# Epoch [128/150], Loss: 0.6389, Avg Accuracy: 0.7413793103448276,  Positive Accuracy: 78.57%, Negative Accuracy: 70.00%
# Epoch [129/150], Loss: 0.6385, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [130/150], Loss: 0.6436, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [131/150], Loss: 0.6310, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [132/150], Loss: 0.6421, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [133/150], Loss: 0.6396, Avg Accuracy: 0.8275862068965517,  Positive Accuracy: 78.57%, Negative Accuracy: 86.67%
# Epoch [134/150], Loss: 0.6485, Avg Accuracy: 0.7931034482758621,  Positive Accuracy: 78.57%, Negative Accuracy: 80.00%
# Epoch [135/150], Loss: 0.6266, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [136/150], Loss: 0.6491, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [137/150], Loss: 0.6426, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [138/150], Loss: 0.6409, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [139/150], Loss: 0.6507, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [140/150], Loss: 0.6296, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [141/150], Loss: 0.6312, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [142/150], Loss: 0.6282, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [143/150], Loss: 0.6209, Avg Accuracy: 0.7413793103448276,  Positive Accuracy: 78.57%, Negative Accuracy: 70.00%
# Epoch [144/150], Loss: 0.6326, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [145/150], Loss: 0.6444, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [146/150], Loss: 0.6152, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [147/150], Loss: 0.6454, Avg Accuracy: 0.7758620689655172,  Positive Accuracy: 78.57%, Negative Accuracy: 76.67%
# Epoch [148/150], Loss: 0.6418, Avg Accuracy: 0.7413793103448276,  Positive Accuracy: 78.57%, Negative Accuracy: 70.00%
# Epoch [149/150], Loss: 0.6176, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%
# Epoch [150/150], Loss: 0.6267, Avg Accuracy: 0.7586206896551724,  Positive Accuracy: 78.57%, Negative Accuracy: 73.33%

# %%
import glob
import glob
import numpy as np
import onnxruntime as ort

from collections import defaultdict

# %%
print(test_pos_dataset.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_HF', 'HRV_VHF',
#        'HRV_TP', 'HRV_HFn', 'HRV_LnHF', 'wave_quality', 'label', 'id', 'age',
#        'gender'],
#       dtype='object')

# %%
import enum


def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    # 如果找到的文件不为空
    if onnx_files:
        # 按文件名排序
        onnx_files.sort()

        # 选择最后一个文件
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    if onnx_files:
        onnx_files.sort()
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
ort_session = ort.InferenceSession(onnx_model_path)

# 预测函数
def predict(features):
    inputs = {ort_session.get_inputs()[0].name: features}
    outputs = ort_session.run(None, inputs)
    return outputs[0]

for idx, pair_data in enumerate([[test_neg_dataset, test_neg_features], [test_pos_dataset, test_pos_features]]):
    if idx == 0:
        print("\nTest for Negative subjects:")
    else:
        print("\nTest for Positive subjects:")

    # 加载测试数据集
    # 计算每个 subject 的准确率
    subject_results = defaultdict(list)

    for (_, row_dataset), (_, features), in zip(pair_data[0].iterrows(), pair_data[1].iterrows()):
        subject = row_dataset['id']
        label = row_dataset['label']

        features = np.array(features, dtype=np.float32)  # 确保 features 的数据类型与模型输入匹配
        features = features.reshape(1, -1)  # 调整形状以匹配模型输入
        prediction = predict(features)
        predicted_label = (prediction >= 0.5).astype(int)  # 使用阈值 0.5 将预测概率转换为类标签
        subject_results[subject].append((predicted_label, label))

    subject_accuracies = {}
    for subject, results in subject_results.items():
        correct = sum(1 for pred, label in results if pred == label)
        accuracy = correct / len(results)
        subject_accuracies[subject] = accuracy

    # 输出每个 subject 的准确度
    correct_count = 0
    for subject, accuracy in subject_accuracies.items():
        print(f'Subject: {subject}, Accuracy: {accuracy:.2f}')
        if accuracy > 0.5:
            correct_count += 1
        elif accuracy == 0.5:
            correct_count += 0.5
    print(f"subject accuracy: {(correct_count / len(subject_accuracies)):.2f}")
# Out:
# Test for Negative subjects:
# Subject: 10067018716173574229320500679341658039, Accuracy: 1.00
# Subject: 220412779112482284366202079009344459295, Accuracy: 1.00
# Subject: 64072384993539353085868859411307902753, Accuracy: 1.00
# Subject: 270887533756973472376441335892518057033, Accuracy: 1.00
# Subject: 282688010890714602204731419184847947787, Accuracy: 1.00
# Subject: 192519081619282340004833305958416869165, Accuracy: 1.00
# Subject: 55619397159686112022662044355041152901, Accuracy: 0.40
# Subject: 214066112721987703187369304704263977384, Accuracy: 0.00
# Subject: 70548274733634719816690703613189281691, Accuracy: 0.80
# Subject: 17583509150572468227110417765438851577, Accuracy: 1.00
# subject accuracy: 0.80
#
# Test for Positive subjects:
# Subject: 291726336157896493559959962336883513986, Accuracy: 0.00
# Subject: 147359196293566602169362260165807304353, Accuracy: 1.00
# Subject: 201404667111814446206819837731426765409, Accuracy: 0.00
# Subject: 82021857307461782491499562936350476465, Accuracy: 1.00
# Subject: 257578913972433675542904987759433589293, Accuracy: 0.00
# Subject: 253236472362712351797769573369433989127, Accuracy: 0.25
# Subject: 93662820189211795719680984402174453884, Accuracy: 1.00
# Subject: 76564679515111601898752093007823406213, Accuracy: 1.00
# Subject: 47155295106343825763989534008758209376, Accuracy: 0.00
# Subject: 639172527045195363287108778219712510, Accuracy: 1.00
# subject accuracy: 0.50
