# %%
import os
import pandas as pd
import sys
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from datetime import datetime
from torch.utils.data import Dataset, DataLoader

sys.path.append(os.path.join(os.getcwd(), '../../../common'))
from ppg_feature_processor import map_gender, map_age

# %%
# 获取当前日期
current_date = datetime.now().strftime("%Y-%m-%d")
# 构建导出的pth文件名以及ONNX文件名
outdir = 'outdir'
pth_file_path = os.path.join(outdir, f'ppg_depression-best_model_{current_date}.pth')
onnx_file_path = os.path.join(outdir, f"ppg_depression-best_model_{current_date}.onnx")

# %%
profile_columns = ['wave_quality', 'age', 'gender', 'label', 'id']

# %%
# 加载数据
train_pos_dataset = pd.read_pickle('./samples/train_pos_dataset.pkl')
train_neg_dataset = pd.read_pickle('./samples/train_neg_dataset.pkl')
test_pos_dataset = pd.read_pickle('./samples/test_pos_dataset.pkl')
test_neg_dataset = pd.read_pickle('./samples/test_neg_dataset.pkl')

# %%
test_neg_dataset['id'].unique()
# Out:
# array(['695153b8-cd54-28f7-5e2d-b43ef7a12347',
#        'e1a05473-85af-4aaf-dff5-9a9a507b188d',
#        'bb2eaaba-1b05-bf28-3bd6-7c76fa5fd943',
#        '40b9a027-fc21-b774-38b3-5d399ac1583c',
#        'c831132a-79ed-6676-ad6c-811e7d40789c',
#        'd2adc252-fd1e-659a-5b27-37327b37c4a4',
#        'c5cf4093-8c88-3388-dd4a-8de8169eac4d',
#        '3b28f19d-7fd1-5d93-8fae-b6eae8ca3b82'], dtype=object)

# %%
test_pos_dataset['id'].unique()
# Out:
# array(['6b209cbb-d1b5-72ad-62f8-a698a20eeaa8',
#        '0e88cac0-231c-e492-409c-8a5d2683b181',
#        '6315febc-2fb1-e8e9-5e42-b60fe3d14f47',
#        'dc7e8552-e3c4-4695-379c-10e144338a4b',
#        '29a8784b-8752-4de0-579c-034c95044509',
#        'f34fb6c0-c2f7-7367-3e25-d101c0605938',
#        'bf102cd1-feed-4807-9ce7-d8bbfe9d0afd',
#        'b61f44a3-7e22-8127-7d75-2060d82e1a9b',
#        '43cb9b81-23c1-a136-bd28-41cae93082a3',
#        '2a4bd1c8-888b-915b-d645-1ae939a492c5'], dtype=object)

# %%
# 加载数据
train_pos_dataset = pd.read_pickle('./samples/train_pos_dataset.pkl')
train_neg_dataset = pd.read_pickle('./samples/train_neg_dataset.pkl')
test_pos_dataset = pd.read_pickle('./samples/test_pos_dataset.pkl')
test_neg_dataset = pd.read_pickle('./samples/test_neg_dataset.pkl')


test_val_pos_list  = (test_pos_dataset['id'].unique()).tolist()
test_val_neg_list  = (test_neg_dataset['id'].unique()).tolist()

validation_pos_data = test_pos_dataset[test_pos_dataset['id'].isin(test_val_pos_list[:3])]
test_pos_dataset = test_pos_dataset[test_pos_dataset['id'].isin(test_val_pos_list[3:])]
validation_neg_data = test_neg_dataset[test_neg_dataset['id'].isin(test_val_neg_list[:3])]
test_neg_dataset = test_neg_dataset[test_neg_dataset['id'].isin(test_val_neg_list[3:])]

# %%
train_pos_dataset['age'].unique()
# Out:
# array([15, 14, 13, 12], dtype=int64)

# %%
# # ---------------------------- 数据预处理 ----------------------------
def map_age(age):
    if age < 13:
        return [1, 0]
    elif age >= 13:
        return [0, 1] 

# ---------------------------- 数据预处理 ----------------------------
def map_gender(gender):
    return [1, 0] if gender == 'Female' else [0, 1]

def preprocess(df):
    df_new = df.copy()
    
    # df_new[['age_0', 'age_1']] = df_new['age'].apply(map_age).apply(pd.Series)
    df_new[['gender_0', 'gender_1']] = df_new['gender'].apply(map_gender).apply(pd.Series)
    return df_new.drop(profile_columns, axis=1)


# 应用预处理
train_pos_features = preprocess(train_pos_dataset)
train_neg_features = preprocess(train_neg_dataset)
val_pos_features = preprocess(validation_pos_data)
val_neg_features = preprocess(validation_neg_data)
test_pos_features = preprocess(test_pos_dataset)
test_neg_features = preprocess(test_neg_dataset)

# %%
print(train_pos_dataset.columns)

print(train_pos_features.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_LF', 'HRV_HF',
#        'HRV_VHF', 'HRV_TP', 'HRV_LFHF', 'HRV_LFn', 'HRV_HFn', 'HRV_LnHF',
#        'wave_quality', 'label', 'id', 'age', 'gender'],
#       dtype='object')
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_LF', 'HRV_HF',
#        'HRV_VHF', 'HRV_TP', 'HRV_LFHF', 'HRV_LFn', 'HRV_HFn', 'HRV_LnHF',
#        'gender_0', 'gender_1'],
#       dtype='object')

# %%
# ---------------------------- DNN 模型 ----------------------------

class DNNModel(nn.Module):
    def __init__(self, input_dim):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.relu = nn.ReLU()
        self.dropOut = nn.Dropout(0.5)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropOut(x)
        x = self.relu(self.fc2(x))
        x = self.dropOut(x)
        x = self.sigmoid(self.fc3(x))
        return x
class_weights = torch.tensor([1,0.65])  # For two classes: 0 and 1
input_dim = train_pos_features.shape[1]
model = DNNModel(input_dim)
criterion = nn.BCELoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01)

# ---------------------------- 自定义数据加载器 ----------------------------

class BalancedDataset(Dataset):
    def __init__(self, pos_data, neg_data):
        self.pos_data = pos_data
        self.neg_data = neg_data
        self.pos_len = len(pos_data)
        self.neg_len = len(neg_data)

    def __len__(self):
        return min(self.pos_len, self.neg_len)

    def __getitem__(self, idx):
        pos_idx = np.random.randint(0, self.pos_len)
        neg_idx = np.random.randint(0, self.neg_len)
        
        pos_sample = self.pos_data.iloc[pos_idx].values.astype(np.float32)
        neg_sample = self.neg_data.iloc[neg_idx].values.astype(np.float32)

        X = np.vstack([pos_sample, neg_sample])
        y = np.array([1, 0], dtype=np.float32)

        return torch.tensor(X), torch.tensor(y)

class TestDataset(Dataset):
    def __init__(self, pos_data, neg_data):
        self.pos_data = pos_data
        self.neg_data = neg_data
        self.pos_len = len(pos_data)
        self.neg_len = len(neg_data)

    def __len__(self):
        return self.pos_len + self.neg_len

    def __getitem__(self, idx):
        if idx < self.pos_len:
            sample = self.pos_data.iloc[idx].values.astype(np.float32)
            label = 1
        else:
            idx -= self.pos_len
            sample = self.neg_data.iloc[idx].values.astype(np.float32)
            label = 0
        
        return torch.tensor(sample), torch.tensor(label, dtype=torch.float32)

# 初始化数据集和数据加载器
batch_size = 64
train_dataset = BalancedDataset(train_pos_features, train_neg_features)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataset = TestDataset(val_pos_features, val_neg_features)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_dataset = TestDataset(test_pos_features, test_neg_features)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# ---------------------------- 模型训练 ----------------------------
num_epochs = 500
train_losses = []
test_accuracies = []

def evaluate_model(model, data_loader):
    model.eval()  # 设置模型为评估模式
    pos_correct = 0
    neg_correct = 0
    pos_total = 0
    neg_total = 0

    with torch.no_grad():  # 关闭梯度计算
        for inputs, labels in data_loader:
            outputs = model(inputs)
            predicted = (outputs.squeeze() >= 0.5).float()

            # print(f"predicted: {predicted}")
            # Calculate accuracy for positive and negative samples
            pos_mask = (labels == 1).float()
            neg_mask = (labels == 0).float()
            pos_correct += ((predicted == labels) * pos_mask).sum().item()
            neg_correct += ((predicted == labels) * neg_mask).sum().item()
            pos_total += pos_mask.sum().item()
            neg_total += neg_mask.sum().item()
            

    pos_accuracy = pos_correct / pos_total if pos_total > 0 else 0
    neg_accuracy = neg_correct / neg_total if neg_total > 0 else 0
    return pos_accuracy, neg_accuracy, (pos_correct+neg_correct) / (pos_total + neg_total)


best_accuracy = 0.0
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), labels)
        epoch_loss += loss.item()

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accuracy calculation
        predicted = (outputs.squeeze() > 0.5).float()
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    # Calculate average loss and accuracy for the epoch
    avg_loss = epoch_loss / len(train_loader)
    avg_accuracy = correct / total
    train_losses.append(avg_loss)
    
    # Evaluate on test set
    pos_accuracy, neg_accuracy, accuracy = evaluate_model(model, val_loader)
    test_accuracies.append(accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Avg Accuracy: {accuracy},  Positive Accuracy: {pos_accuracy * 100:.2f}%, Negative Accuracy: {neg_accuracy * 100:.2f}%')

    # Save the best model
    if accuracy > best_accuracy and (pos_accuracy >0.5 and neg_accuracy >0.5) and epoch > 2:
        best_accuracy = accuracy
        torch.save(model.state_dict(), pth_file_path)
        print("Best Accuracy Model: {}".format(best_accuracy))

        # Export the best model to ONNX
        dummy_input = torch.randn(1, input_dim)
        torch.onnx.export(model, dummy_input, onnx_file_path, input_names=['input'], output_names=['output'])
    

# ---------------------------- 绘制训练曲线 ----------------------------

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Curve')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), [acc * 100 for acc in test_accuracies], marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Testing Accuracy Curve')

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/500], Loss: 0.5505, Avg Accuracy: 0.48863636363636365,  Positive Accuracy: 100.00%, Negative Accuracy: 0.00%
# Epoch [2/500], Loss: 0.5388, Avg Accuracy: 0.4772727272727273,  Positive Accuracy: 97.67%, Negative Accuracy: 0.00%
# Epoch [3/500], Loss: 0.5313, Avg Accuracy: 0.42045454545454547,  Positive Accuracy: 58.14%, Negative Accuracy: 26.67%
# Epoch [4/500], Loss: 0.5058, Avg Accuracy: 0.42045454545454547,  Positive Accuracy: 39.53%, Negative Accuracy: 44.44%
# Epoch [5/500], Loss: 0.5042, Avg Accuracy: 0.5,  Positive Accuracy: 39.53%, Negative Accuracy: 60.00%
# Epoch [6/500], Loss: 0.4982, Avg Accuracy: 0.4772727272727273,  Positive Accuracy: 86.05%, Negative Accuracy: 11.11%
# Epoch [7/500], Loss: 0.4878, Avg Accuracy: 0.4659090909090909,  Positive Accuracy: 25.58%, Negative Accuracy: 66.67%
# Epoch [8/500], Loss: 0.4924, Avg Accuracy: 0.4659090909090909,  Positive Accuracy: 34.88%, Negative Accuracy: 57.78%
# Epoch [9/500], Loss: 0.4882, Avg Accuracy: 0.48863636363636365,  Positive Accuracy: 72.09%, Negative Accuracy: 26.67%
# Epoch [10/500], Loss: 0.4902, Avg Accuracy: 0.4659090909090909,  Positive Accuracy: 44.19%, Negative Accuracy: 48.89%
# Epoch [11/500], Loss: 0.5096, Avg Accuracy: 0.4772727272727273,  Positive Accuracy: 72.09%, Negative Accuracy: 24.44%
# Epoch [12/500], Loss: 0.4854, Avg Accuracy: 0.375,  Positive Accuracy: 32.56%, Negative Accuracy: 42.22%
# Epoch [13/500], Loss: 0.4896, Avg Accuracy: 0.42045454545454547,  Positive Accuracy: 60.47%, Negative Accuracy: 24.44%
# Epoch [14/500], Loss: 0.4734, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 20.93%, Negative Accuracy: 91.11%
# Epoch [15/500], Loss: 0.4597, Avg Accuracy: 0.48863636363636365,  Positive Accuracy: 69.77%, Negative Accuracy: 28.89%
# Epoch [16/500], Loss: 0.4860, Avg Accuracy: 0.5113636363636364,  Positive Accuracy: 76.74%, Negative Accuracy: 26.67%
# Epoch [17/500], Loss: 0.4681, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 51.16%, Negative Accuracy: 60.00%
# Best Accuracy Model: 0.5568181818181818
# Epoch [18/500], Loss: 0.4808, Avg Accuracy: 0.625,  Positive Accuracy: 69.77%, Negative Accuracy: 55.56%
# Best Accuracy Model: 0.625
# Epoch [19/500], Loss: 0.4750, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 60.47%, Negative Accuracy: 55.56%
# Epoch [20/500], Loss: 0.4617, Avg Accuracy: 0.625,  Positive Accuracy: 48.84%, Negative Accuracy: 75.56%
# Epoch [21/500], Loss: 0.4763, Avg Accuracy: 0.5,  Positive Accuracy: 74.42%, Negative Accuracy: 26.67%
# Epoch [22/500], Loss: 0.4669, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 60.47%, Negative Accuracy: 57.78%
# Epoch [23/500], Loss: 0.4669, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 27.91%, Negative Accuracy: 88.89%
# Epoch [24/500], Loss: 0.4812, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 95.35%, Negative Accuracy: 13.33%
# Epoch [25/500], Loss: 0.4818, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 81.40%, Negative Accuracy: 28.89%
# Epoch [26/500], Loss: 0.4819, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 62.79%, Negative Accuracy: 48.89%
# Epoch [27/500], Loss: 0.4747, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 65.12%, Negative Accuracy: 51.11%
# Epoch [28/500], Loss: 0.4691, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 51.16%, Negative Accuracy: 53.33%
# Epoch [29/500], Loss: 0.4608, Avg Accuracy: 0.5113636363636364,  Positive Accuracy: 83.72%, Negative Accuracy: 20.00%
# Epoch [30/500], Loss: 0.4764, Avg Accuracy: 0.45454545454545453,  Positive Accuracy: 53.49%, Negative Accuracy: 37.78%
# Epoch [31/500], Loss: 0.4811, Avg Accuracy: 0.5113636363636364,  Positive Accuracy: 72.09%, Negative Accuracy: 31.11%
# Epoch [32/500], Loss: 0.4568, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 53.49%, Negative Accuracy: 73.33%
# Best Accuracy Model: 0.6363636363636364
# Epoch [33/500], Loss: 0.4753, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 65.12%, Negative Accuracy: 53.33%
# Epoch [34/500], Loss: 0.4666, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 67.44%, Negative Accuracy: 66.67%
# Best Accuracy Model: 0.6704545454545454
# Epoch [35/500], Loss: 0.4623, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 48.84%, Negative Accuracy: 77.78%
# Epoch [36/500], Loss: 0.4482, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 32.56%, Negative Accuracy: 77.78%
# Epoch [37/500], Loss: 0.4837, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 93.02%, Negative Accuracy: 20.00%
# Epoch [38/500], Loss: 0.4653, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 62.79%, Negative Accuracy: 48.89%
# Epoch [39/500], Loss: 0.4724, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 58.14%, Negative Accuracy: 51.11%
# Epoch [40/500], Loss: 0.4905, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 90.70%, Negative Accuracy: 15.56%
# Epoch [41/500], Loss: 0.4791, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 100.00%, Negative Accuracy: 17.78%
# Epoch [42/500], Loss: 0.4741, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 60.47%, Negative Accuracy: 60.00%
# Epoch [43/500], Loss: 0.4632, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 69.77%, Negative Accuracy: 62.22%
# Epoch [44/500], Loss: 0.4751, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 41.86%, Negative Accuracy: 64.44%
# Epoch [45/500], Loss: 0.4595, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 65.12%, Negative Accuracy: 51.11%
# Epoch [46/500], Loss: 0.4765, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 48.84%, Negative Accuracy: 73.33%
# Epoch [47/500], Loss: 0.4426, Avg Accuracy: 0.625,  Positive Accuracy: 60.47%, Negative Accuracy: 64.44%
# Epoch [48/500], Loss: 0.4414, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 55.81%, Negative Accuracy: 77.78%
# Epoch [49/500], Loss: 0.4258, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 46.51%, Negative Accuracy: 73.33%
# Epoch [50/500], Loss: 0.4523, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 44.19%, Negative Accuracy: 68.89%
# Epoch [51/500], Loss: 0.4407, Avg Accuracy: 0.7159090909090909,  Positive Accuracy: 60.47%, Negative Accuracy: 82.22%
# Best Accuracy Model: 0.7159090909090909
# Epoch [52/500], Loss: 0.4642, Avg Accuracy: 0.5,  Positive Accuracy: 62.79%, Negative Accuracy: 37.78%
# Epoch [53/500], Loss: 0.4616, Avg Accuracy: 0.4772727272727273,  Positive Accuracy: 62.79%, Negative Accuracy: 33.33%
# Epoch [54/500], Loss: 0.4585, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 74.42%, Negative Accuracy: 48.89%
# Epoch [55/500], Loss: 0.4583, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 67.44%, Negative Accuracy: 64.44%
# Epoch [56/500], Loss: 0.4547, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 48.84%, Negative Accuracy: 66.67%
# Epoch [57/500], Loss: 0.4772, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 32.56%, Negative Accuracy: 93.33%
# Epoch [58/500], Loss: 0.4707, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 34.88%, Negative Accuracy: 93.33%
# Epoch [59/500], Loss: 0.4649, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 83.72%, Negative Accuracy: 35.56%
# Epoch [60/500], Loss: 0.4711, Avg Accuracy: 0.5113636363636364,  Positive Accuracy: 93.02%, Negative Accuracy: 11.11%
# Epoch [61/500], Loss: 0.4707, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 81.40%, Negative Accuracy: 26.67%
# Epoch [62/500], Loss: 0.4602, Avg Accuracy: 0.4318181818181818,  Positive Accuracy: 60.47%, Negative Accuracy: 26.67%
# Epoch [63/500], Loss: 0.4922, Avg Accuracy: 0.38636363636363635,  Positive Accuracy: 41.86%, Negative Accuracy: 35.56%
# Epoch [64/500], Loss: 0.4750, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 83.72%, Negative Accuracy: 31.11%
# Epoch [65/500], Loss: 0.4750, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 100.00%, Negative Accuracy: 8.89%
# Epoch [66/500], Loss: 0.4706, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 100.00%, Negative Accuracy: 13.33%
# Epoch [67/500], Loss: 0.4630, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 95.35%, Negative Accuracy: 24.44%
# Epoch [68/500], Loss: 0.4492, Avg Accuracy: 0.625,  Positive Accuracy: 34.88%, Negative Accuracy: 88.89%
# Epoch [69/500], Loss: 0.4531, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 46.51%, Negative Accuracy: 80.00%
# Epoch [70/500], Loss: 0.4515, Avg Accuracy: 0.4772727272727273,  Positive Accuracy: 65.12%, Negative Accuracy: 31.11%
# Epoch [71/500], Loss: 0.4459, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 46.51%, Negative Accuracy: 66.67%
# Epoch [72/500], Loss: 0.4638, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 32.56%, Negative Accuracy: 84.44%
# Epoch [73/500], Loss: 0.4431, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 58.14%, Negative Accuracy: 75.56%
# Epoch [74/500], Loss: 0.4433, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 44.19%, Negative Accuracy: 73.33%
# Epoch [75/500], Loss: 0.4542, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 44.19%, Negative Accuracy: 82.22%
# Epoch [76/500], Loss: 0.4413, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 27.91%, Negative Accuracy: 88.89%
# Epoch [77/500], Loss: 0.4457, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 65.12%, Negative Accuracy: 44.44%
# Epoch [78/500], Loss: 0.4611, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 90.70%, Negative Accuracy: 31.11%
# Epoch [79/500], Loss: 0.4616, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 83.72%, Negative Accuracy: 26.67%
# Epoch [80/500], Loss: 0.4463, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 72.09%, Negative Accuracy: 40.00%
# Epoch [81/500], Loss: 0.4421, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 51.16%, Negative Accuracy: 84.44%
# Epoch [82/500], Loss: 0.4506, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 41.86%, Negative Accuracy: 86.67%
# Epoch [83/500], Loss: 0.4416, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 79.07%, Negative Accuracy: 35.56%
# Epoch [84/500], Loss: 0.4492, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 74.42%, Negative Accuracy: 37.78%
# Epoch [85/500], Loss: 0.4346, Avg Accuracy: 0.5,  Positive Accuracy: 46.51%, Negative Accuracy: 53.33%
# Epoch [86/500], Loss: 0.4404, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 67.44%, Negative Accuracy: 48.89%
# Epoch [87/500], Loss: 0.4330, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 67.44%, Negative Accuracy: 44.44%
# Epoch [88/500], Loss: 0.4428, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 34.88%, Negative Accuracy: 86.67%
# Epoch [89/500], Loss: 0.4612, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 48.84%, Negative Accuracy: 77.78%
# Epoch [90/500], Loss: 0.4467, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 41.86%, Negative Accuracy: 62.22%
# Epoch [91/500], Loss: 0.4785, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 58.14%, Negative Accuracy: 77.78%
# Epoch [92/500], Loss: 0.4483, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 69.77%, Negative Accuracy: 46.67%
# Epoch [93/500], Loss: 0.4609, Avg Accuracy: 0.48863636363636365,  Positive Accuracy: 69.77%, Negative Accuracy: 28.89%
# Epoch [94/500], Loss: 0.4578, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 39.53%, Negative Accuracy: 82.22%
# Epoch [95/500], Loss: 0.4667, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 39.53%, Negative Accuracy: 77.78%
# Epoch [96/500], Loss: 0.4302, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 25.58%, Negative Accuracy: 88.89%
# Epoch [97/500], Loss: 0.4584, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 55.81%, Negative Accuracy: 48.89%
# Epoch [98/500], Loss: 0.4554, Avg Accuracy: 0.48863636363636365,  Positive Accuracy: 44.19%, Negative Accuracy: 53.33%
# Epoch [99/500], Loss: 0.4484, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 74.42%, Negative Accuracy: 46.67%
# Epoch [100/500], Loss: 0.4476, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 60.47%, Negative Accuracy: 53.33%
# Epoch [101/500], Loss: 0.4373, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 74.42%, Negative Accuracy: 33.33%
# Epoch [102/500], Loss: 0.4471, Avg Accuracy: 0.4431818181818182,  Positive Accuracy: 34.88%, Negative Accuracy: 53.33%
# Epoch [103/500], Loss: 0.4408, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 48.84%, Negative Accuracy: 82.22%
# Epoch [104/500], Loss: 0.4401, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 37.21%, Negative Accuracy: 80.00%
# Epoch [105/500], Loss: 0.4289, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 67.44%, Negative Accuracy: 64.44%
# Epoch [106/500], Loss: 0.4593, Avg Accuracy: 0.625,  Positive Accuracy: 37.21%, Negative Accuracy: 86.67%
# Epoch [107/500], Loss: 0.4616, Avg Accuracy: 0.5,  Positive Accuracy: 60.47%, Negative Accuracy: 40.00%
# Epoch [108/500], Loss: 0.4380, Avg Accuracy: 0.5113636363636364,  Positive Accuracy: 74.42%, Negative Accuracy: 28.89%
# Epoch [109/500], Loss: 0.4418, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 46.51%, Negative Accuracy: 71.11%
# Epoch [110/500], Loss: 0.4559, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 34.88%, Negative Accuracy: 82.22%
# Epoch [111/500], Loss: 0.4560, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 32.56%, Negative Accuracy: 82.22%
# Epoch [112/500], Loss: 0.4526, Avg Accuracy: 0.5113636363636364,  Positive Accuracy: 86.05%, Negative Accuracy: 17.78%
# Epoch [113/500], Loss: 0.4572, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 88.37%, Negative Accuracy: 17.78%
# Epoch [114/500], Loss: 0.4437, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 44.19%, Negative Accuracy: 88.89%
# Epoch [115/500], Loss: 0.4502, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 44.19%, Negative Accuracy: 91.11%
# Epoch [116/500], Loss: 0.4585, Avg Accuracy: 0.625,  Positive Accuracy: 44.19%, Negative Accuracy: 80.00%
# Epoch [117/500], Loss: 0.4390, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 37.21%, Negative Accuracy: 88.89%
# Epoch [118/500], Loss: 0.4462, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 67.44%, Negative Accuracy: 46.67%
# Epoch [119/500], Loss: 0.4451, Avg Accuracy: 0.4772727272727273,  Positive Accuracy: 53.49%, Negative Accuracy: 42.22%
# Epoch [120/500], Loss: 0.4489, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 37.21%, Negative Accuracy: 84.44%
# Epoch [121/500], Loss: 0.4338, Avg Accuracy: 0.625,  Positive Accuracy: 39.53%, Negative Accuracy: 84.44%
# Epoch [122/500], Loss: 0.4662, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 67.44%, Negative Accuracy: 46.67%
# Epoch [123/500], Loss: 0.4314, Avg Accuracy: 0.5113636363636364,  Positive Accuracy: 58.14%, Negative Accuracy: 44.44%
# Epoch [124/500], Loss: 0.4395, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 44.19%, Negative Accuracy: 86.67%
# Epoch [125/500], Loss: 0.4403, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 41.86%, Negative Accuracy: 91.11%
# Epoch [126/500], Loss: 0.4342, Avg Accuracy: 0.625,  Positive Accuracy: 32.56%, Negative Accuracy: 91.11%
# Epoch [127/500], Loss: 0.4552, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 72.09%, Negative Accuracy: 44.44%
# Epoch [128/500], Loss: 0.4645, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 60.47%, Negative Accuracy: 44.44%
# Epoch [129/500], Loss: 0.4548, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 81.40%, Negative Accuracy: 40.00%
# Epoch [130/500], Loss: 0.4565, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 34.88%, Negative Accuracy: 93.33%
# Epoch [131/500], Loss: 0.4565, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 27.91%, Negative Accuracy: 88.89%
# Epoch [132/500], Loss: 0.4535, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 37.21%, Negative Accuracy: 77.78%
# Epoch [133/500], Loss: 0.4486, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 74.42%, Negative Accuracy: 42.22%
# Epoch [134/500], Loss: 0.4453, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 30.23%, Negative Accuracy: 88.89%
# Epoch [135/500], Loss: 0.4575, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 48.84%, Negative Accuracy: 84.44%
# Epoch [136/500], Loss: 0.4538, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 41.86%, Negative Accuracy: 91.11%
# Epoch [137/500], Loss: 0.4654, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 67.44%, Negative Accuracy: 46.67%
# Epoch [138/500], Loss: 0.4444, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 58.14%, Negative Accuracy: 53.33%
# Epoch [139/500], Loss: 0.4510, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 58.14%, Negative Accuracy: 51.11%
# Epoch [140/500], Loss: 0.4532, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 74.42%, Negative Accuracy: 42.22%
# Epoch [141/500], Loss: 0.4652, Avg Accuracy: 0.625,  Positive Accuracy: 88.37%, Negative Accuracy: 37.78%
# Epoch [142/500], Loss: 0.4382, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 32.56%, Negative Accuracy: 86.67%
# Epoch [143/500], Loss: 0.4377, Avg Accuracy: 0.6931818181818182,  Positive Accuracy: 60.47%, Negative Accuracy: 77.78%
# Epoch [144/500], Loss: 0.4600, Avg Accuracy: 0.625,  Positive Accuracy: 44.19%, Negative Accuracy: 80.00%
# Epoch [145/500], Loss: 0.4566, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 76.74%, Negative Accuracy: 37.78%
# Epoch [146/500], Loss: 0.4482, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 79.07%, Negative Accuracy: 44.44%
# Epoch [147/500], Loss: 0.4396, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 58.14%, Negative Accuracy: 51.11%
# Epoch [148/500], Loss: 0.4503, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 69.77%, Negative Accuracy: 42.22%
# Epoch [149/500], Loss: 0.4416, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 79.07%, Negative Accuracy: 40.00%
# Epoch [150/500], Loss: 0.4574, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 69.77%, Negative Accuracy: 51.11%
# Epoch [151/500], Loss: 0.4461, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 67.44%, Negative Accuracy: 53.33%
# Epoch [152/500], Loss: 0.4680, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 72.09%, Negative Accuracy: 42.22%
# Epoch [153/500], Loss: 0.4328, Avg Accuracy: 0.625,  Positive Accuracy: 46.51%, Negative Accuracy: 77.78%
# Epoch [154/500], Loss: 0.4358, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 51.16%, Negative Accuracy: 80.00%
# Epoch [155/500], Loss: 0.4367, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 62.79%, Negative Accuracy: 68.89%
# Epoch [156/500], Loss: 0.4590, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 81.40%, Negative Accuracy: 31.11%
# Epoch [157/500], Loss: 0.4443, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 86.05%, Negative Accuracy: 35.56%
# Epoch [158/500], Loss: 0.4269, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 39.53%, Negative Accuracy: 86.67%
# Epoch [159/500], Loss: 0.4396, Avg Accuracy: 0.625,  Positive Accuracy: 44.19%, Negative Accuracy: 80.00%
# Epoch [160/500], Loss: 0.4334, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 44.19%, Negative Accuracy: 84.44%
# Epoch [161/500], Loss: 0.4436, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 34.88%, Negative Accuracy: 93.33%
# Epoch [162/500], Loss: 0.4288, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 74.42%, Negative Accuracy: 46.67%
# Epoch [163/500], Loss: 0.4270, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 86.05%, Negative Accuracy: 33.33%
# Epoch [164/500], Loss: 0.4304, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 76.74%, Negative Accuracy: 42.22%
# Epoch [165/500], Loss: 0.4333, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 76.74%, Negative Accuracy: 35.56%
# Epoch [166/500], Loss: 0.4352, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 65.12%, Negative Accuracy: 44.44%
# Epoch [167/500], Loss: 0.4476, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 58.14%, Negative Accuracy: 46.67%
# Epoch [168/500], Loss: 0.4379, Avg Accuracy: 0.5,  Positive Accuracy: 53.49%, Negative Accuracy: 46.67%
# Epoch [169/500], Loss: 0.4331, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 58.14%, Negative Accuracy: 73.33%
# Epoch [170/500], Loss: 0.4373, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 53.49%, Negative Accuracy: 80.00%
# Epoch [171/500], Loss: 0.4359, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 48.84%, Negative Accuracy: 86.67%
# Epoch [172/500], Loss: 0.4246, Avg Accuracy: 0.7045454545454546,  Positive Accuracy: 48.84%, Negative Accuracy: 91.11%
# Epoch [173/500], Loss: 0.4409, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 39.53%, Negative Accuracy: 82.22%
# Epoch [174/500], Loss: 0.4694, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 58.14%, Negative Accuracy: 75.56%
# Epoch [175/500], Loss: 0.4589, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 65.12%, Negative Accuracy: 71.11%
# Epoch [176/500], Loss: 0.4506, Avg Accuracy: 0.625,  Positive Accuracy: 53.49%, Negative Accuracy: 71.11%
# Epoch [177/500], Loss: 0.4555, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 81.40%, Negative Accuracy: 35.56%
# Epoch [178/500], Loss: 0.4282, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 39.53%, Negative Accuracy: 91.11%
# Epoch [179/500], Loss: 0.4176, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 41.86%, Negative Accuracy: 91.11%
# Epoch [180/500], Loss: 0.4278, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 39.53%, Negative Accuracy: 88.89%
# Epoch [181/500], Loss: 0.4357, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 44.19%, Negative Accuracy: 86.67%
# Epoch [182/500], Loss: 0.4492, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 67.44%, Negative Accuracy: 44.44%
# Epoch [183/500], Loss: 0.4614, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 74.42%, Negative Accuracy: 40.00%
# Epoch [184/500], Loss: 0.4380, Avg Accuracy: 0.625,  Positive Accuracy: 88.37%, Negative Accuracy: 37.78%
# Epoch [185/500], Loss: 0.4522, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 79.07%, Negative Accuracy: 35.56%
# Epoch [186/500], Loss: 0.4466, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 37.21%, Negative Accuracy: 88.89%
# Epoch [187/500], Loss: 0.4509, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 39.53%, Negative Accuracy: 88.89%
# Epoch [188/500], Loss: 0.4361, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 65.12%, Negative Accuracy: 48.89%
# Epoch [189/500], Loss: 0.4288, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 72.09%, Negative Accuracy: 40.00%
# Epoch [190/500], Loss: 0.4439, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 86.05%, Negative Accuracy: 35.56%
# Epoch [191/500], Loss: 0.4466, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 37.21%, Negative Accuracy: 91.11%
# Epoch [192/500], Loss: 0.4585, Avg Accuracy: 0.625,  Positive Accuracy: 41.86%, Negative Accuracy: 82.22%
# Epoch [193/500], Loss: 0.4631, Avg Accuracy: 0.625,  Positive Accuracy: 46.51%, Negative Accuracy: 77.78%
# Epoch [194/500], Loss: 0.4541, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 86.05%, Negative Accuracy: 33.33%
# Epoch [195/500], Loss: 0.4202, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 79.07%, Negative Accuracy: 35.56%
# Epoch [196/500], Loss: 0.4405, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 46.51%, Negative Accuracy: 86.67%
# Epoch [197/500], Loss: 0.4420, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 83.72%, Negative Accuracy: 35.56%
# Epoch [198/500], Loss: 0.4378, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 20.93%, Negative Accuracy: 88.89%
# Epoch [199/500], Loss: 0.4216, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 72.09%, Negative Accuracy: 40.00%
# Epoch [200/500], Loss: 0.4356, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 67.44%, Negative Accuracy: 42.22%
# Epoch [201/500], Loss: 0.4237, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 32.56%, Negative Accuracy: 86.67%
# Epoch [202/500], Loss: 0.4603, Avg Accuracy: 0.625,  Positive Accuracy: 37.21%, Negative Accuracy: 86.67%
# Epoch [203/500], Loss: 0.4547, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 67.44%, Negative Accuracy: 44.44%
# Epoch [204/500], Loss: 0.4501, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 72.09%, Negative Accuracy: 33.33%
# Epoch [205/500], Loss: 0.4555, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 93.02%, Negative Accuracy: 31.11%
# Epoch [206/500], Loss: 0.4304, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 69.77%, Negative Accuracy: 46.67%
# Epoch [207/500], Loss: 0.4295, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 46.51%, Negative Accuracy: 84.44%
# Epoch [208/500], Loss: 0.4300, Avg Accuracy: 0.625,  Positive Accuracy: 37.21%, Negative Accuracy: 86.67%
# Epoch [209/500], Loss: 0.4443, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 44.19%, Negative Accuracy: 82.22%
# Epoch [210/500], Loss: 0.4399, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 67.44%, Negative Accuracy: 48.89%
# Epoch [211/500], Loss: 0.4403, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 69.77%, Negative Accuracy: 35.56%
# Epoch [212/500], Loss: 0.4466, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 81.40%, Negative Accuracy: 24.44%
# Epoch [213/500], Loss: 0.4364, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 41.86%, Negative Accuracy: 71.11%
# Epoch [214/500], Loss: 0.4270, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 37.21%, Negative Accuracy: 88.89%
# Epoch [215/500], Loss: 0.4267, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 46.51%, Negative Accuracy: 86.67%
# Epoch [216/500], Loss: 0.4455, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 39.53%, Negative Accuracy: 73.33%
# Epoch [217/500], Loss: 0.4330, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 48.84%, Negative Accuracy: 77.78%
# Epoch [218/500], Loss: 0.4376, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 51.16%, Negative Accuracy: 77.78%
# Epoch [219/500], Loss: 0.4265, Avg Accuracy: 0.625,  Positive Accuracy: 41.86%, Negative Accuracy: 82.22%
# Epoch [220/500], Loss: 0.4411, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 25.58%, Negative Accuracy: 88.89%
# Epoch [221/500], Loss: 0.4263, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 60.47%, Negative Accuracy: 48.89%
# Epoch [222/500], Loss: 0.4265, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 55.81%, Negative Accuracy: 77.78%
# Epoch [223/500], Loss: 0.4269, Avg Accuracy: 0.625,  Positive Accuracy: 44.19%, Negative Accuracy: 80.00%
# Epoch [224/500], Loss: 0.4413, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 39.53%, Negative Accuracy: 86.67%
# Epoch [225/500], Loss: 0.4314, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 53.49%, Negative Accuracy: 80.00%
# Epoch [226/500], Loss: 0.4419, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 30.23%, Negative Accuracy: 88.89%
# Epoch [227/500], Loss: 0.4265, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 86.05%, Negative Accuracy: 28.89%
# Epoch [228/500], Loss: 0.4426, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 41.86%, Negative Accuracy: 84.44%
# Epoch [229/500], Loss: 0.4252, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 41.86%, Negative Accuracy: 86.67%
# Epoch [230/500], Loss: 0.4383, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 86.05%, Negative Accuracy: 28.89%
# Epoch [231/500], Loss: 0.4355, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 41.86%, Negative Accuracy: 93.33%
# Epoch [232/500], Loss: 0.4292, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 48.84%, Negative Accuracy: 84.44%
# Epoch [233/500], Loss: 0.4327, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 32.56%, Negative Accuracy: 95.56%
# Epoch [234/500], Loss: 0.4498, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 65.12%, Negative Accuracy: 40.00%
# Epoch [235/500], Loss: 0.4303, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 76.74%, Negative Accuracy: 37.78%
# Epoch [236/500], Loss: 0.4380, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 83.72%, Negative Accuracy: 35.56%
# Epoch [237/500], Loss: 0.4344, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 83.72%, Negative Accuracy: 35.56%
# Epoch [238/500], Loss: 0.4407, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 39.53%, Negative Accuracy: 88.89%
# Epoch [239/500], Loss: 0.4527, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 69.77%, Negative Accuracy: 40.00%
# Epoch [240/500], Loss: 0.4313, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 83.72%, Negative Accuracy: 37.78%
# Epoch [241/500], Loss: 0.4369, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 13.95%, Negative Accuracy: 91.11%
# Epoch [242/500], Loss: 0.4395, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 39.53%, Negative Accuracy: 88.89%
# Epoch [243/500], Loss: 0.4434, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 53.49%, Negative Accuracy: 82.22%
# Epoch [244/500], Loss: 0.4347, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 51.16%, Negative Accuracy: 77.78%
# Epoch [245/500], Loss: 0.4166, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 46.51%, Negative Accuracy: 84.44%
# Epoch [246/500], Loss: 0.4511, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 32.56%, Negative Accuracy: 88.89%
# Epoch [247/500], Loss: 0.4428, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 88.37%, Negative Accuracy: 33.33%
# Epoch [248/500], Loss: 0.4341, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 88.37%, Negative Accuracy: 28.89%
# Epoch [249/500], Loss: 0.4351, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 76.74%, Negative Accuracy: 35.56%
# Epoch [250/500], Loss: 0.4618, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 76.74%, Negative Accuracy: 37.78%
# Epoch [251/500], Loss: 0.4292, Avg Accuracy: 0.625,  Positive Accuracy: 34.88%, Negative Accuracy: 88.89%
# Epoch [252/500], Loss: 0.4113, Avg Accuracy: 0.625,  Positive Accuracy: 37.21%, Negative Accuracy: 86.67%
# Epoch [253/500], Loss: 0.4340, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 18.60%, Negative Accuracy: 88.89%
# Epoch [254/500], Loss: 0.4299, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 67.44%, Negative Accuracy: 40.00%
# Epoch [255/500], Loss: 0.4416, Avg Accuracy: 0.5113636363636364,  Positive Accuracy: 67.44%, Negative Accuracy: 35.56%
# Epoch [256/500], Loss: 0.4365, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 46.51%, Negative Accuracy: 82.22%
# Epoch [257/500], Loss: 0.4584, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 25.58%, Negative Accuracy: 93.33%
# Epoch [258/500], Loss: 0.4420, Avg Accuracy: 0.625,  Positive Accuracy: 39.53%, Negative Accuracy: 84.44%
# Epoch [259/500], Loss: 0.4422, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 25.58%, Negative Accuracy: 88.89%
# Epoch [260/500], Loss: 0.4340, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 93.02%, Negative Accuracy: 24.44%
# Epoch [261/500], Loss: 0.4378, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 25.58%, Negative Accuracy: 88.89%
# Epoch [262/500], Loss: 0.4478, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 39.53%, Negative Accuracy: 86.67%
# Epoch [263/500], Loss: 0.4314, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 83.72%, Negative Accuracy: 28.89%
# Epoch [264/500], Loss: 0.4264, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 9.30%, Negative Accuracy: 93.33%
# Epoch [265/500], Loss: 0.4368, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 27.91%, Negative Accuracy: 91.11%
# Epoch [266/500], Loss: 0.4355, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 67.44%, Negative Accuracy: 40.00%
# Epoch [267/500], Loss: 0.4252, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 88.37%, Negative Accuracy: 17.78%
# Epoch [268/500], Loss: 0.4302, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 88.37%, Negative Accuracy: 22.22%
# Epoch [269/500], Loss: 0.4598, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 86.05%, Negative Accuracy: 22.22%
# Epoch [270/500], Loss: 0.4352, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 88.37%, Negative Accuracy: 17.78%
# Epoch [271/500], Loss: 0.4632, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 88.37%, Negative Accuracy: 20.00%
# Epoch [272/500], Loss: 0.4269, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 30.23%, Negative Accuracy: 77.78%
# Epoch [273/500], Loss: 0.4341, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 41.86%, Negative Accuracy: 77.78%
# Epoch [274/500], Loss: 0.4356, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 90.70%, Negative Accuracy: 28.89%
# Epoch [275/500], Loss: 0.4370, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 88.37%, Negative Accuracy: 31.11%
# Epoch [276/500], Loss: 0.4344, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 88.37%, Negative Accuracy: 26.67%
# Epoch [277/500], Loss: 0.4406, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 32.56%, Negative Accuracy: 82.22%
# Epoch [278/500], Loss: 0.4230, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 39.53%, Negative Accuracy: 86.67%
# Epoch [279/500], Loss: 0.4311, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 46.51%, Negative Accuracy: 84.44%
# Epoch [280/500], Loss: 0.4413, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 88.37%, Negative Accuracy: 17.78%
# Epoch [281/500], Loss: 0.4239, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 55.81%, Negative Accuracy: 75.56%
# Epoch [282/500], Loss: 0.4447, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 37.21%, Negative Accuracy: 80.00%
# Epoch [283/500], Loss: 0.4517, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 37.21%, Negative Accuracy: 75.56%
# Epoch [284/500], Loss: 0.4327, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 65.12%, Negative Accuracy: 66.67%
# Epoch [285/500], Loss: 0.4508, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 53.49%, Negative Accuracy: 77.78%
# Epoch [286/500], Loss: 0.4549, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 62.79%, Negative Accuracy: 68.89%
# Epoch [287/500], Loss: 0.4374, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 90.70%, Negative Accuracy: 17.78%
# Epoch [288/500], Loss: 0.4476, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 37.21%, Negative Accuracy: 91.11%
# Epoch [289/500], Loss: 0.4426, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 76.74%, Negative Accuracy: 31.11%
# Epoch [290/500], Loss: 0.4332, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 86.05%, Negative Accuracy: 28.89%
# Epoch [291/500], Loss: 0.4361, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 88.37%, Negative Accuracy: 31.11%
# Epoch [292/500], Loss: 0.4341, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 41.86%, Negative Accuracy: 77.78%
# Epoch [293/500], Loss: 0.4290, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 39.53%, Negative Accuracy: 91.11%
# Epoch [294/500], Loss: 0.4328, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 30.23%, Negative Accuracy: 91.11%
# Epoch [295/500], Loss: 0.4438, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 32.56%, Negative Accuracy: 82.22%
# Epoch [296/500], Loss: 0.4467, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 37.21%, Negative Accuracy: 73.33%
# Epoch [297/500], Loss: 0.4171, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 39.53%, Negative Accuracy: 80.00%
# Epoch [298/500], Loss: 0.4509, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 41.86%, Negative Accuracy: 80.00%
# Epoch [299/500], Loss: 0.4396, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 46.51%, Negative Accuracy: 73.33%
# Epoch [300/500], Loss: 0.4163, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 37.21%, Negative Accuracy: 80.00%
# Epoch [301/500], Loss: 0.4659, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 41.86%, Negative Accuracy: 84.44%
# Epoch [302/500], Loss: 0.4544, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 83.72%, Negative Accuracy: 26.67%
# Epoch [303/500], Loss: 0.4415, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 72.09%, Negative Accuracy: 42.22%
# Epoch [304/500], Loss: 0.4715, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 88.37%, Negative Accuracy: 35.56%
# Epoch [305/500], Loss: 0.4283, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 53.49%, Negative Accuracy: 80.00%
# Epoch [306/500], Loss: 0.4104, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 32.56%, Negative Accuracy: 88.89%
# Epoch [307/500], Loss: 0.4345, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 41.86%, Negative Accuracy: 80.00%
# Epoch [308/500], Loss: 0.4358, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 27.91%, Negative Accuracy: 88.89%
# Epoch [309/500], Loss: 0.4229, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 46.51%, Negative Accuracy: 82.22%
# Epoch [310/500], Loss: 0.4074, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 41.86%, Negative Accuracy: 86.67%
# Epoch [311/500], Loss: 0.4398, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 72.09%, Negative Accuracy: 42.22%
# Epoch [312/500], Loss: 0.4336, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 67.44%, Negative Accuracy: 40.00%
# Epoch [313/500], Loss: 0.4208, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 37.21%, Negative Accuracy: 88.89%
# Epoch [314/500], Loss: 0.4382, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 30.23%, Negative Accuracy: 88.89%
# Epoch [315/500], Loss: 0.4125, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 23.26%, Negative Accuracy: 86.67%
# Epoch [316/500], Loss: 0.4567, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 41.86%, Negative Accuracy: 80.00%
# Epoch [317/500], Loss: 0.4471, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 32.56%, Negative Accuracy: 82.22%
# Epoch [318/500], Loss: 0.4407, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 44.19%, Negative Accuracy: 82.22%
# Epoch [319/500], Loss: 0.4290, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 86.05%, Negative Accuracy: 33.33%
# Epoch [320/500], Loss: 0.4398, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 74.42%, Negative Accuracy: 37.78%
# Epoch [321/500], Loss: 0.4348, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 76.74%, Negative Accuracy: 42.22%
# Epoch [322/500], Loss: 0.4225, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 46.51%, Negative Accuracy: 86.67%
# Epoch [323/500], Loss: 0.4261, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 44.19%, Negative Accuracy: 82.22%
# Epoch [324/500], Loss: 0.4231, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 51.16%, Negative Accuracy: 80.00%
# Epoch [325/500], Loss: 0.4326, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 20.93%, Negative Accuracy: 88.89%
# Epoch [326/500], Loss: 0.4459, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 74.42%, Negative Accuracy: 31.11%
# Epoch [327/500], Loss: 0.4383, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 76.74%, Negative Accuracy: 28.89%
# Epoch [328/500], Loss: 0.4372, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 44.19%, Negative Accuracy: 84.44%
# Epoch [329/500], Loss: 0.4516, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 48.84%, Negative Accuracy: 86.67%
# Epoch [330/500], Loss: 0.4399, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 27.91%, Negative Accuracy: 91.11%
# Epoch [331/500], Loss: 0.4385, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 25.58%, Negative Accuracy: 93.33%
# Epoch [332/500], Loss: 0.4296, Avg Accuracy: 0.6931818181818182,  Positive Accuracy: 51.16%, Negative Accuracy: 86.67%
# Epoch [333/500], Loss: 0.4469, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 55.81%, Negative Accuracy: 80.00%
# Epoch [334/500], Loss: 0.4309, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 32.56%, Negative Accuracy: 82.22%
# Epoch [335/500], Loss: 0.4400, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 32.56%, Negative Accuracy: 84.44%
# Epoch [336/500], Loss: 0.4212, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 39.53%, Negative Accuracy: 91.11%
# Epoch [337/500], Loss: 0.4229, Avg Accuracy: 0.6931818181818182,  Positive Accuracy: 58.14%, Negative Accuracy: 80.00%
# Epoch [338/500], Loss: 0.4334, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 41.86%, Negative Accuracy: 84.44%
# Epoch [339/500], Loss: 0.4350, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 81.40%, Negative Accuracy: 37.78%
# Epoch [340/500], Loss: 0.4445, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 90.70%, Negative Accuracy: 33.33%
# Epoch [341/500], Loss: 0.4378, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 95.35%, Negative Accuracy: 24.44%
# Epoch [342/500], Loss: 0.4497, Avg Accuracy: 0.7272727272727273,  Positive Accuracy: 60.47%, Negative Accuracy: 84.44%
# Best Accuracy Model: 0.7272727272727273
# Epoch [343/500], Loss: 0.4413, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 46.51%, Negative Accuracy: 82.22%
# Epoch [344/500], Loss: 0.4380, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 32.56%, Negative Accuracy: 84.44%
# Epoch [345/500], Loss: 0.4190, Avg Accuracy: 0.7272727272727273,  Positive Accuracy: 58.14%, Negative Accuracy: 86.67%
# Epoch [346/500], Loss: 0.4357, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 32.56%, Negative Accuracy: 88.89%
# Epoch [347/500], Loss: 0.4370, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 46.51%, Negative Accuracy: 80.00%
# Epoch [348/500], Loss: 0.4372, Avg Accuracy: 0.625,  Positive Accuracy: 32.56%, Negative Accuracy: 91.11%
# Epoch [349/500], Loss: 0.4093, Avg Accuracy: 0.625,  Positive Accuracy: 32.56%, Negative Accuracy: 91.11%
# Epoch [350/500], Loss: 0.4267, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 39.53%, Negative Accuracy: 86.67%
# Epoch [351/500], Loss: 0.4335, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 30.23%, Negative Accuracy: 86.67%
# Epoch [352/500], Loss: 0.4164, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 83.72%, Negative Accuracy: 40.00%
# Epoch [353/500], Loss: 0.4341, Avg Accuracy: 0.5454545454545454,  Positive Accuracy: 79.07%, Negative Accuracy: 31.11%
# Epoch [354/500], Loss: 0.4394, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 32.56%, Negative Accuracy: 86.67%
# Epoch [355/500], Loss: 0.4425, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 46.51%, Negative Accuracy: 80.00%
# Epoch [356/500], Loss: 0.4434, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 39.53%, Negative Accuracy: 82.22%
# Epoch [357/500], Loss: 0.4268, Avg Accuracy: 0.625,  Positive Accuracy: 39.53%, Negative Accuracy: 84.44%
# Epoch [358/500], Loss: 0.4318, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 46.51%, Negative Accuracy: 86.67%
# Epoch [359/500], Loss: 0.4372, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 34.88%, Negative Accuracy: 84.44%
# Epoch [360/500], Loss: 0.4334, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 39.53%, Negative Accuracy: 82.22%
# Epoch [361/500], Loss: 0.4330, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 37.21%, Negative Accuracy: 82.22%
# Epoch [362/500], Loss: 0.4405, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 25.58%, Negative Accuracy: 91.11%
# Epoch [363/500], Loss: 0.4255, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 51.16%, Negative Accuracy: 84.44%
# Epoch [364/500], Loss: 0.4511, Avg Accuracy: 0.7045454545454546,  Positive Accuracy: 58.14%, Negative Accuracy: 82.22%
# Epoch [365/500], Loss: 0.4324, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 39.53%, Negative Accuracy: 88.89%
# Epoch [366/500], Loss: 0.4523, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 37.21%, Negative Accuracy: 84.44%
# Epoch [367/500], Loss: 0.4366, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 41.86%, Negative Accuracy: 86.67%
# Epoch [368/500], Loss: 0.4211, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 37.21%, Negative Accuracy: 88.89%
# Epoch [369/500], Loss: 0.4278, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 46.51%, Negative Accuracy: 88.89%
# Epoch [370/500], Loss: 0.4392, Avg Accuracy: 0.625,  Positive Accuracy: 39.53%, Negative Accuracy: 84.44%
# Epoch [371/500], Loss: 0.4233, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 44.19%, Negative Accuracy: 88.89%
# Epoch [372/500], Loss: 0.4124, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 37.21%, Negative Accuracy: 88.89%
# Epoch [373/500], Loss: 0.4292, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 46.51%, Negative Accuracy: 84.44%
# Epoch [374/500], Loss: 0.4109, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 41.86%, Negative Accuracy: 88.89%
# Epoch [375/500], Loss: 0.4436, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 83.72%, Negative Accuracy: 35.56%
# Epoch [376/500], Loss: 0.4217, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 88.37%, Negative Accuracy: 28.89%
# Epoch [377/500], Loss: 0.4424, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 27.91%, Negative Accuracy: 93.33%
# Epoch [378/500], Loss: 0.4227, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 37.21%, Negative Accuracy: 88.89%
# Epoch [379/500], Loss: 0.4123, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 41.86%, Negative Accuracy: 88.89%
# Epoch [380/500], Loss: 0.4373, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 25.58%, Negative Accuracy: 88.89%
# Epoch [381/500], Loss: 0.4087, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 27.91%, Negative Accuracy: 86.67%
# Epoch [382/500], Loss: 0.4198, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 27.91%, Negative Accuracy: 86.67%
# Epoch [383/500], Loss: 0.4176, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 23.26%, Negative Accuracy: 91.11%
# Epoch [384/500], Loss: 0.4233, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 23.26%, Negative Accuracy: 91.11%
# Epoch [385/500], Loss: 0.4228, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 83.72%, Negative Accuracy: 33.33%
# Epoch [386/500], Loss: 0.4150, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 51.16%, Negative Accuracy: 84.44%
# Epoch [387/500], Loss: 0.4142, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 25.58%, Negative Accuracy: 88.89%
# Epoch [388/500], Loss: 0.4292, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 34.88%, Negative Accuracy: 91.11%
# Epoch [389/500], Loss: 0.4191, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 41.86%, Negative Accuracy: 91.11%
# Epoch [390/500], Loss: 0.4256, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 30.23%, Negative Accuracy: 91.11%
# Epoch [391/500], Loss: 0.4351, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 25.58%, Negative Accuracy: 91.11%
# Epoch [392/500], Loss: 0.4358, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 34.88%, Negative Accuracy: 84.44%
# Epoch [393/500], Loss: 0.4374, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 81.40%, Negative Accuracy: 33.33%
# Epoch [394/500], Loss: 0.4464, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 93.02%, Negative Accuracy: 22.22%
# Epoch [395/500], Loss: 0.4242, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 95.35%, Negative Accuracy: 20.00%
# Epoch [396/500], Loss: 0.4333, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 41.86%, Negative Accuracy: 91.11%
# Epoch [397/500], Loss: 0.4343, Avg Accuracy: 0.6931818181818182,  Positive Accuracy: 55.81%, Negative Accuracy: 82.22%
# Epoch [398/500], Loss: 0.4250, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 27.91%, Negative Accuracy: 93.33%
# Epoch [399/500], Loss: 0.4242, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 20.93%, Negative Accuracy: 93.33%
# Epoch [400/500], Loss: 0.4401, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 23.26%, Negative Accuracy: 93.33%
# Epoch [401/500], Loss: 0.4221, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 88.37%, Negative Accuracy: 26.67%
# Epoch [402/500], Loss: 0.4244, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 88.37%, Negative Accuracy: 28.89%
# Epoch [403/500], Loss: 0.4252, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 23.26%, Negative Accuracy: 91.11%
# Epoch [404/500], Loss: 0.4498, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 32.56%, Negative Accuracy: 86.67%
# Epoch [405/500], Loss: 0.4203, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 32.56%, Negative Accuracy: 86.67%
# Epoch [406/500], Loss: 0.4074, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 27.91%, Negative Accuracy: 93.33%
# Epoch [407/500], Loss: 0.4251, Avg Accuracy: 0.625,  Positive Accuracy: 39.53%, Negative Accuracy: 84.44%
# Epoch [408/500], Loss: 0.4492, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 30.23%, Negative Accuracy: 91.11%
# Epoch [409/500], Loss: 0.4404, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 27.91%, Negative Accuracy: 93.33%
# Epoch [410/500], Loss: 0.4311, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 32.56%, Negative Accuracy: 93.33%
# Epoch [411/500], Loss: 0.4223, Avg Accuracy: 0.625,  Positive Accuracy: 37.21%, Negative Accuracy: 86.67%
# Epoch [412/500], Loss: 0.4371, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 41.86%, Negative Accuracy: 93.33%
# Epoch [413/500], Loss: 0.4304, Avg Accuracy: 0.625,  Positive Accuracy: 34.88%, Negative Accuracy: 88.89%
# Epoch [414/500], Loss: 0.4252, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 32.56%, Negative Accuracy: 93.33%
# Epoch [415/500], Loss: 0.4208, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 39.53%, Negative Accuracy: 91.11%
# Epoch [416/500], Loss: 0.4189, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 11.63%, Negative Accuracy: 93.33%
# Epoch [417/500], Loss: 0.4325, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 79.07%, Negative Accuracy: 33.33%
# Epoch [418/500], Loss: 0.4300, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 86.05%, Negative Accuracy: 33.33%
# Epoch [419/500], Loss: 0.4369, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 37.21%, Negative Accuracy: 91.11%
# Epoch [420/500], Loss: 0.4339, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 48.84%, Negative Accuracy: 86.67%
# Epoch [421/500], Loss: 0.4388, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 39.53%, Negative Accuracy: 91.11%
# Epoch [422/500], Loss: 0.4229, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 32.56%, Negative Accuracy: 93.33%
# Epoch [423/500], Loss: 0.4472, Avg Accuracy: 0.625,  Positive Accuracy: 32.56%, Negative Accuracy: 91.11%
# Epoch [424/500], Loss: 0.4198, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 27.91%, Negative Accuracy: 93.33%
# Epoch [425/500], Loss: 0.4247, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 32.56%, Negative Accuracy: 86.67%
# Epoch [426/500], Loss: 0.4445, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 39.53%, Negative Accuracy: 93.33%
# Epoch [427/500], Loss: 0.4154, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 27.91%, Negative Accuracy: 88.89%
# Epoch [428/500], Loss: 0.4155, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 39.53%, Negative Accuracy: 86.67%
# Epoch [429/500], Loss: 0.4395, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 23.26%, Negative Accuracy: 93.33%
# Epoch [430/500], Loss: 0.4314, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 34.88%, Negative Accuracy: 86.67%
# Epoch [431/500], Loss: 0.4166, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 86.05%, Negative Accuracy: 33.33%
# Epoch [432/500], Loss: 0.4024, Avg Accuracy: 0.625,  Positive Accuracy: 34.88%, Negative Accuracy: 88.89%
# Epoch [433/500], Loss: 0.4230, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 27.91%, Negative Accuracy: 88.89%
# Epoch [434/500], Loss: 0.4238, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 30.23%, Negative Accuracy: 86.67%
# Epoch [435/500], Loss: 0.4276, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 20.93%, Negative Accuracy: 93.33%
# Epoch [436/500], Loss: 0.4271, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 20.93%, Negative Accuracy: 93.33%
# Epoch [437/500], Loss: 0.4132, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 74.42%, Negative Accuracy: 40.00%
# Epoch [438/500], Loss: 0.4411, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 83.72%, Negative Accuracy: 31.11%
# Epoch [439/500], Loss: 0.4015, Avg Accuracy: 0.625,  Positive Accuracy: 32.56%, Negative Accuracy: 91.11%
# Epoch [440/500], Loss: 0.4069, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 25.58%, Negative Accuracy: 93.33%
# Epoch [441/500], Loss: 0.4219, Avg Accuracy: 0.6818181818181818,  Positive Accuracy: 48.84%, Negative Accuracy: 86.67%
# Epoch [442/500], Loss: 0.4162, Avg Accuracy: 0.6704545454545454,  Positive Accuracy: 46.51%, Negative Accuracy: 86.67%
# Epoch [443/500], Loss: 0.4183, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 23.26%, Negative Accuracy: 93.33%
# Epoch [444/500], Loss: 0.4323, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 25.58%, Negative Accuracy: 95.56%
# Epoch [445/500], Loss: 0.4206, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 32.56%, Negative Accuracy: 95.56%
# Epoch [446/500], Loss: 0.4221, Avg Accuracy: 0.6931818181818182,  Positive Accuracy: 44.19%, Negative Accuracy: 93.33%
# Epoch [447/500], Loss: 0.4528, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 90.70%, Negative Accuracy: 33.33%
# Epoch [448/500], Loss: 0.4497, Avg Accuracy: 0.5681818181818182,  Positive Accuracy: 83.72%, Negative Accuracy: 31.11%
# Epoch [449/500], Loss: 0.4273, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 88.37%, Negative Accuracy: 28.89%
# Epoch [450/500], Loss: 0.4396, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 27.91%, Negative Accuracy: 91.11%
# Epoch [451/500], Loss: 0.4112, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 23.26%, Negative Accuracy: 91.11%
# Epoch [452/500], Loss: 0.4165, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 86.05%, Negative Accuracy: 31.11%
# Epoch [453/500], Loss: 0.4128, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 39.53%, Negative Accuracy: 91.11%
# Epoch [454/500], Loss: 0.4153, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 23.26%, Negative Accuracy: 93.33%
# Epoch [455/500], Loss: 0.4187, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 37.21%, Negative Accuracy: 88.89%
# Epoch [456/500], Loss: 0.4317, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 30.23%, Negative Accuracy: 86.67%
# Epoch [457/500], Loss: 0.4315, Avg Accuracy: 0.5909090909090909,  Positive Accuracy: 27.91%, Negative Accuracy: 88.89%
# Epoch [458/500], Loss: 0.4104, Avg Accuracy: 0.625,  Positive Accuracy: 30.23%, Negative Accuracy: 93.33%
# Epoch [459/500], Loss: 0.4035, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 32.56%, Negative Accuracy: 88.89%
# Epoch [460/500], Loss: 0.4181, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 32.56%, Negative Accuracy: 93.33%
# Epoch [461/500], Loss: 0.4062, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 72.09%, Negative Accuracy: 33.33%
# Epoch [462/500], Loss: 0.4290, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 81.40%, Negative Accuracy: 31.11%
# Epoch [463/500], Loss: 0.4253, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 74.42%, Negative Accuracy: 31.11%
# Epoch [464/500], Loss: 0.4183, Avg Accuracy: 0.625,  Positive Accuracy: 39.53%, Negative Accuracy: 84.44%
# Epoch [465/500], Loss: 0.4063, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 32.56%, Negative Accuracy: 86.67%
# Epoch [466/500], Loss: 0.4307, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 30.23%, Negative Accuracy: 91.11%
# Epoch [467/500], Loss: 0.4309, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 93.02%, Negative Accuracy: 24.44%
# Epoch [468/500], Loss: 0.4274, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 34.88%, Negative Accuracy: 93.33%
# Epoch [469/500], Loss: 0.4253, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 27.91%, Negative Accuracy: 93.33%
# Epoch [470/500], Loss: 0.4283, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 30.23%, Negative Accuracy: 88.89%
# Epoch [471/500], Loss: 0.4175, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 41.86%, Negative Accuracy: 84.44%
# Epoch [472/500], Loss: 0.4134, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 39.53%, Negative Accuracy: 88.89%
# Epoch [473/500], Loss: 0.4338, Avg Accuracy: 0.625,  Positive Accuracy: 32.56%, Negative Accuracy: 91.11%
# Epoch [474/500], Loss: 0.4245, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 44.19%, Negative Accuracy: 84.44%
# Epoch [475/500], Loss: 0.4235, Avg Accuracy: 0.625,  Positive Accuracy: 37.21%, Negative Accuracy: 86.67%
# Epoch [476/500], Loss: 0.4066, Avg Accuracy: 0.6022727272727273,  Positive Accuracy: 30.23%, Negative Accuracy: 88.89%
# Epoch [477/500], Loss: 0.4083, Avg Accuracy: 0.625,  Positive Accuracy: 32.56%, Negative Accuracy: 91.11%
# Epoch [478/500], Loss: 0.4521, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 30.23%, Negative Accuracy: 91.11%
# Epoch [479/500], Loss: 0.4296, Avg Accuracy: 0.625,  Positive Accuracy: 39.53%, Negative Accuracy: 84.44%
# Epoch [480/500], Loss: 0.4254, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 37.21%, Negative Accuracy: 91.11%
# Epoch [481/500], Loss: 0.4376, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 27.91%, Negative Accuracy: 93.33%
# Epoch [482/500], Loss: 0.4361, Avg Accuracy: 0.6363636363636364,  Positive Accuracy: 34.88%, Negative Accuracy: 91.11%
# Epoch [483/500], Loss: 0.4195, Avg Accuracy: 0.625,  Positive Accuracy: 41.86%, Negative Accuracy: 82.22%
# Epoch [484/500], Loss: 0.4651, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 30.23%, Negative Accuracy: 84.44%
# Epoch [485/500], Loss: 0.4266, Avg Accuracy: 0.7272727272727273,  Positive Accuracy: 60.47%, Negative Accuracy: 84.44%
# Epoch [486/500], Loss: 0.4417, Avg Accuracy: 0.625,  Positive Accuracy: 32.56%, Negative Accuracy: 91.11%
# Epoch [487/500], Loss: 0.4452, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 20.93%, Negative Accuracy: 93.33%
# Epoch [488/500], Loss: 0.4190, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 86.05%, Negative Accuracy: 26.67%
# Epoch [489/500], Loss: 0.4223, Avg Accuracy: 0.5227272727272727,  Positive Accuracy: 81.40%, Negative Accuracy: 24.44%
# Epoch [490/500], Loss: 0.4033, Avg Accuracy: 0.625,  Positive Accuracy: 34.88%, Negative Accuracy: 88.89%
# Epoch [491/500], Loss: 0.4223, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 37.21%, Negative Accuracy: 91.11%
# Epoch [492/500], Loss: 0.3964, Avg Accuracy: 0.625,  Positive Accuracy: 30.23%, Negative Accuracy: 93.33%
# Epoch [493/500], Loss: 0.4372, Avg Accuracy: 0.5340909090909091,  Positive Accuracy: 67.44%, Negative Accuracy: 40.00%
# Epoch [494/500], Loss: 0.4109, Avg Accuracy: 0.5568181818181818,  Positive Accuracy: 74.42%, Negative Accuracy: 37.78%
# Epoch [495/500], Loss: 0.4114, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 20.93%, Negative Accuracy: 93.33%
# Epoch [496/500], Loss: 0.4214, Avg Accuracy: 0.6477272727272727,  Positive Accuracy: 37.21%, Negative Accuracy: 91.11%
# Epoch [497/500], Loss: 0.4101, Avg Accuracy: 0.6136363636363636,  Positive Accuracy: 27.91%, Negative Accuracy: 93.33%
# Epoch [498/500], Loss: 0.4263, Avg Accuracy: 0.5795454545454546,  Positive Accuracy: 23.26%, Negative Accuracy: 91.11%
# Epoch [499/500], Loss: 0.4081, Avg Accuracy: 0.625,  Positive Accuracy: 32.56%, Negative Accuracy: 91.11%
# Epoch [500/500], Loss: 0.4154, Avg Accuracy: 0.6590909090909091,  Positive Accuracy: 39.53%, Negative Accuracy: 91.11%

# %%
import glob
import glob
import numpy as np
import onnxruntime as ort

from collections import defaultdict

# %%
print(test_pos_dataset.columns)
# Out:
# Index(['HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD', 'HRV_SDSD', 'HRV_CVNN',
#        'HRV_CVSD', 'HRV_MedianNN', 'HRV_MadNN', 'HRV_MCVNN', 'HRV_IQRNN',
#        'HRV_SDRMSSD', 'HRV_Prc20NN', 'HRV_Prc80NN', 'HRV_pNN50', 'HRV_pNN20',
#        'HRV_MinNN', 'HRV_MaxNN', 'HRV_HTI', 'HRV_TINN', 'HRV_LF', 'HRV_HF',
#        'HRV_VHF', 'HRV_TP', 'HRV_LFHF', 'HRV_LFn', 'HRV_HFn', 'HRV_LnHF',
#        'wave_quality', 'label', 'id', 'age', 'gender'],
#       dtype='object')

# %%
import enum


def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    # 如果找到的文件不为空
    if onnx_files:
        # 按文件名排序
        onnx_files.sort()

        # 选择最后一个文件
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
def get_onnxfile():
    outdir = './outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    if onnx_files:
        onnx_files.sort()
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
ort_session = ort.InferenceSession(onnx_model_path)

# 预测函数
def predict(features):
    inputs = {ort_session.get_inputs()[0].name: features}
    outputs = ort_session.run(None, inputs)
    return outputs[0]

for idx, pair_data in enumerate([[test_neg_dataset, test_neg_features], [test_pos_dataset, test_pos_features]]):
    if idx == 0:
        print("\nTest for Negative subjects:")
    else:
        print("\nTest for Positive subjects:")

    # 加载测试数据集
    # 计算每个 subject 的准确率
    subject_results = defaultdict(list)

    for (_, row_dataset), (_, features), in zip(pair_data[0].iterrows(), pair_data[1].iterrows()):
        subject = row_dataset['id']
        label = row_dataset['label']

        features = np.array(features, dtype=np.float32)  # 确保 features 的数据类型与模型输入匹配
        features = features.reshape(1, -1)  # 调整形状以匹配模型输入
        prediction = predict(features)
        predicted_label = (prediction >= 0.5).astype(int)  # 使用阈值 0.5 将预测概率转换为类标签
        subject_results[subject].append((predicted_label, label))

    subject_accuracies = {}
    for subject, results in subject_results.items():
        correct = sum(1 for pred, label in results if pred == label)
        accuracy = correct / len(results)
        subject_accuracies[subject] = accuracy

    # 输出每个 subject 的准确度
    correct_count = 0
    for subject, accuracy in subject_accuracies.items():
        print(f'Subject: {subject}, Accuracy: {accuracy:.2f}')
        if accuracy > 0.5:
            correct_count += 1
        elif accuracy == 0.5:
            correct_count += 0.5
    print(f"subject accuracy: {(correct_count / len(subject_accuracies)):.2f}")
# Out:
# Test for Negative subjects:
# Subject: 40b9a027-fc21-b774-38b3-5d399ac1583c, Accuracy: 0.67
# Subject: c831132a-79ed-6676-ad6c-811e7d40789c, Accuracy: 0.67
# Subject: d2adc252-fd1e-659a-5b27-37327b37c4a4, Accuracy: 0.20
# Subject: c5cf4093-8c88-3388-dd4a-8de8169eac4d, Accuracy: 1.00
# Subject: 3b28f19d-7fd1-5d93-8fae-b6eae8ca3b82, Accuracy: 0.53
# subject accuracy: 0.80
#
# Test for Positive subjects:
# Subject: dc7e8552-e3c4-4695-379c-10e144338a4b, Accuracy: 0.60
# Subject: 29a8784b-8752-4de0-579c-034c95044509, Accuracy: 0.73
# Subject: f34fb6c0-c2f7-7367-3e25-d101c0605938, Accuracy: 0.79
# Subject: bf102cd1-feed-4807-9ce7-d8bbfe9d0afd, Accuracy: 0.33
# Subject: b61f44a3-7e22-8127-7d75-2060d82e1a9b, Accuracy: 0.73
# Subject: 43cb9b81-23c1-a136-bd28-41cae93082a3, Accuracy: 0.00
# Subject: 2a4bd1c8-888b-915b-d645-1ae939a492c5, Accuracy: 0.80
# subject accuracy: 0.71

# %% [markdown]
# # Testing Remaining Invalid and Unselected Valid Subjects
