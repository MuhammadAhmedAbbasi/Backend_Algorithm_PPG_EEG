# %%
import numpy as np
import pandas as pd
import sys
import os
import torch
import torch.nn as nn

import glob
import glob
import numpy as np
import onnxruntime as ort

from collections import defaultdict

# %%
import pandas as pd

# 加载数据
train_pos_dataset = pd.read_pickle('./new_data_2024_09_20/samples/train_pos_dataset.pkl')
train_neg_dataset = pd.read_pickle('./new_data_2024_09_20/samples/train_neg_dataset.pkl')
test_pos_dataset = pd.read_pickle('./new_data_2024_09_20/samples/test_pos_dataset.pkl')
test_neg_dataset = pd.read_pickle('./new_data_2024_09_20/samples/test_neg_dataset.pkl')
testing_pos_dataset = pd.read_pickle('./new_data_2024_09_20/samples/testing_positive.pkl')
testing_neg_dataset = pd.read_pickle('./new_data_2024_09_20/samples/testing_negative.pkl')

# 要删除的列
columns_to_drop = ['HRV_LF', 'HRV_LFHF', 'HRV_LFn']
# columns_to_drop = []

# 从所有数据集中删除指定的列
train_pos_dataset.drop(columns=columns_to_drop, inplace=True, errors='ignore')
train_neg_dataset.drop(columns=columns_to_drop, inplace=True, errors='ignore')
test_pos_dataset.drop(columns=columns_to_drop, inplace=True, errors='ignore')
test_neg_dataset.drop(columns=columns_to_drop, inplace=True, errors='ignore')
testing_pos_dataset.drop(columns=columns_to_drop, inplace=True, errors='ignore')
testing_neg_dataset.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# 提取唯一 ID 列表
test_val_pos_list = test_pos_dataset['id'].unique().tolist()
test_val_neg_list = test_neg_dataset['id'].unique().tolist()

# 创建验证和测试数据集
validation_pos_data = test_pos_dataset[test_pos_dataset['id'].isin(test_val_pos_list[:3])]
test_pos_dataset = test_pos_dataset[test_pos_dataset['id'].isin(test_val_pos_list[3:])]
validation_neg_data = test_neg_dataset[test_neg_dataset['id'].isin(test_val_neg_list[:3])]
test_neg_dataset = test_neg_dataset[test_neg_dataset['id'].isin(test_val_neg_list[3:])]

# %%
profile_columns = ['wave_quality', 'age', 'gender', 'label', 'id']

# %%
#  map_age will change the age into one-hot encoding  
def map_age(age):
    if age <= 15:
        return [1, 0, 0, 0]
    elif age > 15 and age <= 22:
        return [0, 1, 0, 0]
    elif age > 22 and age <= 30:
        return [0, 0, 1, 0]
    else:
        return [0, 0, 0, 1] 

#  map_gender will change the male and female into one-hot encoding  
def map_gender(gender):
    return [1, 0] if gender == 'Female' else [0, 1]

def preprocess(df):
    df_new = df.copy()
    df_new[['age_0', 'age_1', 'age_2', 'age_3']] = df_new['age'].apply(map_age).apply(pd.Series)
    df_new[['gender_0', 'gender_1']] = df_new['gender'].apply(map_gender).apply(pd.Series)
    return df_new.drop(profile_columns, axis=1)


# 应用预处理
train_pos_features = preprocess(train_pos_dataset)
train_neg_features = preprocess(train_neg_dataset)
val_pos_features = preprocess(validation_pos_data)
val_neg_features = preprocess(validation_neg_data)
test_pos_features = preprocess(test_pos_dataset)
test_neg_features = preprocess(test_neg_dataset)


testing_pos_features = preprocess(testing_pos_dataset)
testing_neg_features = preprocess(testing_neg_dataset)

# %%
# # # ---------------------------- 数据预处理 ----------------------------
# def map_age(age):
#     if age < 13:
#         return [1, 0]
#     elif age >= 13:
#         return [0, 1] 

# # ---------------------------- 数据预处理 ----------------------------
# def map_gender(gender):
#     return [1, 0] if gender == 'Female' else [0, 1]

# def preprocess(df):
#     df_new = df.copy()
    
#     df_new[['age_0', 'age_1']] = df_new['age'].apply(map_age).apply(pd.Series)
#     df_new[['gender_0', 'gender_1']] = df_new['gender'].apply(map_gender).apply(pd.Series)
#     return df_new.drop(profile_columns, axis=1)


# # 应用预处理
# train_pos_features = preprocess(train_pos_dataset)
# train_neg_features = preprocess(train_neg_dataset)
# val_pos_features = preprocess(validation_pos_data)
# val_neg_features = preprocess(validation_neg_data)
# test_pos_features = preprocess(test_pos_dataset)
# test_neg_features = preprocess(test_neg_dataset)


# testing_pos_features = preprocess(testing_pos_dataset)
# testing_neg_features = preprocess(testing_neg_dataset)

# %%
import enum

def get_onnxfile():
    outdir = './outdir'
    # outdir = './new_data_2024_09_20/outdir'
    onnx_files = glob.glob(os.path.join(outdir, '*.onnx'))
    # 如果找到的文件不为空
    if onnx_files:
        # 按文件名排序
        onnx_files.sort()

        # 选择最后一个文件
        last_onnx_file = onnx_files[-1]
        return last_onnx_file

onnx_model_path = get_onnxfile()
ort_session = ort.InferenceSession(onnx_model_path)

# 预测函数
def predict(features):
    inputs = {ort_session.get_inputs()[0].name: features}
    outputs = ort_session.run(None, inputs)
    return outputs[0]

for idx, pair_data in enumerate([[train_neg_dataset, train_neg_features], [train_pos_dataset, train_pos_features]]):
    if idx == 0:
        print("\nTest for Negative subjects:")
    else:
        print("\nTest for Positive subjects:")

    # 加载测试数据集
    # 计算每个 subject 的准确率
    subject_results = defaultdict(list)

    for (_, row_dataset), (_, features), in zip(pair_data[0].iterrows(), pair_data[1].iterrows()):
        subject = row_dataset['id']
        label = row_dataset['label']

        features = np.array(features, dtype=np.float32)  # 确保 features 的数据类型与模型输入匹配
        features = features.reshape(1, -1)  # 调整形状以匹配模型输入
        prediction = predict(features)
        predicted_label = (prediction >= 0.5).astype(int)  # 使用阈值 0.5 将预测概率转换为类标签
        subject_results[subject].append((predicted_label, label))

    subject_accuracies = {}
    subject_count = {}
    for subject, results in subject_results.items():
        correct = sum(1 for pred, label in results if pred == label)
        accuracy = correct / len(results)
        subject_accuracies[subject] = accuracy
        subject_count[subject] = len(results)

    # 输出每个 subject 的准确度
    correct_count = 0
    for (subject, accuracy),(_,count) in zip(subject_accuracies.items(), subject_count.items()):
        print(f'Subject: {subject}, Accuracy: {accuracy:.2f}, Sample Count: {count}')
        if accuracy > 0.5:
            correct_count += 1
        elif accuracy == 0.5:
            correct_count += 0.5
    print(f"subject accuracy: {(correct_count / len(subject_accuracies)):.2f}")
# Out:
# Test for Negative subjects:
# Subject: 8ee348e4-45c8-a3b3-9b30-c0fb2ac25c92, Accuracy: 1.00, Sample Count: 15
# Subject: 23d09035-1aa8-2fef-8065-f2addcf680d1, Accuracy: 1.00, Sample Count: 4
# Subject: e1a05473-85af-4aaf-dff5-9a9a507b188d, Accuracy: 1.00, Sample Count: 15
# Subject: 1949e035-2ac5-2dd1-c2f7-91d81ea9b546, Accuracy: 1.00, Sample Count: 14
# Subject: 2f8a7e09-3897-4161-d964-13f9736e20aa, Accuracy: 1.00, Sample Count: 15
# Subject: 5f9bfd68-ffc2-c961-4b39-d48a29d72b01, Accuracy: 0.18, Sample Count: 11
# Subject: 6ebcfb5d-f938-f673-4fa1-c2323b393ba6, Accuracy: 1.00, Sample Count: 5
# Subject: 8df51dda-6ebd-2c29-86b1-472960ceb38c, Accuracy: 1.00, Sample Count: 15
# Subject: 179dad82-dee9-d423-da3d-4917bae95aa8, Accuracy: 1.00, Sample Count: 6
# Subject: 8ae1e3fe-9ac7-5bc2-251c-62efe59be142, Accuracy: 1.00, Sample Count: 9
# Subject: 3e3d3729-8cb7-bc9c-a93e-98b196dd9fad, Accuracy: 1.00, Sample Count: 12
# Subject: 127d9913-29a2-25ff-d123-27423c776fd9, Accuracy: 1.00, Sample Count: 15
# Subject: 0b20c8c8-054c-420f-1261-d193cb95d365, Accuracy: 0.80, Sample Count: 15
# Subject: 8e57c504-b084-5555-3606-bcd242cb62b2, Accuracy: 0.14, Sample Count: 14
# Subject: bbcb257d-f62f-a809-ab9a-6a10305d43d5, Accuracy: 0.00, Sample Count: 1
# Subject: 34445fb0-1a82-48e0-a633-16c6dcbcf3d8, Accuracy: 1.00, Sample Count: 10
# Subject: 5637365c-5c44-f98a-5384-c14f9a6a1e82, Accuracy: 1.00, Sample Count: 5
# Subject: 13fbbc43-d58e-8115-1e69-0ab5503eb1f5, Accuracy: 1.00, Sample Count: 12
# Subject: 3db4ec78-0911-4334-3789-bfd1feee8d66, Accuracy: 1.00, Sample Count: 2
# Subject: 14c8e468-01a8-1fbb-da07-f2bd6638de33, Accuracy: 0.87, Sample Count: 15
# Subject: bc6ffe2d-6fd1-5723-266f-1cea446139b0, Accuracy: 1.00, Sample Count: 15
# Subject: eeb6a92b-0e23-7c08-c7ff-51c9fd87e0dc, Accuracy: 1.00, Sample Count: 15
# Subject: e16a91e3-e3a5-d42c-8226-8ccd414402a3, Accuracy: 1.00, Sample Count: 15
# Subject: 542242ec-d814-ee96-ad3b-b6fd8060dc79, Accuracy: 0.20, Sample Count: 15
# Subject: 9a909ffc-d13e-c38f-e866-f814defcbfda, Accuracy: 1.00, Sample Count: 2
# Subject: a3bb10b9-2ac2-ecf1-a40d-4cec92f0a2c9, Accuracy: 1.00, Sample Count: 15
# Subject: e144aa5e-bb1a-ee2e-4873-69dd9d71e4a4, Accuracy: 0.40, Sample Count: 15
# Subject: 1aeb556d-1e4f-31aa-204f-09b62f2c13d0, Accuracy: 1.00, Sample Count: 1
# Subject: 5d9a6588-b345-3ad6-b623-1fde4b1f279b, Accuracy: 0.00, Sample Count: 14
# Subject: c2a7924f-96fd-c4e5-f44e-73aa0d3060d8, Accuracy: 1.00, Sample Count: 11
# Subject: ef002460-af1e-0ae6-323b-20d8dd8dc250, Accuracy: 0.36, Sample Count: 11
# Subject: 5e8f7bd2-6461-9dc1-9253-486769cdaaf5, Accuracy: 1.00, Sample Count: 8
# Subject: b4cf31c5-df7a-075e-5459-a0afc90c538a, Accuracy: 1.00, Sample Count: 6
# Subject: ff83e26f-0773-9b45-f91c-071bd17b10b5, Accuracy: 1.00, Sample Count: 14
# Subject: f734890f-4e3a-c75d-4978-03f1ea48d841, Accuracy: 0.93, Sample Count: 15
# Subject: cf132970-7f2f-ca07-6a2a-d2f9acc07430, Accuracy: 0.50, Sample Count: 4
# Subject: 859959c0-bfb7-83a1-8594-5ae77ff3f3b4, Accuracy: 1.00, Sample Count: 15
# Subject: b2f8ac06-cf37-b601-f6f3-65f46b5ce500, Accuracy: 1.00, Sample Count: 13
# Subject: 2cee9fb6-e907-59ef-d44e-c3c6cf2aa5b2, Accuracy: 1.00, Sample Count: 1
# Subject: 061ae8cd-bf5f-aac7-ac62-7e6a59b78ac3, Accuracy: 0.53, Sample Count: 15
# Subject: 1cb46388-b67b-59a1-8854-7f80c60940a3, Accuracy: 0.50, Sample Count: 2
# Subject: b8d9a9fb-29ec-1049-eadc-3fedfb7ee5a5, Accuracy: 0.33, Sample Count: 15
# Subject: 6ef52454-faae-1300-671f-5132b7b3e1f5, Accuracy: 1.00, Sample Count: 15
# Subject: 711de251-858f-3c89-0c4f-380e4a5fd709, Accuracy: 1.00, Sample Count: 5
# Subject: 1787dc68-e640-2db3-0b3a-bfc0791f0f44, Accuracy: 1.00, Sample Count: 15
# Subject: ef736c08-6674-93c3-ba4b-c741a89b28e0, Accuracy: 1.00, Sample Count: 3
# Subject: 36c73f79-5f4d-1f15-6ae6-742529f3b18c, Accuracy: 0.18, Sample Count: 11
# Subject: 484f8abd-08c7-84a5-f6b2-bbfda13e048d, Accuracy: 1.00, Sample Count: 8
# Subject: 3d871aca-0451-5f0a-1e46-f76c3cb32ef0, Accuracy: 1.00, Sample Count: 12
# Subject: 3a510cc6-362b-8eba-7449-439c5a8d5f4c, Accuracy: 0.13, Sample Count: 15
# Subject: 915b5d62-9bb0-655d-c013-8c84c3e98c87, Accuracy: 1.00, Sample Count: 12
# Subject: aa491176-3c35-e430-81c3-bf365804068b, Accuracy: 1.00, Sample Count: 15
# Subject: 06d85785-c95e-2be3-7346-31b6fd182706, Accuracy: 1.00, Sample Count: 4
# Subject: 9394b150-8097-4249-46c4-0e430b348d73, Accuracy: 1.00, Sample Count: 15
# Subject: 7651ce74-6af3-5ee2-2f46-ba2fb14fcf4a, Accuracy: 0.47, Sample Count: 15
# Subject: ea30d007-14a6-4c63-e5ae-34b09e28cdb2, Accuracy: 0.20, Sample Count: 15
# Subject: a868764d-033a-1036-f905-e029dd4d7ff1, Accuracy: 0.50, Sample Count: 2
# Subject: eadb5607-8809-4eda-b570-20ce6422fe19, Accuracy: 1.00, Sample Count: 8
# Subject: f8fd9136-63dc-cceb-e257-42abcdabd431, Accuracy: 1.00, Sample Count: 15
# Subject: 09836267-ef48-a76b-cca0-e579b2f5558b, Accuracy: 0.13, Sample Count: 15
# Subject: e7ef58c6-93bd-7430-997f-2b23c1f76b9b, Accuracy: 0.33, Sample Count: 3
# Subject: 59761f60-ebf4-f92a-c8c8-5420ac37e3a9, Accuracy: 1.00, Sample Count: 5
# Subject: d26c81df-c282-df49-96d4-b3618aabe6b3, Accuracy: 1.00, Sample Count: 13
# Subject: 22dfdab7-c963-7995-fdb0-586cdb0fc750, Accuracy: 0.33, Sample Count: 9
# Subject: 057bdd99-be6b-81da-8e11-f6687117f0e2, Accuracy: 1.00, Sample Count: 7
# Subject: 15296f6a-42b1-9f4f-fdfe-4e6378685caa, Accuracy: 1.00, Sample Count: 9
# Subject: c7f56e0c-1c40-c762-dd9d-c5bf12a69684, Accuracy: 1.00, Sample Count: 1
# Subject: 41bdce27-e22c-0695-bd6d-201562589a47, Accuracy: 1.00, Sample Count: 1
# Subject: e1f563f8-90bf-4b92-be94-b2ebff83a52d, Accuracy: 0.64, Sample Count: 14
# Subject: 40b9a027-fc21-b774-38b3-5d399ac1583c, Accuracy: 0.12, Sample Count: 8
# Subject: 31678a19-e59c-c77c-620f-c923c10b34be, Accuracy: 1.00, Sample Count: 7
# Subject: fed9c748-0ecd-6c7e-f104-e05d74ba1488, Accuracy: 1.00, Sample Count: 15
# Subject: 47020f1f-8eae-e72a-3353-3eb135306622, Accuracy: 1.00, Sample Count: 13
# Subject: 1768b173-ebca-fcc0-4860-c989874c8710, Accuracy: 1.00, Sample Count: 7
# Subject: b475ecbe-c3cb-ade9-9115-2153613021d4, Accuracy: 0.50, Sample Count: 8
# Subject: 4ccc7c07-3fa7-ee92-80b7-99473cd0863b, Accuracy: 0.40, Sample Count: 15
# Subject: 661e44b7-55fa-5ba6-92c3-6dd79a697b9a, Accuracy: 1.00, Sample Count: 11
# Subject: f5dc6d57-2bc0-5c2b-3a42-2d74a826ea86, Accuracy: 0.50, Sample Count: 2
# Subject: 3b28f19d-7fd1-5d93-8fae-b6eae8ca3b82, Accuracy: 0.33, Sample Count: 9
# Subject: 1902fe28-88cc-14d1-e5e4-649a5205ae21, Accuracy: 1.00, Sample Count: 13
# Subject: 07d7ac89-e84f-aa9a-b4ba-ae0bda191e57, Accuracy: 1.00, Sample Count: 15
# Subject: 2a025ced-fe59-a4b3-0cf5-77689e20dc56, Accuracy: 0.45, Sample Count: 11
# Subject: ee8c18af-332e-29b3-1165-6f939deeecaa, Accuracy: 1.00, Sample Count: 15
# Subject: d6c0396b-1139-4395-446d-54dc25203921, Accuracy: 1.00, Sample Count: 5
# Subject: 442df0e7-2e07-179d-a11f-03b06a1cc0d0, Accuracy: 1.00, Sample Count: 11
# Subject: 47d05821-c083-6cda-3d31-882633c63e4c, Accuracy: 0.50, Sample Count: 2
# Subject: 6b0f1873-9701-013f-6690-be179a444335, Accuracy: 1.00, Sample Count: 12
# Subject: 519f7bf1-6ddf-4014-2caf-5e0ca8356316, Accuracy: 1.00, Sample Count: 2
# Subject: 48a96f87-7fc2-9aa9-bdbd-095bbb5c63ce, Accuracy: 0.64, Sample Count: 14
# Subject: b1258f68-6daa-4474-ee4d-2992522fe41e, Accuracy: 1.00, Sample Count: 12
# Subject: c5cf4093-8c88-3388-dd4a-8de8169eac4d, Accuracy: 0.70, Sample Count: 10
# Subject: ab6d10d7-2245-d3af-a1d7-f6d182d3131b, Accuracy: 0.40, Sample Count: 10
# Subject: a3f39dac-711d-cbee-1d09-e8d2019fa3d5, Accuracy: 1.00, Sample Count: 11
# Subject: 4492fe43-4473-da97-6ce5-0a85fa24a5f7, Accuracy: 0.40, Sample Count: 15
# Subject: a1276cea-f175-a713-48ae-75b4180e1631, Accuracy: 0.60, Sample Count: 15
# Subject: b61f44a3-7e22-8127-7d75-2060d82e1a9b, Accuracy: 1.00, Sample Count: 15
# Subject: 4da8cad4-9802-f921-35a5-6906386dd28a, Accuracy: 1.00, Sample Count: 5
# Subject: a94e4393-384c-3a99-3c14-c23e608dd4c7, Accuracy: 1.00, Sample Count: 11
# Subject: 22a0c441-5fad-ca2e-fe55-f667f0064b54, Accuracy: 0.38, Sample Count: 8
# Subject: c831132a-79ed-6676-ad6c-811e7d40789c, Accuracy: 1.00, Sample Count: 11
# Subject: cc472b11-54b5-5785-27d0-6b5ee4c644cf, Accuracy: 0.50, Sample Count: 6
# Subject: 9676a153-da9a-f46c-779e-551206d92e41, Accuracy: 1.00, Sample Count: 8
# Subject: 217fc97f-6078-0c93-dfa3-2ed780cd9195, Accuracy: 1.00, Sample Count: 8
# Subject: ae10b469-3e20-eff1-eb09-80c4b720a422, Accuracy: 1.00, Sample Count: 4
# Subject: 6eab329f-50ac-d683-4a01-e43aa320d366, Accuracy: 1.00, Sample Count: 3
# Subject: 93bca70f-a46b-5b41-f937-01d66c0f98e4, Accuracy: 1.00, Sample Count: 2
# Subject: 4cc407e4-9771-02b6-cfd0-fc847ce6ba05, Accuracy: 1.00, Sample Count: 2
# Subject: 695153b8-cd54-28f7-5e2d-b43ef7a12347, Accuracy: 1.00, Sample Count: 15
# Subject: f9b743a8-3d70-e8e9-7af8-6e1cb5d66567, Accuracy: 1.00, Sample Count: 10
# Subject: 91a89ac9-f767-614f-97dd-ce09b72a6605, Accuracy: 1.00, Sample Count: 12
# Subject: 4d8d4de5-a420-5e4f-2981-071431b849d2, Accuracy: 0.67, Sample Count: 15
# Subject: 314c2a44-e7c2-2307-3960-9930e029b720, Accuracy: 0.40, Sample Count: 5
# Subject: 38d47811-cff4-9965-fce9-facf4a613c60, Accuracy: 1.00, Sample Count: 3
# Subject: 6d879db2-4a18-1839-ca0d-dfb7a5f77f54, Accuracy: 0.87, Sample Count: 15
# Subject: d2adc252-fd1e-659a-5b27-37327b37c4a4, Accuracy: 0.21, Sample Count: 14
# Subject: d148761a-1175-29ae-7dd8-a73a529fd059, Accuracy: 1.00, Sample Count: 9
# Subject: e775fef5-8005-4574-8dbc-9779f5fd78fd, Accuracy: 1.00, Sample Count: 4
# Subject: d9bc42e3-776a-3ccd-9224-b66b4cbd92df, Accuracy: 0.80, Sample Count: 15
# Subject: 37ae4b7c-04fb-841c-75a6-532fe936a7cf, Accuracy: 1.00, Sample Count: 12
# Subject: afdb37c1-120c-eca1-f767-866485073f77, Accuracy: 0.10, Sample Count: 10
# Subject: 39b695f2-2cdd-ce5b-709a-a263cb8f9b34, Accuracy: 1.00, Sample Count: 15
# Subject: 9b7e0bf0-38fc-8797-a0e1-a758b9aedf4c, Accuracy: 0.40, Sample Count: 15
# Subject: 229fd00c-e370-07b5-b549-ab30f3cbbc69, Accuracy: 0.20, Sample Count: 5
# Subject: 73ad61cb-2c13-f505-c171-605e5b7eb722, Accuracy: 0.80, Sample Count: 10
# Subject: 15ef5ac8-90d2-748d-a81a-e83f4c603443, Accuracy: 0.36, Sample Count: 11
# Subject: fd7d9b8c-4574-1507-2226-212529e156dc, Accuracy: 1.00, Sample Count: 15
# Subject: 0a33cb89-a686-9b15-5d49-451ff77bec3d, Accuracy: 0.14, Sample Count: 14
# Subject: 48954108-6a28-64cd-2585-ce708fa6e2be, Accuracy: 0.00, Sample Count: 2
# Subject: 0feb0f39-532d-2486-1f6b-2f8c0d70b24f, Accuracy: 1.00, Sample Count: 10
# Subject: 163f49e3-4026-e051-efaf-e91b9f15dc95, Accuracy: 1.00, Sample Count: 4
# Subject: c35d0097-5810-67c4-7c8e-72e8673f0bdc, Accuracy: 1.00, Sample Count: 11
# Subject: ad674d01-4c98-9197-6876-ae14db61152f, Accuracy: 0.67, Sample Count: 3
# Subject: 992df89c-aed5-6b21-8a06-8e362c4e9ef4, Accuracy: 0.27, Sample Count: 15
# Subject: e308825b-1e12-18f9-fa00-0d2c2e5f60ca, Accuracy: 0.93, Sample Count: 15
# Subject: 3e648288-ddaa-9fa0-af04-d8aa9c5d3aca, Accuracy: 0.09, Sample Count: 11
# Subject: 202f313a-af01-11e3-b2ba-f02a374ec24f, Accuracy: 0.10, Sample Count: 10
# Subject: ac0cde67-f643-22c6-0e97-b910b70dfce9, Accuracy: 0.00, Sample Count: 15
# Subject: f8651b9a-791a-5d89-baa8-5cb38ae5401b, Accuracy: 1.00, Sample Count: 7
# Subject: 3534febe-86c1-f2e5-faf4-86b8dd027e56, Accuracy: 0.20, Sample Count: 15
# Subject: 3bd7c5d4-8402-103f-04d7-9b00d4e5ebba, Accuracy: 1.00, Sample Count: 12
# Subject: 1eb091d2-2d29-6b79-4681-3dc9b04218fc, Accuracy: 0.14, Sample Count: 7
# Subject: 636bcbaf-43d6-7c8d-4864-417c3a9da5d2, Accuracy: 1.00, Sample Count: 11
# Subject: de72d4fb-812e-92b2-e268-b1d5b816ce56, Accuracy: 1.00, Sample Count: 1
# Subject: c32b0eae-5547-1f49-7179-d0b241871dbc, Accuracy: 0.83, Sample Count: 12
# Subject: eb658d47-4cab-b1f2-cd54-a6c3535ccd3b, Accuracy: 1.00, Sample Count: 13
# Subject: 2121ad4a-6621-530c-2a3d-cc49dfb50341, Accuracy: 1.00, Sample Count: 10
# Subject: 7cd75eea-7f3f-51df-944c-dde56c17e4be, Accuracy: 0.18, Sample Count: 11
# subject accuracy: 0.72
#
# Test for Positive subjects:
# Subject: 20240717_2A12, Accuracy: 0.73, Sample Count: 246
# Subject: 20240717_2A21, Accuracy: 0.75, Sample Count: 230
# Subject: 25342799-aff8-b14a-81eb-940a97ce65a7, Accuracy: 0.00, Sample Count: 71
# Subject: 0cf44683-dda2-b7fb-5d13-9151df4db1c5, Accuracy: 0.55, Sample Count: 31
# Subject: 59d9f43d-b1cb-5c9e-82b2-e6f649c67f20, Accuracy: 0.29, Sample Count: 24
# Subject: f34fb6c0-c2f7-7367-3e25-d101c0605938, Accuracy: 0.58, Sample Count: 64
# Subject: 6a44c3c3-f41c-91a8-85d8-915156655f23, Accuracy: 0.00, Sample Count: 12
# Subject: 00212fb4-0488-59a8-2688-5fe74ee77781, Accuracy: 0.38, Sample Count: 42
# Subject: dc7e8552-e3c4-4695-379c-10e144338a4b, Accuracy: 0.80, Sample Count: 64
# Subject: bf102cd1-feed-4807-9ce7-d8bbfe9d0afd, Accuracy: 0.90, Sample Count: 31
# Subject: 2a4bd1c8-888b-915b-d645-1ae939a492c5, Accuracy: 0.87, Sample Count: 71
# Subject: a4993294-3529-e653-3177-ce307357ea08, Accuracy: 0.76, Sample Count: 25
# Subject: 5f9070ae-5c60-fc6c-23f7-027734646ce4, Accuracy: 0.52, Sample Count: 61
# Subject: d269758d-078b-c2d3-9996-1a54e129cba9, Accuracy: 0.62, Sample Count: 24
# Subject: 0f00efc4-65ef-cace-2e33-394ed0eaac10, Accuracy: 0.76, Sample Count: 71
# Subject: 5c941061-c729-0f7a-c1b1-6c5813bd8363, Accuracy: 0.35, Sample Count: 71
# Subject: 0db4808b-1953-08fd-c848-086386c6707c, Accuracy: 0.74, Sample Count: 70
# Subject: 850e5fd0-90a9-b081-8202-339998bb51cf, Accuracy: 0.00, Sample Count: 64
# Subject: 5d1ed612-d672-588d-91e9-19616832e65e, Accuracy: 0.00, Sample Count: 69
# Subject: f1b5a636-2ab1-52de-df4b-648c041aaa19, Accuracy: 0.45, Sample Count: 71
# Subject: 513195bb-f9b4-1d3d-6829-4cdf70008d23, Accuracy: 0.78, Sample Count: 37
# Subject: eeb255b5-6a3d-0f9f-2f96-7f14b74472a4, Accuracy: 0.00, Sample Count: 13
# Subject: c9f6bffc-451c-2f44-b658-d1e15dac902f, Accuracy: 0.51, Sample Count: 61
# Subject: 9878443f-63d9-06a0-2314-c105d40cfbf0, Accuracy: 0.25, Sample Count: 4
# Subject: 711c0cea-be2d-f87e-57d9-05fd203426e9, Accuracy: 0.81, Sample Count: 64
# Subject: 0e88cac0-231c-e492-409c-8a5d2683b181, Accuracy: 0.80, Sample Count: 45
# Subject: a793eaaf-fd17-2821-5e37-0ca88a71d1dc, Accuracy: 0.00, Sample Count: 58
# Subject: 99a8891e-67de-e941-e435-7c30c7faf658, Accuracy: 0.64, Sample Count: 28
# Subject: 9a34857c-2f52-99be-d371-af9a8244b656, Accuracy: 0.00, Sample Count: 71
# Subject: 29a8784b-8752-4de0-579c-034c95044509, Accuracy: 0.51, Sample Count: 53
# Subject: 6b209cbb-d1b5-72ad-62f8-a698a20eeaa8, Accuracy: 0.00, Sample Count: 70
# Subject: 4115b0eb-dfb2-12c9-325e-91cf5d65c64f, Accuracy: 0.62, Sample Count: 13
# Subject: 198bf5f3-cb34-b325-5b8e-4b8dcf838f53, Accuracy: 0.92, Sample Count: 38
# Subject: 04a8fa82-4f32-d69c-72d9-8d82a472b803, Accuracy: 0.24, Sample Count: 34
# subject accuracy: 0.59

# %%
for key, value in subject_results.items():
    print(key,len(value))
# Out:
# 20240717_2A12 246
# 20240717_2A21 230
# 25342799-aff8-b14a-81eb-940a97ce65a7 71
# 0cf44683-dda2-b7fb-5d13-9151df4db1c5 31
# 59d9f43d-b1cb-5c9e-82b2-e6f649c67f20 24
# f34fb6c0-c2f7-7367-3e25-d101c0605938 64
# 6a44c3c3-f41c-91a8-85d8-915156655f23 12
# 00212fb4-0488-59a8-2688-5fe74ee77781 42
# dc7e8552-e3c4-4695-379c-10e144338a4b 64
# bf102cd1-feed-4807-9ce7-d8bbfe9d0afd 31
# 2a4bd1c8-888b-915b-d645-1ae939a492c5 71
# a4993294-3529-e653-3177-ce307357ea08 25
# 5f9070ae-5c60-fc6c-23f7-027734646ce4 61
# d269758d-078b-c2d3-9996-1a54e129cba9 24
# 0f00efc4-65ef-cace-2e33-394ed0eaac10 71
# 5c941061-c729-0f7a-c1b1-6c5813bd8363 71
# 0db4808b-1953-08fd-c848-086386c6707c 70
# 850e5fd0-90a9-b081-8202-339998bb51cf 64
# 5d1ed612-d672-588d-91e9-19616832e65e 69
# f1b5a636-2ab1-52de-df4b-648c041aaa19 71
# 513195bb-f9b4-1d3d-6829-4cdf70008d23 37
# eeb255b5-6a3d-0f9f-2f96-7f14b74472a4 13
# c9f6bffc-451c-2f44-b658-d1e15dac902f 61
# 9878443f-63d9-06a0-2314-c105d40cfbf0 4
# 711c0cea-be2d-f87e-57d9-05fd203426e9 64
# 0e88cac0-231c-e492-409c-8a5d2683b181 45
# a793eaaf-fd17-2821-5e37-0ca88a71d1dc 58
# 99a8891e-67de-e941-e435-7c30c7faf658 28
# 9a34857c-2f52-99be-d371-af9a8244b656 71
# 29a8784b-8752-4de0-579c-034c95044509 53
# 6b209cbb-d1b5-72ad-62f8-a698a20eeaa8 70
# 4115b0eb-dfb2-12c9-325e-91cf5d65c64f 13
# 198bf5f3-cb34-b325-5b8e-4b8dcf838f53 38
# 04a8fa82-4f32-d69c-72d9-8d82a472b803 34

# %%
import pandas as pd


Student_path = r'C:\Users\Administrator\Desktop\Backend-Algorithm\Algorithm\PPG\ppg_depression\data_preprocess\new_data_2024_09_20\outdir\MiddleSchool_Depression_Anxiety.xlsx'
middle_file_dir = r'C:\Users\Administrator\Desktop\middle_school_data\ppg_data'
students = pd.read_excel(Student_path, sheet_name= 'MHT')
student_id = students['subjectid']
gender = students['gender']
age = students['age']

# %%
student_data = students[students['subjectid'] == '1787dc68-e640-2db3-0b3a-bfc0791f0f44']

# %%
s = student_data['gender'].tolist()[0]

# %%
s
# Out:
# 'Male'

# %%
import sys
from service.ppg.ppg_algorithm_service import *
from Service.config import *
import pandas as pd


Student_path = r'C:\Users\Administrator\Desktop\Backend-Algorithm\Algorithm\PPG\ppg_depression\data_preprocess\new_data_2024_09_20\outdir\MiddleSchool_Depression_Anxiety.xlsx'
middle_file_dir = r'C:\Users\Administrator\Desktop\middle_school_data\ppg_data'
students = pd.read_excel(Student_path, sheet_name= 'MHT')
student_id = students['subjectid']
gender = students['gender']
age = students['age']


def load_wave_middleSchool(path):
    try:
        with open(path, 'r', encoding='utf-8') as file:  
            data = json.load(file)
        return data["ppg_raw_data"]
    except:
        print("Subject Not Loaded")
        pass

def generate_dataset(subject_collection):
    ignored_id = []
    dataset = pd.DataFrame()
    student_id = students['subjectid']
    gender = students['gender']
    age = students['age']
    for subject, g, a in zip(student_id, gender, age):
            # The university subjects.
            files = os.listdir(middle_file_dir)
            for file in files:
                if file.startswith(subject) and file.endswith('.json'):
                    file_path = os.path.join(middle_file_dir, file)
                    tmp_wave = load_wave_middleSchool(file_path)
                    print(f"Subject Wave {len(tmp_wave)}, Subject gender: {g}, Subject age: {a}")

            if len(tmp_wave) >= (sampling_frequency * data_minimum_minutes_threshold * 60):
                # Perform prediction
                prediction_results = ppg_get_pyschoindex(tmp_wave, 125, g, a)
                # Extract predictions
                depression_prediction = prediction_results.depression_prediction
                anxiety_prediction = prediction_results.anxiety_prediction
                stress_prediction = prediction_results.stress_prediction
                # vitality_prediction = prediction_results.vitality_prediction
                # insomnia_service = prediction_results.insomnia_prediction
                print(depression_prediction, anxiety_prediction, stress_prediction)

train_pos_dataset = generate_dataset(student_id)

# %%
def generate_dataset(student_id):
    Student_path = r'C:\Users\Administrator\Desktop\Backend-Algorithm\Algorithm\PPG\ppg_depression\data_preprocess\new_data_2024_09_20\outdir\MiddleSchool_Depression_Anxiety.xlsx'
    middle_file_dir = r'C:\Users\Administrator\Desktop\middle_school_data\ppg_data'
    students = pd.read_excel(Student_path, sheet_name= 'MHT')
    student_data = students[students['subjectid'] == student_id]
    gender = students['gender']
    age = students['age']
    files = os.listdir(middle_file_dir)
    for file in files:
        if file.startswith(student_id) and file.endswith('.json'):
            file_path = os.path.join(middle_file_dir, file)
            X = load_wave_middleSchool(file_path)
            print(f"Subject Wave {len(X)}, Subject gender: {gender}, Subject age: {age}")
