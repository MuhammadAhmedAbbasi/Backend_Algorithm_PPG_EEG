# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 读取 Excel 文件
file_path = '../healthy_scale_results.xlsx'  # 将此替换为您的 Excel 文件路径
df = pd.read_excel(file_path, sheet_name='ERQ')
print(df)
# Out:
#      ID Sex  Age (years)  height  weight（kg）  \
# 0   A01   男           22   174.0        60.0
# 1   A02   男           21   180.0        71.0
# 2   A03   男           42   168.0        55.0
# 3   A04   男           22   165.0        53.0
# 4   A05   男           22   164.0        65.0
# 5   A06   男           21   173.0        72.0
# 6   A07   男           22   165.0        62.0
# 7   A08   男           23   177.0        68.0
# 8   A09   男           22   178.0        56.0
# 9   A10   男           22   178.0        65.0
# 10  A11   男           23   162.0        84.0
# 11  A12   女           20   167.0        60.0
# 12  A13   女           22   168.0        54.0
# 13  A14   女           21   164.0        56.0
# 14  A15   女           20   160.0        56.0
# 15  A16   女           20   160.0        46.0
# 16  A17   女           18   156.0        50.0
# 17  A18   女           20   163.5        60.0
# 18  A19   女           15   163.0        50.0
# 19  A20   女           25   155.0        60.0
# ...

# %%
# Sex 分布
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Sex')
plt.title('Sex Distribution')
plt.show()
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30007 (\N{CJK UNIFIED IDEOGRAPH-7537}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22899 (\N{CJK UNIFIED IDEOGRAPH-5973}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Age 分布
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='Age (years)', kde=True)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ###

# %% [markdown]
# #### 患者数据进行分析

# %%
file_path = '../unhealthy_clinic_results.xlsx'  # 将此替换为您的 Excel 文件路径
unhealthy_df = pd.read_excel(file_path)
print(unhealthy_df)
# Out:
#                床号 性别  年龄            入院时间             入院诊断        病情备注  抑郁  焦虑  \
# 0   20240619_2A02  女  25   6/17/24 16:44           双向情感障碍         NaN   1   0
# 1   20240619_2A03  女  41   6/17/24 10:31           焦虑抑郁状态  焦虑明显，抑郁有一点   0   1
# 2   20240619_2A05  女  38   6/17/24 13:39          广泛性焦虑障碍         NaN   0   1
# 3   20240619_2A06  女  60   6/12/24 14:02             焦虑状态     目前没什么焦虑   0   1
# 4   20240619_2A07  女  56     6/4/24 9:33          复发性抑郁障碍         NaN   1   0
# 5   20240619_2A08  女  57   6/14/24 08：57           焦虑抑郁状态      焦虑但不抑郁   0   1
# 6   20240619_2A09  女  56   6/15/24 10：58          复发性抑郁障碍         NaN   1   0
# 7   20240619_2A15  女  53   6/11/24 08：53          复发性抑郁障碍         NaN   1   0
# 8   20240619_2A17  女  62   6/12/24 09：17           焦虑抑郁状态         NaN   0   1
# 9   20240619_2A19  女  73   6/11/24 10：18          复发性抑郁障碍         NaN   1   0
# 10  20240619_2A21  男  59   6/17/24 08：51          复发性抑郁障碍         NaN   1   0
# ...

# %%
depression_df = unhealthy_df[unhealthy_df['焦虑']==1]
# print(depression_df)
plt.figure(figsize=(10, 5))
sns.histplot(data=depression_df, x='年龄', kde=True)
plt.title('Age Distribution')
plt.show()
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 40836 (\N{CJK UNIFIED IDEOGRAPH-9F84}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
